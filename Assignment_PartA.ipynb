# %% [markdown]
# ## FIT3182 ASSIGNMENT 2 Part A
# #####  Student ID: 32203004
# #####  Student Email: cgoh0016@student.monash.edu

# %% [markdown]
# ### Task 1:  MongoDB Data Model

# %%
{
    "_id": ObjectId("..."),  
    "station": 948700,
    "date": ISODate("2023-11-21"),
    "hotspots": [{
                    "time": item.isoformat(),
                    "coordinates": [lat, long],
                    "confidence": int(row["confidence"]),  
                    "surface_temperature_celcius": float(row["surface_temperature_celcius"])
                    }]
    "ghi": 250
    "air_temperature_celcius": 22.1,
    "relative_humidity": 65,
    "windspeed_knots": 10,
    "max_wind_speed": 15,
    "precipitation": 0.0,
  
}

# %% [markdown]
# ### Justification
#
# First off, here are the findings from analyzing the queries and the dataset:
# 1. One climate record may be linked with multiple hotspot records resulting in a one to many relationship
# 2. Data Redundancy (Potential): Embedding hotspot data within the climate records could lead to some data redundancy, especially as the collection size grows. However, for the dataset size likely encountered in Task 2, this redundancy is manageable, and the benefits outweigh the drawbacks.
#
# Hence, by combining the data via embedding, you can directly analyze how factors like air temperature, humidity, or wind speed relate to the surface temperature hotspots. This would be much more difficult if you had to query and join the data from separate collections every time.
#
# In addition, if you frequently need to retrieve both hotspot data and relevant climate data for a specific date and location (in this case in **Task 2: Question 2C, 2D** and so on, embedding them into one collection simplifies queries. You can write a single query to get the information you need, rather than needing to query and join data from separate collections.
#
# Moreover, when the data is embedded, you can create visualizations that combine hotspot locations with climate data. This can provide a more comprehensive understanding of the relationship between the two. For example, you could create a map that shows hotspots overlaid with contours of air temperature.
#
# This may however, result in data redundancy, especially as the collection size grows. This would not be a large concern or affect the database as it would be impossible for the amount of fires to exceed the maximum file size per document for MongoDB.
#
# In addition, we can easily rectify this by introducing denormalization and indexing.
#
# ###  Task 2. Querying MongoDB using PyMongo (15%)
# #### Task 2.1

# %%
# IMPORTING 
import numpy as np
import pandas as pd 
from pymongo import MongoClient

# %%
# READING CSV FOR CHECKING PURPOSES
climate = pd.read_csv('/home/student/A2/Dataset/climate_historic.csv')
hotspot = pd.read_csv('/home/student/A2/Dataset/hotspot_historic.csv')

# %%
# CONNECTING TO MONGO
client = MongoClient('10.192.104.132', 27017)
db = client["fit3182_assignment_db"]

climate_data_collection = db["climate_data"]

# %%
climate_data_collection.drop()

# %%
import csv
import datetime

def insert_document(collection, data):
  try:
    collection.insert_one(data)
  except Exception as e:
    print(f"Error inserting document: {e}")

# Read hotspot data
with open(r"/home/student/A2/Dataset/climate_historic.csv") as csvfile:
  reader = csv.DictReader(csvfile)
  for row in reader:
    item = datetime.datetime.strptime(row["date"], "%d/%m/%Y").date().isoformat()
    
    with open("/home/student/A2/Dataset/hotspot_historic.csv") as hotspot_file:
            hotspot_reader = csv.DictReader(hotspot_file)
            matching_hotspots = []
            for hotspot_row in hotspot_reader:
                hotspot_date = datetime.datetime.strptime(hotspot_row["date"], "%d/%m/%Y").date().isoformat()
                if hotspot_date == item:
                    matching_hotspots.append({
                        "time": datetime.datetime.strptime(hotspot_row["datetime"], "%Y-%m-%d %H:%M:%S").time().isoformat(),
                        "latitude": float(hotspot_row["latitude"]),
                        "longitude": float(hotspot_row["longitude"]),
                        "surface_temperature_celcius": float(hotspot_row["surface_temperature_celcius"]),
                        "confidence": float(hotspot_row["confidence"])
                    })
    
    data = {
            "date": item,
            "station": row["station"],
            "air_temperature_celcius": float(row["air_temperature_celcius"]),
            "relative_humidity": float(row["relative_humidity"]),
            "windspeed_knots": float(row["windspeed_knots"]),
            "max_wind_speed": float(row["max_wind_speed"]),
            "precipitation": (row["precipitation"]),  
            "GHI_w/m2": float(row["GHI_w/m2"]),
            "hotspots": matching_hotspots
        }
    insert_document(climate_data_collection, data)

# %%
# testing
from pprint import pprint
pprint(client.list_database_names())
pprint(db.list_collection_names())

climatecount = climate_data_collection.count_documents({})  
# hotspotcount = hotspots_collection.count_documents({}) 

climatecsvcount = climate.shape[0]
hotspotcsvcount = hotspot.shape[0]

print(f"Number of documents in climate data: {climatecount}")
# print(f"Number of documents in hotspot data: {hotspotcount}")
print(f"Number of rows in climate data CSV: {climatecsvcount}")
print(f"Number of rows in hotspot data CSV: {hotspotcsvcount}")
# Out:
# ['admin', 'config', 'fit3182_assignment_db', 'fit3182_db', 'local']
# ['climate_data']
# Number of documents in climate data: 366
# Number of rows in climate data CSV: 366
# Number of rows in hotspot data CSV: 2668

# %%
document1 = climate_data_collection.find_one()
pprint(document1)

random_records = climate_data_collection.aggregate([{ "$sample": { "size": 5 } }])
for record in random_records:
    pprint(record)
# Out:
# {'GHI_w/m2': 154.0,
#  '_id': ObjectId('6654141b4f0eb9e1d0be3797'),
#  'air_temperature_celcius': 19.0,
#  'date': '2022-12-31',
#  'hotspots': [],
#  'max_wind_speed': 11.1,
#  'precipitation': '0.00I',
#  'relative_humidity': 56.8,
#  'station': '948700',
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 183.0,
#  '_id': ObjectId('6654142c4f0eb9e1d0be38de'),
#  'air_temperature_celcius': 23.0,
#  'date': '2023-11-24',
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation': '0.01G',
#  'relative_humidity': 58.8,
#  'station': '948702',
#  'windspeed_knots': 9.1}
# {'GHI_w/m2': 82.0,
#  '_id': ObjectId('665414264f0eb9e1d0be3853'),
#  'air_temperature_celcius': 9.0,
#  'date': '2023-07-08',
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation': '0.08G',
#  'relative_humidity': 42.8,
#  'station': '948701',
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 82.0,
#  '_id': ObjectId('665414274f0eb9e1d0be3871'),
#  'air_temperature_celcius': 9.0,
#  'date': '2023-08-07',
#  'hotspots': [],
#  'max_wind_speed': 15.9,
#  'precipitation': '0.12G',
#  'relative_humidity': 42.9,
#  'station': '948702',
#  'windspeed_knots': 8.9}
# {'GHI_w/m2': 128.0,
#  '_id': ObjectId('6654142d4f0eb9e1d0be38eb'),
#  'air_temperature_celcius': 15.0,
#  'date': '2023-12-07',
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation': '1.26G',
#  'relative_humidity': 51.0,
#  'station': '948702',
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 180.0,
#  '_id': ObjectId('665414214f0eb9e1d0be37eb'),
#  'air_temperature_celcius': 23.0,
#  'date': '2023-03-26',
#  'hotspots': [{'confidence': 74.0,
#                'latitude': -37.665,
#                'longitude': 142.1339,
#                'surface_temperature_celcius': 48.0,
#                'time': '04:47:20'},
#               {'confidence': 74.0,
#                'latitude': -38.0564,
#                'longitude': 142.8525,
#                'surface_temperature_celcius': 48.0,
#                'time': '04:43:40'},
#               {'confidence': 81.0,
#                'latitude': -38.018,
#                'longitude': 143.899,
#                'surface_temperature_celcius': 54.0,
#                'time': '04:43:20'},
#               {'confidence': 68.0,
#                'latitude': -38.1131,
#                'longitude': 143.7173,
#                'surface_temperature_celcius': 44.0,
#                'time': '04:41:10'},
#               {'confidence': 80.0,
#                'latitude': -38.1106,
#                'longitude': 143.7314,
#                'surface_temperature_celcius': 53.0,
#                'time': '04:40:50'},
#               {'confidence': 75.0,
#                'latitude': -37.8289,
#                'longitude': 145.9315,
#                'surface_temperature_celcius': 49.0,
#                'time': '04:40:10'},
#               {'confidence': 81.0,
#                'latitude': -38.0652,
#                'longitude': 142.9781,
#                'surface_temperature_celcius': 54.0,
#                'time': '04:39:50'},
#               {'confidence': 71.0,
#                'latitude': -37.522,
#                'longitude': 143.3874,
#                'surface_temperature_celcius': 73.0,
#                'time': '04:39:10'},
#               {'confidence': 91.0,
#                'latitude': -38.0674,
#                'longitude': 142.965,
#                'surface_temperature_celcius': 68.0,
#                'time': '04:39:10'},
#               {'confidence': 92.0,
#                'latitude': -38.0715,
#                'longitude': 142.9591,
#                'surface_temperature_celcius': 70.0,
#                'time': '04:39:10'},
#               {'confidence': 100.0,
#                'latitude': -38.0693,
#                'longitude': 142.9722,
#                'surface_temperature_celcius': 89.0,
#                'time': '04:39:10'},
#               {'confidence': 82.0,
#                'latitude': -37.9488,
#                'longitude': 143.8882,
#                'surface_temperature_celcius': 55.0,
#                'time': '04:39:10'},
#               {'confidence': 87.0,
#                'latitude': -37.9462,
#                'longitude': 143.9026,
#                'surface_temperature_celcius': 62.0,
#                'time': '04:39:10'},
#               {'confidence': 60.0,
#                'latitude': -37.8469,
#                'longitude': 143.5343,
#                'surface_temperature_celcius': 50.0,
#                'time': '04:39:10'},
#               {'confidence': 84.0,
#                'latitude': -37.8468,
#                'longitude': 142.8775,
#                'surface_temperature_celcius': 58.0,
#                'time': '04:39:10'},
#               {'confidence': 67.0,
#                'latitude': -37.1956,
#                'longitude': 141.0252,
#                'surface_temperature_celcius': 44.0,
#                'time': '04:39:10'},
#               {'confidence': 74.0,
#                'latitude': -38.0542,
#                'longitude': 142.8655,
#                'surface_temperature_celcius': 48.0,
#                'time': '04:39:10'}],
#  'max_wind_speed': 26.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 60.6,
#  'station': '948701',
#  'windspeed_knots': 10.1}

# %% [markdown]
# #### Task 2.2 MongoDB Queries

# %%
# QUESTION A
a = list(climate_data_collection.find({'date': '2023-12-12'}))
print("Climate data on 12th December 2023:")
for record in a:
    pprint(record)
# Out:
# Climate data on 12th December 2023:
# {'GHI_w/m2': 156.0,
#  '_id': ObjectId('6654142d4f0eb9e1d0be38f0'),
#  'air_temperature_celcius': 19.0,
#  'date': '2023-12-12',
#  'hotspots': [{'confidence': 53.0,
#                'latitude': -37.903,
#                'longitude': 145.25,
#                'surface_temperature_celcius': 44.0,
#                'time': '00:45:38'}],
#  'max_wind_speed': 12.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 55.3,
#  'station': '948702',
#  'windspeed_knots': 6.2}

# %%
# QUESTION B
# Find the latitude, longitude, surface temperature (°C), and confidence 
# when the surface temperature (°C) was between 65 °C and 100 °C
b = list(climate_data_collection.aggregate([{'$unwind': '$hotspots'}, 
                                                 {'$match': {'hotspots.surface_temperature_celcius': {'$gte': 65, '$lte': 100}}}, 
                                                 {'$project': {'_id': 0, 'latitude': '$hotspots.latitude', 
                               'longitude': '$hotspots.latitude', 
                               'surface_temperature_celcius': '$hotspots.surface_temperature_celcius'}}]))

print(len(b))
print("\nHotspot data when surface temperature was between 65 °C and 100 °C:")
for record in b:
    pprint(record)
# Out:
# 476
#
# Hotspot data when surface temperature was between 65 °C and 100 °C:
# {'latitude': -37.2284,
#  'longitude': -37.2284,
#  'surface_temperature_celcius': 73.0}
# {'latitude': -37.6572,
#  'longitude': -37.6572,
#  'surface_temperature_celcius': 80.0}
# {'latitude': -37.0193,
#  'longitude': -37.0193,
#  'surface_temperature_celcius': 71.0}
# {'latitude': -37.4229,
#  'longitude': -37.4229,
#  'surface_temperature_celcius': 99.0}
# {'latitude': -37.0055,
#  'longitude': -37.0055,
#  'surface_temperature_celcius': 68.0}
# {'latitude': -37.4128,
#  'longitude': -37.4128,
#  'surface_temperature_celcius': 98.0}
# {'latitude': -34.357, 'longitude': -34.357, 'surface_temperature_celcius': 67.0}
# {'latitude': -34.3539,
#  'longitude': -34.3539,
#  'surface_temperature_celcius': 72.0}
# {'latitude': -36.9939,
#  'longitude': -36.9939,
#  'surface_temperature_celcius': 68.0}
# {'latitude': -36.9959,
#  'longitude': -36.9959,
#  'surface_temperature_celcius': 75.0}
# {'latitude': -34.3654,
#  'longitude': -34.3654,
#  'surface_temperature_celcius': 65.0}
# {'latitude': -34.3554,
#  'longitude': -34.3554,
#  'surface_temperature_celcius': 79.0}
# {'latitude': -34.3555,
#  'longitude': -34.3555,
#  'surface_temperature_celcius': 75.0}
# {'latitude': -36.7152,
#  'longitude': -36.7152,
#  'surface_temperature_celcius': 74.0}
# {'latitude': -37.0155,
#  'longitude': -37.0155,
#  'surface_temperature_celcius': 80.0}
# {'latitude': -37.6622,
#  'longitude': -37.6622,
#  'surface_temperature_celcius': 79.0}
# {'latitude': -37.4523,
#  'longitude': -37.4523,
#  'surface_temperature_celcius': 66.0}
# {'latitude': -37.4261,
#  'longitude': -37.4261,
#  'surface_temperature_celcius': 83.0}
# {'latitude': -37.3949,
#  'longitude': -37.3949,
#  'surface_temperature_celcius': 91.0}
# {'latitude': -37.6625,
#  'longitude': -37.6625,
#  'surface_temperature_celcius': 70.0}
# {'latitude': -37.8973,
#  'longitude': -37.8973,
#  'surface_temperature_celcius': 65.0}
# {'latitude': -37.7805,
#  'longitude': -37.7805,
#  'surface_temperature_celcius': 75.0}
# {'latitude': -37.8774,
#  'longitude': -37.8774,
#  'surface_temperature_celcius': 77.0}
# {'latitude': -37.8881,
#  'longitude': -37.8881,
#  'surface_temperature_celcius': 99.0}
# {'latitude': -37.522, 'longitude': -37.522, 'surface_temperature_celcius': 73.0}
# {'latitude': -38.0674,
#  'longitude': -38.0674,
#  'surface_temperature_celcius': 68.0}
# {'latitude': -38.0715,
#  'longitude': -38.0715,
#  'surface_temperature_celcius': 70.0}
# {'latitude': -38.0693,
#  'longitude': -38.0693,
#  'surface_temperature_celcius': 89.0}
# {'latitude': -36.4557,
#  'longitude': -36.4557,
#  'surface_temperature_celcius': 71.0}
# {'latitude': -36.8009,
#  'longitude': -36.8009,
#  'surface_temperature_celcius': 76.0}
# {'latitude': -36.8099,
#  'longitude': -36.8099,
#  'surface_temperature_celcius': 73.0}
# {'latitude': -36.7806,
#  'longitude': -36.7806,
#  'surface_temperature_celcius': 74.0}
# {'latitude': -34.3526,
#  'longitude': -34.3526,
#  'surface_temperature_celcius': 82.0}
# {'latitude': -37.0924,
#  'longitude': -37.0924,
#  'surface_temperature_celcius': 80.0}
# {'latitude': -37.9452,
#  'longitude': -37.9452,
#  'surface_temperature_celcius': 80.0}
# {'latitude': -34.351, 'longitude': -34.351, 'surface_temperature_celcius': 86.0}
# {'latitude': -37.5012,
#  'longitude': -37.5012,
#  'surface_temperature_celcius': 90.0}
# {'latitude': -37.9247,
#  'longitude': -37.9247,
#  'surface_temperature_celcius': 81.0}
# {'latitude': -35.0805,
#  'longitude': -35.0805,
#  'surface_temperature_celcius': 81.0}
# {'latitude': -37.3735,
#  'longitude': -37.3735,
#  'surface_temperature_celcius': 96.0}
# {'latitude': -37.7465,
#  'longitude': -37.7465,
#  'surface_temperature_celcius': 72.0}
# {'latitude': -37.8072,
#  'longitude': -37.8072,
#  'surface_temperature_celcius': 77.0}
# {'latitude': -37.3704,
#  'longitude': -37.3704,
#  'surface_temperature_celcius': 78.0}
# {'latitude': -37.297, 'longitude': -37.297, 'surface_temperature_celcius': 93.0}
# {'latitude': -37.2988,
#  'longitude': -37.2988,
#  'surface_temperature_celcius': 90.0}
# {'latitude': -37.3025,
#  'longitude': -37.3025,
#  'surface_temperature_celcius': 98.0}
# {'latitude': -37.383, 'longitude': -37.383, 'surface_temperature_celcius': 89.0}
# {'latitude': -37.7446,
#  'longitude': -37.7446,
#  'surface_temperature_celcius': 66.0}
# {'latitude': -37.7509,
#  'longitude': -37.7509,
#  'surface_temperature_celcius': 82.0}
# {'latitude': -37.7974,
#  'longitude': -37.7974,
#  'surface_temperature_celcius': 97.0}
# {'latitude': -35.7657,
#  'longitude': -35.7657,
#  'surface_temperature_celcius': 66.0}
# {'latitude': -37.7236,
#  'longitude': -37.7236,
#  'surface_temperature_celcius': 86.0}
# {'latitude': -37.3046,
#  'longitude': -37.3046,
#  'surface_temperature_celcius': 72.0}
# {'latitude': -36.4312,
#  'longitude': -36.4312,
#  'surface_temperature_celcius': 76.0}
# {'latitude': -36.1556,
#  'longitude': -36.1556,
#  'surface_temperature_celcius': 65.0}
# {'latitude': -35.7647,
#  'longitude': -35.7647,
#  'surface_temperature_celcius': 65.0}
# {'latitude': -35.4033,
#  'longitude': -35.4033,
#  'surface_temperature_celcius': 67.0}
# {'latitude': -36.6281,
#  'longitude': -36.6281,
#  'surface_temperature_celcius': 68.0}
# {'latitude': -36.111, 'longitude': -36.111, 'surface_temperature_celcius': 66.0}
# {'latitude': -36.1615,
#  'longitude': -36.1615,
#  'surface_temperature_celcius': 66.0}
# {'latitude': -36.1122,
#  'longitude': -36.1122,
#  'surface_temperature_celcius': 76.0}
# {'latitude': -37.3735,
#  'longitude': -37.3735,
#  'surface_temperature_celcius': 95.0}
# {'latitude': -35.4255,
#  'longitude': -35.4255,
#  'surface_temperature_celcius': 65.0}
# {'latitude': -36.1955,
#  'longitude': -36.1955,
#  'surface_temperature_celcius': 78.0}
# {'latitude': -35.4533,
#  'longitude': -35.4533,
#  'surface_temperature_celcius': 66.0}
# {'latitude': -36.5989,
#  'longitude': -36.5989,
#  'surface_temperature_celcius': 81.0}
# {'latitude': -36.6299,
#  'longitude': -36.6299,
#  'surface_temperature_celcius': 71.0}
# {'latitude': -36.1925,
#  'longitude': -36.1925,
#  'surface_temperature_celcius': 79.0}
# {'latitude': -36.095, 'longitude': -36.095, 'surface_temperature_celcius': 82.0}
# {'latitude': -36.6006,
#  'longitude': -36.6006,
#  'surface_temperature_celcius': 78.0}
# {'latitude': -37.0769,
#  'longitude': -37.0769,
#  'surface_temperature_celcius': 72.0}
# {'latitude': -36.883, 'longitude': -36.883, 'surface_temperature_celcius': 67.0}
# {'latitude': -36.0973,
#  'longitude': -36.0973,
#  'surface_temperature_celcius': 92.0}
# {'latitude': -36.1819,
#  'longitude': -36.1819,
#  'surface_temperature_celcius': 98.0}
# {'latitude': -37.6387,
#  'longitude': -37.6387,
#  'surface_temperature_celcius': 88.0}
# {'latitude': -37.6439,
#  'longitude': -37.6439,
#  'surface_temperature_celcius': 83.0}
# {'latitude': -37.3165,
#  'longitude': -37.3165,
#  'surface_temperature_celcius': 72.0}
# {'latitude': -37.3158,
#  'longitude': -37.3158,
#  'surface_temperature_celcius': 76.0}
# {'latitude': -37.4471,
#  'longitude': -37.4471,
#  'surface_temperature_celcius': 65.0}
# {'latitude': -37.7835,
#  'longitude': -37.7835,
#  'surface_temperature_celcius': 66.0}
# {'latitude': -37.4449,
#  'longitude': -37.4449,
#  'surface_temperature_celcius': 65.0}
# {'latitude': -37.4323,
#  'longitude': -37.4323,
#  'surface_temperature_celcius': 76.0}
# {'latitude': -37.4343,
#  'longitude': -37.4343,
#  'surface_temperature_celcius': 92.0}
# {'latitude': -37.5816,
#  'longitude': -37.5816,
#  'surface_temperature_celcius': 65.0}
# {'latitude': -36.6334,
#  'longitude': -36.6334,
#  'surface_temperature_celcius': 69.0}
# {'latitude': -37.7966,
#  'longitude': -37.7966,
#  'surface_temperature_celcius': 66.0}
# {'latitude': -35.805, 'longitude': -35.805, 'surface_temperature_celcius': 95.0}
# {'latitude': -37.8429,
#  'longitude': -37.8429,
#  'surface_temperature_celcius': 88.0}
# {'latitude': -37.8062,
#  'longitude': -37.8062,
#  'surface_temperature_celcius': 65.0}
# {'latitude': -36.9918,
#  'longitude': -36.9918,
#  'surface_temperature_celcius': 97.0}
# {'latitude': -36.1104,
#  'longitude': -36.1104,
#  'surface_temperature_celcius': 76.0}
# {'latitude': -37.782, 'longitude': -37.782, 'surface_temperature_celcius': 99.0}
# {'latitude': -36.9902,
#  'longitude': -36.9902,
#  'surface_temperature_celcius': 65.0}
# {'latitude': -37.745, 'longitude': -37.745, 'surface_temperature_celcius': 65.0}
# {'latitude': -36.0157,
#  'longitude': -36.0157,
#  'surface_temperature_celcius': 70.0}
# {'latitude': -37.777, 'longitude': -37.777, 'surface_temperature_celcius': 85.0}
# {'latitude': -37.5888,
#  'longitude': -37.5888,
#  'surface_temperature_celcius': 72.0}
# {'latitude': -34.3943,
#  'longitude': -34.3943,
#  'surface_temperature_celcius': 65.0}
# {'latitude': -36.0844,
#  'longitude': -36.0844,
#  'surface_temperature_celcius': 71.0}
# {'latitude': -36.031, 'longitude': -36.031, 'surface_temperature_celcius': 69.0}
# {'latitude': -37.5814,
#  'longitude': -37.5814,
#  'surface_temperature_celcius': 68.0}
# {'latitude': -37.5788,
#  'longitude': -37.5788,
#  'surface_temperature_celcius': 67.0}
# {'latitude': -36.6384,
#  'longitude': -36.6384,
#  'surface_temperature_celcius': 66.0}
# {'latitude': -35.811, 'longitude': -35.811, 'surface_temperature_celcius': 96.0}
# {'latitude': -36.9034,
#  'longitude': -36.9034,
#  'surface_temperature_celcius': 95.0}
# {'latitude': -37.7746,
#  'longitude': -37.7746,
#  'surface_temperature_celcius': 65.0}
# {'latitude': -37.803, 'longitude': -37.803, 'surface_temperature_celcius': 78.0}
# {'latitude': -37.7542,
#  'longitude': -37.7542,
#  'surface_temperature_celcius': 77.0}
# {'latitude': -37.3803,
#  'longitude': -37.3803,
#  'surface_temperature_celcius': 68.0}
# {'latitude': -37.7617,
#  'longitude': -37.7617,
#  'surface_temperature_celcius': 81.0}
# {'latitude': -37.8161,
#  'longitude': -37.8161,
#  'surface_temperature_celcius': 71.0}
# {'latitude': -36.0387,
#  'longitude': -36.0387,
#  'surface_temperature_celcius': 67.0}
# {'latitude': -36.6349,
#  'longitude': -36.6349,
#  'surface_temperature_celcius': 86.0}
# {'latitude': -36.9018,
#  'longitude': -36.9018,
#  'surface_temperature_celcius': 100.0}
# {'latitude': -36.6986,
#  'longitude': -36.6986,
#  'surface_temperature_celcius': 72.0}
# {'latitude': -38.0052,
#  'longitude': -38.0052,
#  'surface_temperature_celcius': 89.0}
# {'latitude': -37.2168,
#  'longitude': -37.2168,
#  'surface_temperature_celcius': 89.0}
# {'latitude': -37.222, 'longitude': -37.222, 'surface_temperature_celcius': 78.0}
# {'latitude': -37.2063,
#  'longitude': -37.2063,
#  'surface_temperature_celcius': 70.0}
# {'latitude': -37.2082,
#  'longitude': -37.2082,
#  'surface_temperature_celcius': 70.0}
# {'latitude': -37.224, 'longitude': -37.224, 'surface_temperature_celcius': 76.0}
# {'latitude': -37.34, 'longitude': -37.34, 'surface_temperature_celcius': 74.0}
# {'latitude': -36.7287,
#  'longitude': -36.7287,
#  'surface_temperature_celcius': 85.0}
# {'latitude': -35.2363,
#  'longitude': -35.2363,
#  'surface_temperature_celcius': 69.0}
# {'latitude': -35.2378,
#  'longitude': -35.2378,
#  'surface_temperature_celcius': 94.0}
# {'latitude': -35.2381,
#  'longitude': -35.2381,
#  'surface_temperature_celcius': 83.0}
# {'latitude': -37.3493,
#  'longitude': -37.3493,
#  'surface_temperature_celcius': 80.0}
# {'latitude': -36.7165,
#  'longitude': -36.7165,
#  'surface_temperature_celcius': 66.0}
# {'latitude': -37.5812,
#  'longitude': -37.5812,
#  'surface_temperature_celcius': 75.0}
# {'latitude': -37.5949,
#  'longitude': -37.5949,
#  'surface_temperature_celcius': 98.0}
# {'latitude': -37.8247,
#  'longitude': -37.8247,
#  'surface_temperature_celcius': 77.0}
# {'latitude': -37.4028,
#  'longitude': -37.4028,
#  'surface_temperature_celcius': 75.0}
# {'latitude': -37.4033,
#  'longitude': -37.4033,
#  'surface_temperature_celcius': 70.0}
# {'latitude': -37.8249,
#  'longitude': -37.8249,
#  'surface_temperature_celcius': 98.0}
# {'latitude': -36.6823,
#  'longitude': -36.6823,
#  'surface_temperature_celcius': 71.0}
# {'latitude': -36.4489,
#  'longitude': -36.4489,
#  'surface_temperature_celcius': 73.0}
# {'latitude': -36.9498,
#  'longitude': -36.9498,
#  'surface_temperature_celcius': 78.0}
# {'latitude': -36.1941,
#  'longitude': -36.1941,
#  'surface_temperature_celcius': 72.0}
# {'latitude': -36.4142,
#  'longitude': -36.4142,
#  'surface_temperature_celcius': 97.0}
# {'latitude': -36.1924,
#  'longitude': -36.1924,
#  'surface_temperature_celcius': 70.0}
# {'latitude': -36.0295,
#  'longitude': -36.0295,
#  'surface_temperature_celcius': 65.0}
# {'latitude': -37.0761,
#  'longitude': -37.0761,
#  'surface_temperature_celcius': 89.0}
# {'latitude': -35.0616,
#  'longitude': -35.0616,
#  'surface_temperature_celcius': 73.0}
# {'latitude': -36.3999,
#  'longitude': -36.3999,
#  'surface_temperature_celcius': 88.0}
# {'latitude': -36.1748,
#  'longitude': -36.1748,
#  'surface_temperature_celcius': 69.0}
# {'latitude': -36.0691,
#  'longitude': -36.0691,
#  'surface_temperature_celcius': 85.0}
# {'latitude': -35.1949,
#  'longitude': -35.1949,
#  'surface_temperature_celcius': 66.0}
# {'latitude': -36.91, 'longitude': -36.91, 'surface_temperature_celcius': 96.0}
# {'latitude': -35.8071,
#  'longitude': -35.8071,
#  'surface_temperature_celcius': 66.0}
# {'latitude': -36.7787,
#  'longitude': -36.7787,
#  'surface_temperature_celcius': 80.0}
# {'latitude': -36.2948,
#  'longitude': -36.2948,
#  'surface_temperature_celcius': 82.0}
# {'latitude': -38.1561,
#  'longitude': -38.1561,
#  'surface_temperature_celcius': 65.0}
# {'latitude': -37.8185,
#  'longitude': -37.8185,
#  'surface_temperature_celcius': 66.0}
# {'latitude': -36.1771,
#  'longitude': -36.1771,
#  'surface_temperature_celcius': 93.0}
# {'latitude': -38.027, 'longitude': -38.027, 'surface_temperature_celcius': 95.0}
# {'latitude': -35.7642,
#  'longitude': -35.7642,
#  'surface_temperature_celcius': 65.0}
# {'latitude': -36.429, 'longitude': -36.429, 'surface_temperature_celcius': 67.0}
# {'latitude': -36.1346,
#  'longitude': -36.1346,
#  'surface_temperature_celcius': 71.0}
# {'latitude': -37.0899,
#  'longitude': -37.0899,
#  'surface_temperature_celcius': 90.0}
# {'latitude': -36.3823,
#  'longitude': -36.3823,
#  'surface_temperature_celcius': 77.0}
# {'latitude': -36.1462,
#  'longitude': -36.1462,
#  'surface_temperature_celcius': 66.0}
# {'latitude': -36.5243,
#  'longitude': -36.5243,
#  'surface_temperature_celcius': 72.0}
# {'latitude': -37.618, 'longitude': -37.618, 'surface_temperature_celcius': 82.0}
# {'latitude': -36.8867,
#  'longitude': -36.8867,
#  'surface_temperature_celcius': 66.0}
# {'latitude': -36.9364,
#  'longitude': -36.9364,
#  'surface_temperature_celcius': 70.0}
# {'latitude': -37.3847,
#  'longitude': -37.3847,
#  'surface_temperature_celcius': 88.0}
# {'latitude': -35.6374,
#  'longitude': -35.6374,
#  'surface_temperature_celcius': 95.0}
# {'latitude': -36.8835,
#  'longitude': -36.8835,
#  'surface_temperature_celcius': 67.0}
# {'latitude': -36.4125,
#  'longitude': -36.4125,
#  'surface_temperature_celcius': 92.0}
# {'latitude': -37.0669,
#  'longitude': -37.0669,
#  'surface_temperature_celcius': 80.0}
# {'latitude': -36.0714,
#  'longitude': -36.0714,
#  'surface_temperature_celcius': 71.0}
# {'latitude': -36.2933,
#  'longitude': -36.2933,
#  'surface_temperature_celcius': 75.0}
# {'latitude': -37.4591,
#  'longitude': -37.4591,
#  'surface_temperature_celcius': 89.0}
# {'latitude': -36.3487,
#  'longitude': -36.3487,
#  'surface_temperature_celcius': 68.0}
# {'latitude': -36.5399,
#  'longitude': -36.5399,
#  'surface_temperature_celcius': 66.0}
# {'latitude': -36.8158,
#  'longitude': -36.8158,
#  'surface_temperature_celcius': 80.0}
# {'latitude': -36.4518,
#  'longitude': -36.4518,
#  'surface_temperature_celcius': 97.0}
# {'latitude': -36.7903,
#  'longitude': -36.7903,
#  'surface_temperature_celcius': 67.0}
# {'latitude': -36.1067,
#  'longitude': -36.1067,
#  'surface_temperature_celcius': 79.0}
# {'latitude': -36.1441,
#  'longitude': -36.1441,
#  'surface_temperature_celcius': 65.0}
# {'latitude': -36.4816,
#  'longitude': -36.4816,
#  'surface_temperature_celcius': 75.0}
# {'latitude': -36.0837,
#  'longitude': -36.0837,
#  'surface_temperature_celcius': 87.0}
# {'latitude': -36.782, 'longitude': -36.782, 'surface_temperature_celcius': 67.0}
# {'latitude': -36.5586,
#  'longitude': -36.5586,
#  'surface_temperature_celcius': 71.0}
# {'latitude': -36.5568,
#  'longitude': -36.5568,
#  'surface_temperature_celcius': 68.0}
# {'latitude': -36.4538,
#  'longitude': -36.4538,
#  'surface_temperature_celcius': 81.0}
# {'latitude': -36.4612,
#  'longitude': -36.4612,
#  'surface_temperature_celcius': 80.0}
# {'latitude': -36.7089,
#  'longitude': -36.7089,
#  'surface_temperature_celcius': 93.0}
# {'latitude': -36.601, 'longitude': -36.601, 'surface_temperature_celcius': 80.0}
# {'latitude': -36.8681,
#  'longitude': -36.8681,
#  'surface_temperature_celcius': 76.0}
# {'latitude': -37.1999,
#  'longitude': -37.1999,
#  'surface_temperature_celcius': 90.0}
# {'latitude': -37.6171,
#  'longitude': -37.6171,
#  'surface_temperature_celcius': 68.0}
# {'latitude': -37.7587,
#  'longitude': -37.7587,
#  'surface_temperature_celcius': 80.0}
# {'latitude': -37.4611,
#  'longitude': -37.4611,
#  'surface_temperature_celcius': 69.0}
# {'latitude': -38.0254,
#  'longitude': -38.0254,
#  'surface_temperature_celcius': 99.0}
# {'latitude': -37.88, 'longitude': -37.88, 'surface_temperature_celcius': 65.0}
# {'latitude': -37.8885,
#  'longitude': -37.8885,
#  'surface_temperature_celcius': 85.0}
# {'latitude': -35.0706,
#  'longitude': -35.0706,
#  'surface_temperature_celcius': 75.0}
# {'latitude': -38.0795,
#  'longitude': -38.0795,
#  'surface_temperature_celcius': 91.0}
# {'latitude': -35.1857,
#  'longitude': -35.1857,
#  'surface_temperature_celcius': 92.0}
# {'latitude': -35.6469,
#  'longitude': -35.6469,
#  'surface_temperature_celcius': 93.0}
# {'latitude': -35.6453,
#  'longitude': -35.6453,
#  'surface_temperature_celcius': 69.0}
# {'latitude': -36.4409,
#  'longitude': -36.4409,
#  'surface_temperature_celcius': 92.0}
# {'latitude': -37.9174,
#  'longitude': -37.9174,
#  'surface_temperature_celcius': 93.0}
# {'latitude': -37.9152,
#  'longitude': -37.9152,
#  'surface_temperature_celcius': 77.0}
# {'latitude': -37.8906,
#  'longitude': -37.8906,
#  'surface_temperature_celcius': 75.0}
# {'latitude': -35.8182,
#  'longitude': -35.8182,
#  'surface_temperature_celcius': 92.0}
# {'latitude': -37.9246,
#  'longitude': -37.9246,
#  'surface_temperature_celcius': 96.0}
# {'latitude': -36.3313,
#  'longitude': -36.3313,
#  'surface_temperature_celcius': 73.0}
# {'latitude': -36.2857,
#  'longitude': -36.2857,
#  'surface_temperature_celcius': 67.0}
# {'latitude': -36.0749,
#  'longitude': -36.0749,
#  'surface_temperature_celcius': 70.0}
# {'latitude': -36.4449,
#  'longitude': -36.4449,
#  'surface_temperature_celcius': 68.0}
# {'latitude': -36.3972,
#  'longitude': -36.3972,
#  'surface_temperature_celcius': 90.0}
# {'latitude': -36.5532,
#  'longitude': -36.5532,
#  'surface_temperature_celcius': 67.0}
# {'latitude': -36.1367,
#  'longitude': -36.1367,
#  'surface_temperature_celcius': 71.0}
# {'latitude': -36.1518,
#  'longitude': -36.1518,
#  'surface_temperature_celcius': 79.0}
# {'latitude': -36.1418,
#  'longitude': -36.1418,
#  'surface_temperature_celcius': 76.0}
# {'latitude': -36.7499,
#  'longitude': -36.7499,
#  'surface_temperature_celcius': 99.0}
# {'latitude': -36.7432,
#  'longitude': -36.7432,
#  'surface_temperature_celcius': 79.0}
# {'latitude': -36.7531,
#  'longitude': -36.7531,
#  'surface_temperature_celcius': 78.0}
# {'latitude': -36.7943,
#  'longitude': -36.7943,
#  'surface_temperature_celcius': 84.0}
# {'latitude': -36.7957,
#  'longitude': -36.7957,
#  'surface_temperature_celcius': 87.0}
# {'latitude': -36.9329,
#  'longitude': -36.9329,
#  'surface_temperature_celcius': 82.0}
# {'latitude': -35.8276,
#  'longitude': -35.8276,
#  'surface_temperature_celcius': 85.0}
# {'latitude': -35.9326,
#  'longitude': -35.9326,
#  'surface_temperature_celcius': 66.0}
# {'latitude': -36.6892,
#  'longitude': -36.6892,
#  'surface_temperature_celcius': 69.0}
# {'latitude': -36.73, 'longitude': -36.73, 'surface_temperature_celcius': 65.0}
# {'latitude': -36.8283,
#  'longitude': -36.8283,
#  'surface_temperature_celcius': 93.0}
# {'latitude': -36.6527,
#  'longitude': -36.6527,
#  'surface_temperature_celcius': 81.0}
# {'latitude': -36.1898,
#  'longitude': -36.1898,
#  'surface_temperature_celcius': 78.0}
# {'latitude': -36.8298,
#  'longitude': -36.8298,
#  'surface_temperature_celcius': 79.0}
# {'latitude': -36.6615,
#  'longitude': -36.6615,
#  'surface_temperature_celcius': 90.0}
# {'latitude': -36.8238,
#  'longitude': -36.8238,
#  'surface_temperature_celcius': 73.0}
# {'latitude': -36.1988,
#  'longitude': -36.1988,
#  'surface_temperature_celcius': 100.0}
# {'latitude': -36.7651,
#  'longitude': -36.7651,
#  'surface_temperature_celcius': 68.0}
# {'latitude': -36.5199,
#  'longitude': -36.5199,
#  'surface_temperature_celcius': 77.0}
# {'latitude': -37.0782,
#  'longitude': -37.0782,
#  'surface_temperature_celcius': 68.0}
# {'latitude': -36.3966,
#  'longitude': -36.3966,
#  'surface_temperature_celcius': 74.0}
# {'latitude': -37.1349,
#  'longitude': -37.1349,
#  'surface_temperature_celcius': 67.0}
# {'latitude': -37.6397,
#  'longitude': -37.6397,
#  'surface_temperature_celcius': 68.0}
# {'latitude': -37.6267,
#  'longitude': -37.6267,
#  'surface_temperature_celcius': 66.0}
# {'latitude': -36.5871,
#  'longitude': -36.5871,
#  'surface_temperature_celcius': 72.0}
# {'latitude': -36.2618,
#  'longitude': -36.2618,
#  'surface_temperature_celcius': 65.0}
# {'latitude': -36.6828,
#  'longitude': -36.6828,
#  'surface_temperature_celcius': 66.0}
# {'latitude': -37.4843,
#  'longitude': -37.4843,
#  'surface_temperature_celcius': 66.0}
# {'latitude': -37.7274,
#  'longitude': -37.7274,
#  'surface_temperature_celcius': 73.0}
# {'latitude': -37.6964,
#  'longitude': -37.6964,
#  'surface_temperature_celcius': 69.0}
# {'latitude': -38.0509,
#  'longitude': -38.0509,
#  'surface_temperature_celcius': 82.0}
# {'latitude': -37.9284,
#  'longitude': -37.9284,
#  'surface_temperature_celcius': 70.0}
# {'latitude': -37.5701,
#  'longitude': -37.5701,
#  'surface_temperature_celcius': 94.0}
# {'latitude': -36.7101,
#  'longitude': -36.7101,
#  'surface_temperature_celcius': 67.0}
# {'latitude': -38.1693,
#  'longitude': -38.1693,
#  'surface_temperature_celcius': 73.0}
# {'latitude': -36.7128,
#  'longitude': -36.7128,
#  'surface_temperature_celcius': 77.0}
# {'latitude': -37.4885,
#  'longitude': -37.4885,
#  'surface_temperature_celcius': 81.0}
# {'latitude': -36.7101,
#  'longitude': -36.7101,
#  'surface_temperature_celcius': 68.0}
# {'latitude': -37.0959,
#  'longitude': -37.0959,
#  'surface_temperature_celcius': 65.0}
# {'latitude': -37.9594,
#  'longitude': -37.9594,
#  'surface_temperature_celcius': 87.0}
# {'latitude': -36.5921,
#  'longitude': -36.5921,
#  'surface_temperature_celcius': 82.0}
# {'latitude': -36.6787,
#  'longitude': -36.6787,
#  'surface_temperature_celcius': 79.0}
# {'latitude': -38.0423,
#  'longitude': -38.0423,
#  'surface_temperature_celcius': 66.0}
# {'latitude': -38.1224,
#  'longitude': -38.1224,
#  'surface_temperature_celcius': 73.0}
# {'latitude': -38.0792,
#  'longitude': -38.0792,
#  'surface_temperature_celcius': 93.0}
# {'latitude': -37.9157,
#  'longitude': -37.9157,
#  'surface_temperature_celcius': 72.0}
# {'latitude': -37.7935,
#  'longitude': -37.7935,
#  'surface_temperature_celcius': 78.0}
# {'latitude': -37.7756,
#  'longitude': -37.7756,
#  'surface_temperature_celcius': 67.0}
# {'latitude': -37.7171,
#  'longitude': -37.7171,
#  'surface_temperature_celcius': 68.0}
# {'latitude': -37.7236,
#  'longitude': -37.7236,
#  'surface_temperature_celcius': 73.0}
# {'latitude': -37.7002,
#  'longitude': -37.7002,
#  'surface_temperature_celcius': 89.0}
# {'latitude': -37.6498,
#  'longitude': -37.6498,
#  'surface_temperature_celcius': 70.0}
# {'latitude': -37.5728,
#  'longitude': -37.5728,
#  'surface_temperature_celcius': 98.0}
# {'latitude': -37.4352,
#  'longitude': -37.4352,
#  'surface_temperature_celcius': 96.0}
# {'latitude': -36.5828,
#  'longitude': -36.5828,
#  'surface_temperature_celcius': 70.0}
# {'latitude': -36.5987,
#  'longitude': -36.5987,
#  'surface_temperature_celcius': 79.0}
# {'latitude': -36.5262,
#  'longitude': -36.5262,
#  'surface_temperature_celcius': 84.0}
# {'latitude': -36.6995,
#  'longitude': -36.6995,
#  'surface_temperature_celcius': 76.0}
# {'latitude': -36.8879,
#  'longitude': -36.8879,
#  'surface_temperature_celcius': 72.0}
# {'latitude': -35.8768,
#  'longitude': -35.8768,
#  'surface_temperature_celcius': 86.0}
# {'latitude': -36.4899,
#  'longitude': -36.4899,
#  'surface_temperature_celcius': 73.0}
# {'latitude': -36.663, 'longitude': -36.663, 'surface_temperature_celcius': 72.0}
# {'latitude': -36.092, 'longitude': -36.092, 'surface_temperature_celcius': 75.0}
# {'latitude': -34.9023,
#  'longitude': -34.9023,
#  'surface_temperature_celcius': 65.0}
# {'latitude': -36.2637,
#  'longitude': -36.2637,
#  'surface_temperature_celcius': 69.0}
# {'latitude': -37.2609,
#  'longitude': -37.2609,
#  'surface_temperature_celcius': 66.0}
# {'latitude': -36.91, 'longitude': -36.91, 'surface_temperature_celcius': 73.0}
# {'latitude': -36.2652,
#  'longitude': -36.2652,
#  'surface_temperature_celcius': 70.0}
# {'latitude': -36.738, 'longitude': -36.738, 'surface_temperature_celcius': 77.0}
# {'latitude': -37.876, 'longitude': -37.876, 'surface_temperature_celcius': 65.0}
# {'latitude': -36.1546,
#  'longitude': -36.1546,
#  'surface_temperature_celcius': 74.0}
# {'latitude': -37.9091,
#  'longitude': -37.9091,
#  'surface_temperature_celcius': 70.0}
# {'latitude': -36.1559,
#  'longitude': -36.1559,
#  'surface_temperature_celcius': 66.0}
# {'latitude': -37.9071,
#  'longitude': -37.9071,
#  'surface_temperature_celcius': 88.0}
# {'latitude': -37.3902,
#  'longitude': -37.3902,
#  'surface_temperature_celcius': 98.0}
# {'latitude': -37.5027,
#  'longitude': -37.5027,
#  'surface_temperature_celcius': 95.0}
# {'latitude': -37.5043,
#  'longitude': -37.5043,
#  'surface_temperature_celcius': 93.0}
# {'latitude': -36.1964,
#  'longitude': -36.1964,
#  'surface_temperature_celcius': 72.0}
# {'latitude': -37.769, 'longitude': -37.769, 'surface_temperature_celcius': 72.0}
# {'latitude': -36.1303,
#  'longitude': -36.1303,
#  'surface_temperature_celcius': 67.0}
# {'latitude': -36.1345,
#  'longitude': -36.1345,
#  'surface_temperature_celcius': 84.0}
# {'latitude': -36.1586,
#  'longitude': -36.1586,
#  'surface_temperature_celcius': 85.0}
# {'latitude': -36.5847,
#  'longitude': -36.5847,
#  'surface_temperature_celcius': 78.0}
# {'latitude': -36.9111,
#  'longitude': -36.9111,
#  'surface_temperature_celcius': 72.0}
# {'latitude': -37.5115,
#  'longitude': -37.5115,
#  'surface_temperature_celcius': 86.0}
# {'latitude': -37.6775,
#  'longitude': -37.6775,
#  'surface_temperature_celcius': 78.0}
# {'latitude': -36.3332,
#  'longitude': -36.3332,
#  'surface_temperature_celcius': 90.0}
# {'latitude': -36.9303,
#  'longitude': -36.9303,
#  'surface_temperature_celcius': 72.0}
# {'latitude': -36.3195,
#  'longitude': -36.3195,
#  'surface_temperature_celcius': 77.0}
# {'latitude': -36.5839,
#  'longitude': -36.5839,
#  'surface_temperature_celcius': 99.0}
# {'latitude': -36.5854,
#  'longitude': -36.5854,
#  'surface_temperature_celcius': 94.0}
# {'latitude': -36.3014,
#  'longitude': -36.3014,
#  'surface_temperature_celcius': 76.0}
# {'latitude': -38.1917,
#  'longitude': -38.1917,
#  'surface_temperature_celcius': 94.0}
# {'latitude': -38.1987,
#  'longitude': -38.1987,
#  'surface_temperature_celcius': 76.0}
# {'latitude': -36.5454,
#  'longitude': -36.5454,
#  'surface_temperature_celcius': 96.0}
# {'latitude': -36.7593,
#  'longitude': -36.7593,
#  'surface_temperature_celcius': 69.0}
# {'latitude': -36.3435,
#  'longitude': -36.3435,
#  'surface_temperature_celcius': 67.0}
# {'latitude': -36.6942,
#  'longitude': -36.6942,
#  'surface_temperature_celcius': 72.0}
# {'latitude': -36.3459,
#  'longitude': -36.3459,
#  'surface_temperature_celcius': 91.0}
# {'latitude': -36.4046,
#  'longitude': -36.4046,
#  'surface_temperature_celcius': 73.0}
# {'latitude': -36.0594,
#  'longitude': -36.0594,
#  'surface_temperature_celcius': 79.0}
# {'latitude': -36.0576,
#  'longitude': -36.0576,
#  'surface_temperature_celcius': 94.0}
# {'latitude': -36.388, 'longitude': -36.388, 'surface_temperature_celcius': 73.0}
# {'latitude': -36.094, 'longitude': -36.094, 'surface_temperature_celcius': 67.0}
# {'latitude': -36.5438,
#  'longitude': -36.5438,
#  'surface_temperature_celcius': 84.0}
# {'latitude': -36.6537,
#  'longitude': -36.6537,
#  'surface_temperature_celcius': 76.0}
# {'latitude': -36.663, 'longitude': -36.663, 'surface_temperature_celcius': 71.0}
# {'latitude': -37.6982,
#  'longitude': -37.6982,
#  'surface_temperature_celcius': 73.0}
# {'latitude': -36.7187,
#  'longitude': -36.7187,
#  'surface_temperature_celcius': 76.0}
# {'latitude': -36.7742,
#  'longitude': -36.7742,
#  'surface_temperature_celcius': 89.0}
# {'latitude': -36.5061,
#  'longitude': -36.5061,
#  'surface_temperature_celcius': 68.0}
# {'latitude': -36.4035,
#  'longitude': -36.4035,
#  'surface_temperature_celcius': 95.0}
# {'latitude': -36.4286,
#  'longitude': -36.4286,
#  'surface_temperature_celcius': 84.0}
# {'latitude': -36.3635,
#  'longitude': -36.3635,
#  'surface_temperature_celcius': 68.0}
# {'latitude': -36.664, 'longitude': -36.664, 'surface_temperature_celcius': 87.0}
# {'latitude': -36.6564,
#  'longitude': -36.6564,
#  'surface_temperature_celcius': 69.0}
# {'latitude': -36.6657,
#  'longitude': -36.6657,
#  'surface_temperature_celcius': 72.0}
# {'latitude': -36.8742,
#  'longitude': -36.8742,
#  'surface_temperature_celcius': 84.0}
# {'latitude': -36.7751,
#  'longitude': -36.7751,
#  'surface_temperature_celcius': 68.0}
# {'latitude': -36.3961,
#  'longitude': -36.3961,
#  'surface_temperature_celcius': 69.0}
# {'latitude': -36.7708,
#  'longitude': -36.7708,
#  'surface_temperature_celcius': 98.0}
# {'latitude': -37.758, 'longitude': -37.758, 'surface_temperature_celcius': 82.0}
# {'latitude': -37.7609,
#  'longitude': -37.7609,
#  'surface_temperature_celcius': 74.0}
# {'latitude': -36.5116,
#  'longitude': -36.5116,
#  'surface_temperature_celcius': 66.0}
# {'latitude': -36.803, 'longitude': -36.803, 'surface_temperature_celcius': 70.0}
# {'latitude': -36.4143,
#  'longitude': -36.4143,
#  'surface_temperature_celcius': 65.0}
# {'latitude': -36.7153,
#  'longitude': -36.7153,
#  'surface_temperature_celcius': 86.0}
# {'latitude': -36.8791,
#  'longitude': -36.8791,
#  'surface_temperature_celcius': 93.0}
# {'latitude': -36.7309,
#  'longitude': -36.7309,
#  'surface_temperature_celcius': 88.0}
# {'latitude': -36.882, 'longitude': -36.882, 'surface_temperature_celcius': 70.0}
# {'latitude': -37.5135,
#  'longitude': -37.5135,
#  'surface_temperature_celcius': 72.0}
# {'latitude': -36.2121,
#  'longitude': -36.2121,
#  'surface_temperature_celcius': 74.0}
# {'latitude': -36.2206,
#  'longitude': -36.2206,
#  'surface_temperature_celcius': 80.0}
# {'latitude': -38.0132,
#  'longitude': -38.0132,
#  'surface_temperature_celcius': 73.0}
# {'latitude': -38.0148,
#  'longitude': -38.0148,
#  'surface_temperature_celcius': 71.0}
# {'latitude': -37.8412,
#  'longitude': -37.8412,
#  'surface_temperature_celcius': 87.0}
# {'latitude': -37.8429,
#  'longitude': -37.8429,
#  'surface_temperature_celcius': 78.0}
# {'latitude': -36.6139,
#  'longitude': -36.6139,
#  'surface_temperature_celcius': 77.0}
# {'latitude': -37.9509,
#  'longitude': -37.9509,
#  'surface_temperature_celcius': 76.0}
# {'latitude': -36.6224,
#  'longitude': -36.6224,
#  'surface_temperature_celcius': 80.0}
# {'latitude': -38.0933,
#  'longitude': -38.0933,
#  'surface_temperature_celcius': 78.0}
# {'latitude': -35.6138,
#  'longitude': -35.6138,
#  'surface_temperature_celcius': 68.0}
# {'latitude': -36.0885,
#  'longitude': -36.0885,
#  'surface_temperature_celcius': 76.0}
# {'latitude': -36.3193,
#  'longitude': -36.3193,
#  'surface_temperature_celcius': 78.0}
# {'latitude': -36.0652,
#  'longitude': -36.0652,
#  'surface_temperature_celcius': 82.0}
# {'latitude': -36.0682,
#  'longitude': -36.0682,
#  'surface_temperature_celcius': 90.0}
# {'latitude': -37.7889,
#  'longitude': -37.7889,
#  'surface_temperature_celcius': 71.0}
# {'latitude': -36.2306,
#  'longitude': -36.2306,
#  'surface_temperature_celcius': 72.0}
# {'latitude': -36.4168,
#  'longitude': -36.4168,
#  'surface_temperature_celcius': 68.0}
# {'latitude': -36.4211,
#  'longitude': -36.4211,
#  'surface_temperature_celcius': 81.0}
# {'latitude': -36.8094,
#  'longitude': -36.8094,
#  'surface_temperature_celcius': 77.0}
# {'latitude': -37.8323,
#  'longitude': -37.8323,
#  'surface_temperature_celcius': 68.0}
# {'latitude': -38.2853,
#  'longitude': -38.2853,
#  'surface_temperature_celcius': 83.0}
# {'latitude': -38.2375,
#  'longitude': -38.2375,
#  'surface_temperature_celcius': 82.0}
# {'latitude': -37.4463,
#  'longitude': -37.4463,
#  'surface_temperature_celcius': 70.0}
# {'latitude': -37.6854,
#  'longitude': -37.6854,
#  'surface_temperature_celcius': 76.0}
# {'latitude': -38.0881,
#  'longitude': -38.0881,
#  'surface_temperature_celcius': 84.0}
# {'latitude': -38.0866,
#  'longitude': -38.0866,
#  'surface_temperature_celcius': 78.0}
# {'latitude': -38.2391,
#  'longitude': -38.2391,
#  'surface_temperature_celcius': 71.0}
# {'latitude': -38.5123,
#  'longitude': -38.5123,
#  'surface_temperature_celcius': 89.0}
# {'latitude': -36.3438,
#  'longitude': -36.3438,
#  'surface_temperature_celcius': 78.0}
# {'latitude': -37.4357,
#  'longitude': -37.4357,
#  'surface_temperature_celcius': 74.0}
# {'latitude': -37.5867,
#  'longitude': -37.5867,
#  'surface_temperature_celcius': 85.0}
# {'latitude': -36.2911,
#  'longitude': -36.2911,
#  'surface_temperature_celcius': 67.0}
# {'latitude': -36.2842,
#  'longitude': -36.2842,
#  'surface_temperature_celcius': 79.0}
# {'latitude': -36.7218,
#  'longitude': -36.7218,
#  'surface_temperature_celcius': 65.0}
# {'latitude': -37.3656,
#  'longitude': -37.3656,
#  'surface_temperature_celcius': 78.0}
# {'latitude': -36.4179,
#  'longitude': -36.4179,
#  'surface_temperature_celcius': 75.0}
# {'latitude': -36.3207,
#  'longitude': -36.3207,
#  'surface_temperature_celcius': 70.0}
# {'latitude': -36.2882,
#  'longitude': -36.2882,
#  'surface_temperature_celcius': 86.0}
# {'latitude': -36.3153,
#  'longitude': -36.3153,
#  'surface_temperature_celcius': 69.0}
# {'latitude': -36.4169,
#  'longitude': -36.4169,
#  'surface_temperature_celcius': 81.0}
# {'latitude': -37.4671,
#  'longitude': -37.4671,
#  'surface_temperature_celcius': 73.0}
# {'latitude': -36.3254,
#  'longitude': -36.3254,
#  'surface_temperature_celcius': 77.0}
# {'latitude': -36.0816,
#  'longitude': -36.0816,
#  'surface_temperature_celcius': 98.0}
# {'latitude': -36.1532,
#  'longitude': -36.1532,
#  'surface_temperature_celcius': 90.0}
# {'latitude': -36.0077,
#  'longitude': -36.0077,
#  'surface_temperature_celcius': 93.0}
# {'latitude': -36.0828,
#  'longitude': -36.0828,
#  'surface_temperature_celcius': 75.0}
# {'latitude': -36.5541,
#  'longitude': -36.5541,
#  'surface_temperature_celcius': 69.0}
# {'latitude': -35.6819,
#  'longitude': -35.6819,
#  'surface_temperature_celcius': 69.0}
# {'latitude': -35.6871,
#  'longitude': -35.6871,
#  'surface_temperature_celcius': 68.0}
# {'latitude': -36.1506,
#  'longitude': -36.1506,
#  'surface_temperature_celcius': 95.0}
# {'latitude': -37.4984,
#  'longitude': -37.4984,
#  'surface_temperature_celcius': 73.0}
# {'latitude': -37.253, 'longitude': -37.253, 'surface_temperature_celcius': 78.0}
# {'latitude': -36.9396,
#  'longitude': -36.9396,
#  'surface_temperature_celcius': 70.0}
# {'latitude': -36.3387,
#  'longitude': -36.3387,
#  'surface_temperature_celcius': 77.0}
# {'latitude': -36.3433,
#  'longitude': -36.3433,
#  'surface_temperature_celcius': 94.0}
# {'latitude': -36.345, 'longitude': -36.345, 'surface_temperature_celcius': 87.0}
# {'latitude': -36.7032,
#  'longitude': -36.7032,
#  'surface_temperature_celcius': 66.0}
# {'latitude': -36.3402,
#  'longitude': -36.3402,
#  'surface_temperature_celcius': 77.0}
# {'latitude': -36.5661,
#  'longitude': -36.5661,
#  'surface_temperature_celcius': 65.0}
# {'latitude': -36.5023,
#  'longitude': -36.5023,
#  'surface_temperature_celcius': 66.0}
# {'latitude': -36.8616,
#  'longitude': -36.8616,
#  'surface_temperature_celcius': 78.0}
# {'latitude': -38.0372,
#  'longitude': -38.0372,
#  'surface_temperature_celcius': 67.0}
# {'latitude': -38.049, 'longitude': -38.049, 'surface_temperature_celcius': 74.0}
# {'latitude': -35.4666,
#  'longitude': -35.4666,
#  'surface_temperature_celcius': 65.0}
# {'latitude': -36.0396,
#  'longitude': -36.0396,
#  'surface_temperature_celcius': 76.0}
# {'latitude': -36.2775,
#  'longitude': -36.2775,
#  'surface_temperature_celcius': 74.0}
# {'latitude': -38.0361,
#  'longitude': -38.0361,
#  'surface_temperature_celcius': 90.0}
# {'latitude': -36.7746,
#  'longitude': -36.7746,
#  'surface_temperature_celcius': 68.0}
# {'latitude': -36.8359,
#  'longitude': -36.8359,
#  'surface_temperature_celcius': 78.0}
# {'latitude': -37.9085,
#  'longitude': -37.9085,
#  'surface_temperature_celcius': 82.0}
# {'latitude': -38.4349,
#  'longitude': -38.4349,
#  'surface_temperature_celcius': 93.0}
# {'latitude': -38.4792,
#  'longitude': -38.4792,
#  'surface_temperature_celcius': 65.0}
# {'latitude': -37.9047,
#  'longitude': -37.9047,
#  'surface_temperature_celcius': 90.0}
# {'latitude': -36.7685,
#  'longitude': -36.7685,
#  'surface_temperature_celcius': 69.0}
# {'latitude': -36.7801,
#  'longitude': -36.7801,
#  'surface_temperature_celcius': 68.0}
# {'latitude': -36.1002,
#  'longitude': -36.1002,
#  'surface_temperature_celcius': 78.0}
# {'latitude': -36.4325,
#  'longitude': -36.4325,
#  'surface_temperature_celcius': 67.0}
# {'latitude': -36.2693,
#  'longitude': -36.2693,
#  'surface_temperature_celcius': 85.0}
# {'latitude': -36.3774,
#  'longitude': -36.3774,
#  'surface_temperature_celcius': 68.0}
# {'latitude': -36.3756,
#  'longitude': -36.3756,
#  'surface_temperature_celcius': 88.0}
# {'latitude': -36.369, 'longitude': -36.369, 'surface_temperature_celcius': 80.0}
# {'latitude': -36.3799,
#  'longitude': -36.3799,
#  'surface_temperature_celcius': 89.0}
# {'latitude': -37.8644,
#  'longitude': -37.8644,
#  'surface_temperature_celcius': 69.0}
# {'latitude': -38.3998,
#  'longitude': -38.3998,
#  'surface_temperature_celcius': 65.0}
# {'latitude': -37.4796,
#  'longitude': -37.4796,
#  'surface_temperature_celcius': 87.0}
# {'latitude': -37.379, 'longitude': -37.379, 'surface_temperature_celcius': 82.0}
# {'latitude': -37.379, 'longitude': -37.379, 'surface_temperature_celcius': 78.0}
# {'latitude': -37.396, 'longitude': -37.396, 'surface_temperature_celcius': 65.0}
# {'latitude': -37.399, 'longitude': -37.399, 'surface_temperature_celcius': 84.0}
# {'latitude': -37.401, 'longitude': -37.401, 'surface_temperature_celcius': 79.0}
# {'latitude': -37.446, 'longitude': -37.446, 'surface_temperature_celcius': 65.0}
# {'latitude': -37.406, 'longitude': -37.406, 'surface_temperature_celcius': 88.0}
# {'latitude': -37.452, 'longitude': -37.452, 'surface_temperature_celcius': 77.0}
# {'latitude': -37.45, 'longitude': -37.45, 'surface_temperature_celcius': 69.0}
# {'latitude': -37.436, 'longitude': -37.436, 'surface_temperature_celcius': 76.0}
# {'latitude': -37.444, 'longitude': -37.444, 'surface_temperature_celcius': 66.0}
# {'latitude': -37.562, 'longitude': -37.562, 'surface_temperature_celcius': 72.0}
# {'latitude': -37.462, 'longitude': -37.462, 'surface_temperature_celcius': 90.0}
# {'latitude': -37.46, 'longitude': -37.46, 'surface_temperature_celcius': 65.0}
# {'latitude': -38.127, 'longitude': -38.127, 'surface_temperature_celcius': 77.0}
# {'latitude': -37.294, 'longitude': -37.294, 'surface_temperature_celcius': 87.0}
# {'latitude': -37.293, 'longitude': -37.293, 'surface_temperature_celcius': 85.0}
# {'latitude': -37.247, 'longitude': -37.247, 'surface_temperature_celcius': 68.0}
# {'latitude': -36.098, 'longitude': -36.098, 'surface_temperature_celcius': 67.0}
# {'latitude': -37.331, 'longitude': -37.331, 'surface_temperature_celcius': 65.0}
# {'latitude': -37.477, 'longitude': -37.477, 'surface_temperature_celcius': 93.0}
# {'latitude': -37.475, 'longitude': -37.475, 'surface_temperature_celcius': 77.0}
# {'latitude': -37.69, 'longitude': -37.69, 'surface_temperature_celcius': 80.0}
# {'latitude': -36.94, 'longitude': -36.94, 'surface_temperature_celcius': 69.0}
# {'latitude': -37.862, 'longitude': -37.862, 'surface_temperature_celcius': 65.0}
# {'latitude': -37.945, 'longitude': -37.945, 'surface_temperature_celcius': 73.0}
# {'latitude': -37.606, 'longitude': -37.606, 'surface_temperature_celcius': 87.0}
# {'latitude': -37.61, 'longitude': -37.61, 'surface_temperature_celcius': 80.0}
# {'latitude': -37.609, 'longitude': -37.609, 'surface_temperature_celcius': 84.0}
# {'latitude': -37.642, 'longitude': -37.642, 'surface_temperature_celcius': 65.0}
# {'latitude': -37.634, 'longitude': -37.634, 'surface_temperature_celcius': 71.0}
# {'latitude': -37.605, 'longitude': -37.605, 'surface_temperature_celcius': 83.0}
# {'latitude': -37.6, 'longitude': -37.6, 'surface_temperature_celcius': 86.0}
# {'latitude': -37.618, 'longitude': -37.618, 'surface_temperature_celcius': 76.0}
# {'latitude': -36.282, 'longitude': -36.282, 'surface_temperature_celcius': 71.0}
# {'latitude': -37.95, 'longitude': -37.95, 'surface_temperature_celcius': 70.0}
# {'latitude': -37.875, 'longitude': -37.875, 'surface_temperature_celcius': 73.0}
# {'latitude': -37.613, 'longitude': -37.613, 'surface_temperature_celcius': 75.0}
# {'latitude': -37.624, 'longitude': -37.624, 'surface_temperature_celcius': 66.0}
# {'latitude': -38.057, 'longitude': -38.057, 'surface_temperature_celcius': 73.0}
# {'latitude': -37.966, 'longitude': -37.966, 'surface_temperature_celcius': 68.0}
# {'latitude': -35.543, 'longitude': -35.543, 'surface_temperature_celcius': 67.0}

# %%
# QUESTION C
# Find date, surface temperature (°C), air temperature (°C), relative humidity and maxwind speed 
# on 15th and 16th of December 2023.
c = list(climate_data_collection.aggregate([
    {'$match': {'date': {'$in': ['2023-12-15', '2023-12-16']}}},
    {'$unwind': '$hotspots'},
    {'$project': {
        '_id': 0,
        'date': 1,
        'surface_temperature_celcius': '$hotspots.surface_temperature_celcius',
        'air_temperature_celcius': 1,
        'relative_humidity': 1,
        'max_wind_speed': 1
    }}
]))

print(len(c))

print("\nData on 15th and 16th December 2023:")
for record in c:
    pprint(record)
# Out:
# 19
#
# Data on 15th and 16th December 2023:
# {'air_temperature_celcius': 18.0,
#  'date': '2023-12-15',
#  'max_wind_speed': 14.0,
#  'relative_humidity': 52.0,
#  'surface_temperature_celcius': 42.0}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-12-15',
#  'max_wind_speed': 14.0,
#  'relative_humidity': 52.0,
#  'surface_temperature_celcius': 36.0}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-12-15',
#  'max_wind_speed': 14.0,
#  'relative_humidity': 52.0,
#  'surface_temperature_celcius': 38.0}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-12-15',
#  'max_wind_speed': 14.0,
#  'relative_humidity': 52.0,
#  'surface_temperature_celcius': 40.0}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-12-16',
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7,
#  'surface_temperature_celcius': 43.0}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-12-16',
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7,
#  'surface_temperature_celcius': 33.0}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-12-16',
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7,
#  'surface_temperature_celcius': 54.0}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-12-16',
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7,
#  'surface_temperature_celcius': 73.0}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-12-16',
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7,
#  'surface_temperature_celcius': 55.0}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-12-16',
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7,
#  'surface_temperature_celcius': 75.0}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-12-16',
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7,
#  'surface_temperature_celcius': 55.0}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-12-16',
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7,
#  'surface_temperature_celcius': 66.0}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-12-16',
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7,
#  'surface_temperature_celcius': 56.0}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-12-16',
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7,
#  'surface_temperature_celcius': 60.0}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-12-16',
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7,
#  'surface_temperature_celcius': 73.0}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-12-16',
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7,
#  'surface_temperature_celcius': 48.0}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-12-16',
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7,
#  'surface_temperature_celcius': 55.0}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-12-16',
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7,
#  'surface_temperature_celcius': 64.0}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-12-16',
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7,
#  'surface_temperature_celcius': 57.0}

# %%
# QUESTION D:  Find datetime, air temperature (°C), surface temperature (°C) and confidence
# when the confidence is between 80 and 100

d = list(climate_data_collection.aggregate([
    {'$unwind': '$hotspots'},
    {'$match': {'hotspots.confidence': {'$gte': 80, '$lte': 100}}}, 
    {'$project': {
    '_id': 0,
    'date': 1,
    'hotspots.time': 1,
    'air_temperature_celcius': 1,
    'hotspots.surface_temperature_celcius': 1,
    'hotspots.confidence': 1
    }}]))
     

print(len(d))
print("\nWhen confidence is between 80 and 100:")
for record in d:
    pprint(record)
# Out:
# 1133
#
# When confidence is between 80 and 100:
# {'air_temperature_celcius': 20.0,
#  'date': '2023-03-06',
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 62.0,
#               'time': '05:06:30'}}
# {'air_temperature_celcius': 20.0,
#  'date': '2023-03-06',
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 59.0,
#               'time': '05:06:20'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-03-07',
#  'hotspots': {'confidence': 88.0,
#               'surface_temperature_celcius': 64.0,
#               'time': '04:16:10'}}
# {'air_temperature_celcius': 23.0,
#  'date': '2023-03-09',
#  'hotspots': {'confidence': 86.0,
#               'surface_temperature_celcius': 41.0,
#               'time': '13:23:40'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-03-10',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 105.0,
#               'time': '04:48:40'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-03-10',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 109.0,
#               'time': '04:46:20'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-03-10',
#  'hotspots': {'confidence': 94.0,
#               'surface_temperature_celcius': 73.0,
#               'time': '04:45:30'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-03-10',
#  'hotspots': {'confidence': 97.0,
#               'surface_temperature_celcius': 80.0,
#               'time': '04:45:30'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-03-10',
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 55.0,
#               'time': '04:43:50'}}
# {'air_temperature_celcius': 21.0,
#  'date': '2023-03-12',
#  'hotspots': {'confidence': 94.0,
#               'surface_temperature_celcius': 105.0,
#               'time': '04:33:50'}}
# {'air_temperature_celcius': 21.0,
#  'date': '2023-03-12',
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 71.0,
#               'time': '04:29:50'}}
# {'air_temperature_celcius': 21.0,
#  'date': '2023-03-12',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 99.0,
#               'time': '04:28:20'}}
# {'air_temperature_celcius': 21.0,
#  'date': '2023-03-12',
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 68.0,
#               'time': '04:28:00'}}
# {'air_temperature_celcius': 21.0,
#  'date': '2023-03-12',
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 98.0,
#               'time': '04:27:20'}}
# {'air_temperature_celcius': 25.0,
#  'date': '2023-03-14',
#  'hotspots': {'confidence': 90.0,
#               'surface_temperature_celcius': 67.0,
#               'time': '04:24:40'}}
# {'air_temperature_celcius': 25.0,
#  'date': '2023-03-14',
#  'hotspots': {'confidence': 93.0,
#               'surface_temperature_celcius': 72.0,
#               'time': '04:22:20'}}
# {'air_temperature_celcius': 25.0,
#  'date': '2023-03-14',
#  'hotspots': {'confidence': 90.0,
#               'surface_temperature_celcius': 68.0,
#               'time': '04:20:50'}}
# {'air_temperature_celcius': 25.0,
#  'date': '2023-03-14',
#  'hotspots': {'confidence': 95.0,
#               'surface_temperature_celcius': 75.0,
#               'time': '04:16:30'}}
# {'air_temperature_celcius': 25.0,
#  'date': '2023-03-14',
#  'hotspots': {'confidence': 89.0,
#               'surface_temperature_celcius': 65.0,
#               'time': '04:16:20'}}
# {'air_temperature_celcius': 25.0,
#  'date': '2023-03-14',
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 55.0,
#               'time': '04:14:40'}}
# {'air_temperature_celcius': 25.0,
#  'date': '2023-03-14',
#  'hotspots': {'confidence': 96.0,
#               'surface_temperature_celcius': 79.0,
#               'time': '04:14:30'}}
# {'air_temperature_celcius': 25.0,
#  'date': '2023-03-14',
#  'hotspots': {'confidence': 94.0,
#               'surface_temperature_celcius': 75.0,
#               'time': '04:14:30'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-03-17',
#  'hotspots': {'confidence': 94.0,
#               'surface_temperature_celcius': 74.0,
#               'time': '04:48:20'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-03-17',
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 59.0,
#               'time': '04:45:10'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-03-17',
#  'hotspots': {'confidence': 86.0,
#               'surface_temperature_celcius': 60.0,
#               'time': '04:45:00'}}
# {'air_temperature_celcius': 21.0,
#  'date': '2023-03-18',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 121.0,
#               'time': '03:50:50'}}
# {'air_temperature_celcius': 21.0,
#  'date': '2023-03-18',
#  'hotspots': {'confidence': 97.0,
#               'surface_temperature_celcius': 80.0,
#               'time': '03:50:40'}}
# {'air_temperature_celcius': 24.0,
#  'date': '2023-03-19',
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 60.0,
#               'time': '04:39:50'}}
# {'air_temperature_celcius': 24.0,
#  'date': '2023-03-19',
#  'hotspots': {'confidence': 96.0,
#               'surface_temperature_celcius': 79.0,
#               'time': '04:39:20'}}
# {'air_temperature_celcius': 24.0,
#  'date': '2023-03-19',
#  'hotspots': {'confidence': 90.0,
#               'surface_temperature_celcius': 66.0,
#               'time': '04:36:00'}}
# {'air_temperature_celcius': 24.0,
#  'date': '2023-03-19',
#  'hotspots': {'confidence': 98.0,
#               'surface_temperature_celcius': 83.0,
#               'time': '04:33:00'}}
# {'air_temperature_celcius': 24.0,
#  'date': '2023-03-19',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 91.0,
#               'time': '04:32:50'}}
# {'air_temperature_celcius': 24.0,
#  'date': '2023-03-19',
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 58.0,
#               'time': '04:32:50'}}
# {'air_temperature_celcius': 24.0,
#  'date': '2023-03-19',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 113.0,
#               'time': '04:32:40'}}
# {'air_temperature_celcius': 24.0,
#  'date': '2023-03-19',
#  'hotspots': {'confidence': 92.0,
#               'surface_temperature_celcius': 70.0,
#               'time': '04:32:40'}}
# {'air_temperature_celcius': 24.0,
#  'date': '2023-03-19',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 106.0,
#               'time': '04:32:40'}}
# {'air_temperature_celcius': 23.0,
#  'date': '2023-03-25',
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 65.0,
#               'time': '03:59:50'}}
# {'air_temperature_celcius': 23.0,
#  'date': '2023-03-25',
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 62.0,
#               'time': '03:58:10'}}
# {'air_temperature_celcius': 23.0,
#  'date': '2023-03-25',
#  'hotspots': {'confidence': 95.0,
#               'surface_temperature_celcius': 75.0,
#               'time': '03:58:10'}}
# {'air_temperature_celcius': 23.0,
#  'date': '2023-03-25',
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 59.0,
#               'time': '03:57:10'}}
# {'air_temperature_celcius': 23.0,
#  'date': '2023-03-25',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 111.0,
#               'time': '03:57:10'}}
# {'air_temperature_celcius': 23.0,
#  'date': '2023-03-25',
#  'hotspots': {'confidence': 95.0,
#               'surface_temperature_celcius': 77.0,
#               'time': '03:57:10'}}
# {'air_temperature_celcius': 23.0,
#  'date': '2023-03-25',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 99.0,
#               'time': '03:56:40'}}
# {'air_temperature_celcius': 23.0,
#  'date': '2023-03-26',
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 54.0,
#               'time': '04:43:20'}}
# {'air_temperature_celcius': 23.0,
#  'date': '2023-03-26',
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 53.0,
#               'time': '04:40:50'}}
# {'air_temperature_celcius': 23.0,
#  'date': '2023-03-26',
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 54.0,
#               'time': '04:39:50'}}
# {'air_temperature_celcius': 23.0,
#  'date': '2023-03-26',
#  'hotspots': {'confidence': 91.0,
#               'surface_temperature_celcius': 68.0,
#               'time': '04:39:10'}}
# {'air_temperature_celcius': 23.0,
#  'date': '2023-03-26',
#  'hotspots': {'confidence': 92.0,
#               'surface_temperature_celcius': 70.0,
#               'time': '04:39:10'}}
# {'air_temperature_celcius': 23.0,
#  'date': '2023-03-26',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 89.0,
#               'time': '04:39:10'}}
# {'air_temperature_celcius': 23.0,
#  'date': '2023-03-26',
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 55.0,
#               'time': '04:39:10'}}
# {'air_temperature_celcius': 23.0,
#  'date': '2023-03-26',
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 62.0,
#               'time': '04:39:10'}}
# {'air_temperature_celcius': 23.0,
#  'date': '2023-03-26',
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 58.0,
#               'time': '04:39:10'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-03-28',
#  'hotspots': {'confidence': 88.0,
#               'surface_temperature_celcius': 64.0,
#               'time': '04:38:00'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-03-28',
#  'hotspots': {'confidence': 86.0,
#               'surface_temperature_celcius': 60.0,
#               'time': '04:33:40'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-03-28',
#  'hotspots': {'confidence': 92.0,
#               'surface_temperature_celcius': 71.0,
#               'time': '04:33:30'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-03-28',
#  'hotspots': {'confidence': 95.0,
#               'surface_temperature_celcius': 76.0,
#               'time': '04:33:30'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-03-28',
#  'hotspots': {'confidence': 93.0,
#               'surface_temperature_celcius': 73.0,
#               'time': '04:32:20'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-03-28',
#  'hotspots': {'confidence': 83.0,
#               'surface_temperature_celcius': 56.0,
#               'time': '04:30:50'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-03-28',
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 54.0,
#               'time': '04:30:20'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-03-28',
#  'hotspots': {'confidence': 94.0,
#               'surface_temperature_celcius': 74.0,
#               'time': '04:30:10'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-03-28',
#  'hotspots': {'confidence': 98.0,
#               'surface_temperature_celcius': 82.0,
#               'time': '04:30:10'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-03-28',
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 54.0,
#               'time': '04:30:10'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-03-28',
#  'hotspots': {'confidence': 97.0,
#               'surface_temperature_celcius': 80.0,
#               'time': '04:30:10'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-03-28',
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 54.0,
#               'time': '04:28:30'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-03-28',
#  'hotspots': {'confidence': 88.0,
#               'surface_temperature_celcius': 63.0,
#               'time': '04:28:30'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-03-28',
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 62.0,
#               'time': '04:28:30'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-03-28',
#  'hotspots': {'confidence': 97.0,
#               'surface_temperature_celcius': 80.0,
#               'time': '04:27:40'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-03-28',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 107.0,
#               'time': '04:27:20'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-03-28',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 108.0,
#               'time': '04:27:10'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-03-28',
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 55.0,
#               'time': '04:27:00'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-03-28',
#  'hotspots': {'confidence': 99.0,
#               'surface_temperature_celcius': 86.0,
#               'time': '04:27:00'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-03-28',
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 55.0,
#               'time': '04:26:50'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-03-28',
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 53.0,
#               'time': '04:26:50'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-03-28',
#  'hotspots': {'confidence': 83.0,
#               'surface_temperature_celcius': 57.0,
#               'time': '04:26:50'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-03-28',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 90.0,
#               'time': '04:26:50'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-03-28',
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 62.0,
#               'time': '04:26:50'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-03-28',
#  'hotspots': {'confidence': 97.0,
#               'surface_temperature_celcius': 81.0,
#               'time': '04:26:50'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-03-28',
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 59.0,
#               'time': '04:26:50'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-03-28',
#  'hotspots': {'confidence': 88.0,
#               'surface_temperature_celcius': 63.0,
#               'time': '04:26:50'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-03-28',
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 62.0,
#               'time': '04:26:50'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-03-28',
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 58.0,
#               'time': '04:26:50'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-03-28',
#  'hotspots': {'confidence': 97.0,
#               'surface_temperature_celcius': 81.0,
#               'time': '04:26:50'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-03-28',
#  'hotspots': {'confidence': 83.0,
#               'surface_temperature_celcius': 57.0,
#               'time': '04:26:50'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-03-28',
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 60.0,
#               'time': '04:26:50'}}
# {'air_temperature_celcius': 14.0,
#  'date': '2023-03-31',
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 55.0,
#               'time': '05:07:10'}}
# {'air_temperature_celcius': 14.0,
#  'date': '2023-03-31',
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 62.0,
#               'time': '05:01:20'}}
# {'air_temperature_celcius': 14.0,
#  'date': '2023-03-31',
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 56.0,
#               'time': '04:58:30'}}
# {'air_temperature_celcius': 14.0,
#  'date': '2023-03-31',
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 53.0,
#               'time': '04:58:00'}}
# {'air_temperature_celcius': 14.0,
#  'date': '2023-03-31',
#  'hotspots': {'confidence': 86.0,
#               'surface_temperature_celcius': 61.0,
#               'time': '04:57:10'}}
# {'air_temperature_celcius': 14.0,
#  'date': '2023-03-31',
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 54.0,
#               'time': '00:36:30'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 91.0,
#               'surface_temperature_celcius': 43.0,
#               'time': '13:17:00'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 83.0,
#               'surface_temperature_celcius': 40.0,
#               'time': '13:15:30'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 62.0,
#               'time': '13:15:10'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 96.0,
#               'surface_temperature_celcius': 45.0,
#               'time': '13:15:10'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 96.0,
#               'time': '03:59:10'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 93.0,
#               'surface_temperature_celcius': 72.0,
#               'time': '03:57:50'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 55.0,
#               'time': '03:56:20'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 88.0,
#               'surface_temperature_celcius': 64.0,
#               'time': '03:55:10'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 95.0,
#               'surface_temperature_celcius': 77.0,
#               'time': '03:55:10'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 96.0,
#               'surface_temperature_celcius': 78.0,
#               'time': '03:54:00'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 93.0,
#               'time': '03:53:50'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 59.0,
#               'time': '03:53:30'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 58.0,
#               'time': '03:52:30'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 90.0,
#               'time': '03:52:30'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 115.0,
#               'time': '03:52:20'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 86.0,
#               'surface_temperature_celcius': 61.0,
#               'time': '03:52:10'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 98.0,
#               'time': '03:52:10'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 89.0,
#               'time': '03:52:10'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 59.0,
#               'time': '03:52:10'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 83.0,
#               'surface_temperature_celcius': 63.0,
#               'time': '03:51:30'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 89.0,
#               'surface_temperature_celcius': 66.0,
#               'time': '03:51:30'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 62.0,
#               'time': '03:51:10'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 54.0,
#               'time': '03:51:00'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 98.0,
#               'surface_temperature_celcius': 82.0,
#               'time': '03:51:00'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 53.0,
#               'time': '03:51:00'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 103.0,
#               'time': '03:51:00'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 97.0,
#               'time': '03:50:50'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 90.0,
#               'surface_temperature_celcius': 66.0,
#               'time': '03:50:50'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 61.0,
#               'time': '03:50:40'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 99.0,
#               'surface_temperature_celcius': 86.0,
#               'time': '03:50:40'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 93.0,
#               'surface_temperature_celcius': 72.0,
#               'time': '03:50:40'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 95.0,
#               'surface_temperature_celcius': 76.0,
#               'time': '03:50:40'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 86.0,
#               'surface_temperature_celcius': 60.0,
#               'time': '03:50:40'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 89.0,
#               'surface_temperature_celcius': 65.0,
#               'time': '03:50:40'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 55.0,
#               'time': '03:50:40'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 89.0,
#               'surface_temperature_celcius': 65.0,
#               'time': '03:50:40'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-04-03',
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 54.0,
#               'time': '01:07:20'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 93.0,
#               'surface_temperature_celcius': 44.0,
#               'time': '15:31:00'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 64.0,
#               'time': '15:30:40'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 88.0,
#               'surface_temperature_celcius': 63.0,
#               'time': '04:41:50'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 62.0,
#               'time': '04:41:10'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 88.0,
#               'surface_temperature_celcius': 64.0,
#               'time': '04:41:00'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 86.0,
#               'surface_temperature_celcius': 61.0,
#               'time': '04:41:00'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 120.0,
#               'time': '04:40:00'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 90.0,
#               'surface_temperature_celcius': 67.0,
#               'time': '04:39:50'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 66.0,
#               'time': '04:39:50'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 90.0,
#               'surface_temperature_celcius': 66.0,
#               'time': '04:39:40'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 54.0,
#               'time': '04:39:40'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 107.0,
#               'time': '04:39:20'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 88.0,
#               'surface_temperature_celcius': 64.0,
#               'time': '04:37:10'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 88.0,
#               'surface_temperature_celcius': 63.0,
#               'time': '04:36:10'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 62.0,
#               'time': '04:36:10'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 90.0,
#               'surface_temperature_celcius': 76.0,
#               'time': '04:36:00'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 95.0,
#               'time': '04:35:00'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 83.0,
#               'surface_temperature_celcius': 57.0,
#               'time': '04:34:50'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 89.0,
#               'surface_temperature_celcius': 65.0,
#               'time': '04:34:20'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 96.0,
#               'surface_temperature_celcius': 78.0,
#               'time': '04:34:20'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 66.0,
#               'time': '04:34:20'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 57.0,
#               'time': '04:34:00'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 92.0,
#               'surface_temperature_celcius': 81.0,
#               'time': '04:33:50'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 54.0,
#               'time': '04:33:40'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 113.0,
#               'time': '04:33:30'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 58.0,
#               'time': '04:33:30'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 59.0,
#               'time': '04:33:30'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 62.0,
#               'time': '04:33:10'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 62.0,
#               'time': '04:33:10'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 97.0,
#               'surface_temperature_celcius': 79.0,
#               'time': '04:33:00'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 86.0,
#               'surface_temperature_celcius': 61.0,
#               'time': '04:33:00'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 98.0,
#               'surface_temperature_celcius': 82.0,
#               'time': '04:32:50'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 61.0,
#               'time': '04:32:50'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 58.0,
#               'time': '04:32:50'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 55.0,
#               'time': '04:32:50'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 123.0,
#               'time': '04:32:50'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 55.0,
#               'time': '04:32:50'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 118.0,
#               'time': '04:32:50'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 54.0,
#               'time': '04:32:40'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 96.0,
#               'surface_temperature_celcius': 78.0,
#               'time': '04:32:40'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 93.0,
#               'surface_temperature_celcius': 72.0,
#               'time': '04:32:40'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 120.0,
#               'time': '04:32:40'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 92.0,
#               'time': '04:32:40'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 101.0,
#               'time': '04:32:40'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 54.0,
#               'time': '04:32:40'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 98.0,
#               'time': '04:32:40'}}
# {'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 53.0,
#               'time': '00:12:50'}}
# {'air_temperature_celcius': 17.0,
#  'date': '2023-04-05',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 58.0,
#               'time': '13:09:00'}}
# {'air_temperature_celcius': 17.0,
#  'date': '2023-04-05',
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 39.0,
#               'time': '13:09:00'}}
# {'air_temperature_celcius': 17.0,
#  'date': '2023-04-05',
#  'hotspots': {'confidence': 93.0,
#               'surface_temperature_celcius': 44.0,
#               'time': '13:08:40'}}
# {'air_temperature_celcius': 17.0,
#  'date': '2023-04-05',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 47.0,
#               'time': '13:08:40'}}
# {'air_temperature_celcius': 17.0,
#  'date': '2023-04-05',
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 40.0,
#               'time': '13:07:00'}}
# {'air_temperature_celcius': 17.0,
#  'date': '2023-04-05',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 49.0,
#               'time': '13:04:20'}}
# {'air_temperature_celcius': 17.0,
#  'date': '2023-04-05',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 55.0,
#               'time': '13:03:20'}}
# {'air_temperature_celcius': 17.0,
#  'date': '2023-04-05',
#  'hotspots': {'confidence': 98.0,
#               'surface_temperature_celcius': 45.0,
#               'time': '13:03:00'}}
# {'air_temperature_celcius': 17.0,
#  'date': '2023-04-05',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 55.0,
#               'time': '13:03:00'}}
# {'air_temperature_celcius': 17.0,
#  'date': '2023-04-05',
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 39.0,
#               'time': '13:03:00'}}
# {'air_temperature_celcius': 17.0,
#  'date': '2023-04-05',
#  'hotspots': {'confidence': 88.0,
#               'surface_temperature_celcius': 42.0,
#               'time': '13:02:40'}}
# {'air_temperature_celcius': 17.0,
#  'date': '2023-04-05',
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 39.0,
#               'time': '13:02:40'}}
# {'air_temperature_celcius': 17.0,
#  'date': '2023-04-05',
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 88.0,
#               'time': '05:16:50'}}
# {'air_temperature_celcius': 17.0,
#  'date': '2023-04-05',
#  'hotspots': {'confidence': 93.0,
#               'surface_temperature_celcius': 83.0,
#               'time': '05:15:30'}}
# {'air_temperature_celcius': 17.0,
#  'date': '2023-04-05',
#  'hotspots': {'confidence': 93.0,
#               'surface_temperature_celcius': 72.0,
#               'time': '03:40:50'}}
# {'air_temperature_celcius': 17.0,
#  'date': '2023-04-05',
#  'hotspots': {'confidence': 95.0,
#               'surface_temperature_celcius': 76.0,
#               'time': '03:40:30'}}
# {'air_temperature_celcius': 17.0,
#  'date': '2023-04-05',
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 54.0,
#               'time': '03:40:20'}}
# {'air_temperature_celcius': 17.0,
#  'date': '2023-04-05',
#  'hotspots': {'confidence': 89.0,
#               'surface_temperature_celcius': 65.0,
#               'time': '03:39:30'}}
# {'air_temperature_celcius': 17.0,
#  'date': '2023-04-05',
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 62.0,
#               'time': '03:39:30'}}
# {'air_temperature_celcius': 17.0,
#  'date': '2023-04-05',
#  'hotspots': {'confidence': 90.0,
#               'surface_temperature_celcius': 66.0,
#               'time': '03:39:20'}}
# {'air_temperature_celcius': 17.0,
#  'date': '2023-04-05',
#  'hotspots': {'confidence': 83.0,
#               'surface_temperature_celcius': 56.0,
#               'time': '03:39:20'}}
# {'air_temperature_celcius': 17.0,
#  'date': '2023-04-05',
#  'hotspots': {'confidence': 89.0,
#               'surface_temperature_celcius': 65.0,
#               'time': '03:39:10'}}
# {'air_temperature_celcius': 17.0,
#  'date': '2023-04-05',
#  'hotspots': {'confidence': 83.0,
#               'surface_temperature_celcius': 64.0,
#               'time': '03:39:10'}}
# {'air_temperature_celcius': 17.0,
#  'date': '2023-04-05',
#  'hotspots': {'confidence': 95.0,
#               'surface_temperature_celcius': 76.0,
#               'time': '03:39:10'}}
# {'air_temperature_celcius': 17.0,
#  'date': '2023-04-05',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 92.0,
#               'time': '03:39:10'}}
# {'air_temperature_celcius': 17.0,
#  'date': '2023-04-05',
#  'hotspots': {'confidence': 88.0,
#               'surface_temperature_celcius': 63.0,
#               'time': '03:39:10'}}
# {'air_temperature_celcius': 17.0,
#  'date': '2023-04-05',
#  'hotspots': {'confidence': 89.0,
#               'surface_temperature_celcius': 64.0,
#               'time': '03:39:10'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 97.0,
#               'surface_temperature_celcius': 45.0,
#               'time': '13:45:30'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 65.0,
#               'time': '04:32:20'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 92.0,
#               'surface_temperature_celcius': 69.0,
#               'time': '04:31:10'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 95.0,
#               'time': '04:27:50'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 88.0,
#               'time': '04:27:50'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 54.0,
#               'time': '04:27:10'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 97.0,
#               'time': '04:27:00'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 86.0,
#               'surface_temperature_celcius': 60.0,
#               'time': '04:27:00'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 90.0,
#               'surface_temperature_celcius': 76.0,
#               'time': '04:27:00'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 99.0,
#               'time': '04:27:00'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 83.0,
#               'surface_temperature_celcius': 57.0,
#               'time': '04:27:00'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 83.0,
#               'surface_temperature_celcius': 64.0,
#               'time': '04:24:40'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 89.0,
#               'surface_temperature_celcius': 65.0,
#               'time': '04:24:20'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 89.0,
#               'surface_temperature_celcius': 65.0,
#               'time': '04:24:20'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 89.0,
#               'surface_temperature_celcius': 64.0,
#               'time': '04:24:00'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 92.0,
#               'surface_temperature_celcius': 70.0,
#               'time': '04:23:50'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 99.0,
#               'surface_temperature_celcius': 85.0,
#               'time': '04:23:50'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 93.0,
#               'surface_temperature_celcius': 72.0,
#               'time': '04:23:30'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 89.0,
#               'surface_temperature_celcius': 65.0,
#               'time': '04:23:10'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 62.0,
#               'time': '04:23:00'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 60.0,
#               'time': '04:22:40'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 83.0,
#               'surface_temperature_celcius': 56.0,
#               'time': '04:22:20'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 71.0,
#               'time': '04:22:20'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 60.0,
#               'time': '04:22:20'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 103.0,
#               'time': '04:22:20'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 91.0,
#               'surface_temperature_celcius': 69.0,
#               'time': '04:22:20'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 86.0,
#               'surface_temperature_celcius': 68.0,
#               'time': '04:22:10'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 59.0,
#               'time': '04:22:10'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 90.0,
#               'surface_temperature_celcius': 67.0,
#               'time': '04:22:10'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 90.0,
#               'surface_temperature_celcius': 66.0,
#               'time': '04:21:30'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 94.0,
#               'surface_temperature_celcius': 96.0,
#               'time': '04:21:10'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 115.0,
#               'time': '04:21:00'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 58.0,
#               'time': '04:21:00'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 95.0,
#               'time': '04:20:50'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 88.0,
#               'surface_temperature_celcius': 65.0,
#               'time': '04:20:50'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 83.0,
#               'surface_temperature_celcius': 63.0,
#               'time': '04:20:50'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 60.0,
#               'time': '04:20:40'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 83.0,
#               'surface_temperature_celcius': 78.0,
#               'time': '04:20:40'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 96.0,
#               'surface_temperature_celcius': 77.0,
#               'time': '04:20:40'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 91.0,
#               'surface_temperature_celcius': 68.0,
#               'time': '04:20:40'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 97.0,
#               'surface_temperature_celcius': 81.0,
#               'time': '04:20:40'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 56.0,
#               'time': '04:20:40'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 94.0,
#               'surface_temperature_celcius': 104.0,
#               'time': '04:20:40'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 92.0,
#               'surface_temperature_celcius': 71.0,
#               'time': '04:20:40'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 62.0,
#               'time': '04:20:40'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 61.0,
#               'time': '04:20:40'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 53.0,
#               'time': '04:20:40'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 60.0,
#               'time': '04:20:40'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 90.0,
#               'surface_temperature_celcius': 67.0,
#               'time': '04:20:40'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 62.0,
#               'time': '04:20:40'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 94.0,
#               'surface_temperature_celcius': 86.0,
#               'time': '04:20:40'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 57.0,
#               'time': '04:20:40'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 62.0,
#               'time': '04:20:40'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 100.0,
#               'time': '04:20:40'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 86.0,
#               'surface_temperature_celcius': 72.0,
#               'time': '04:20:40'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 57.0,
#               'time': '04:20:40'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-04-06',
#  'hotspots': {'confidence': 94.0,
#               'surface_temperature_celcius': 89.0,
#               'time': '04:20:40'}}
# {'air_temperature_celcius': 21.0,
#  'date': '2023-04-07',
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 41.0,
#               'time': '12:56:50'}}
# {'air_temperature_celcius': 21.0,
#  'date': '2023-04-07',
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 39.0,
#               'time': '12:56:30'}}
# {'air_temperature_celcius': 21.0,
#  'date': '2023-04-07',
#  'hotspots': {'confidence': 94.0,
#               'surface_temperature_celcius': 49.0,
#               'time': '12:56:30'}}
# {'air_temperature_celcius': 21.0,
#  'date': '2023-04-07',
#  'hotspots': {'confidence': 86.0,
#               'surface_temperature_celcius': 41.0,
#               'time': '12:53:40'}}
# {'air_temperature_celcius': 21.0,
#  'date': '2023-04-07',
#  'hotspots': {'confidence': 86.0,
#               'surface_temperature_celcius': 41.0,
#               'time': '12:52:10'}}
# {'air_temperature_celcius': 21.0,
#  'date': '2023-04-07',
#  'hotspots': {'confidence': 97.0,
#               'surface_temperature_celcius': 45.0,
#               'time': '12:51:20'}}
# {'air_temperature_celcius': 21.0,
#  'date': '2023-04-07',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 49.0,
#               'time': '12:51:00'}}
# {'air_temperature_celcius': 21.0,
#  'date': '2023-04-07',
#  'hotspots': {'confidence': 92.0,
#               'surface_temperature_celcius': 43.0,
#               'time': '12:50:50'}}
# {'air_temperature_celcius': 21.0,
#  'date': '2023-04-07',
#  'hotspots': {'confidence': 89.0,
#               'surface_temperature_celcius': 42.0,
#               'time': '12:50:40'}}
# {'air_temperature_celcius': 21.0,
#  'date': '2023-04-07',
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 54.0,
#               'time': '05:09:50'}}
# {'air_temperature_celcius': 21.0,
#  'date': '2023-04-07',
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 53.0,
#               'time': '05:03:10'}}
# {'air_temperature_celcius': 21.0,
#  'date': '2023-04-07',
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 54.0,
#               'time': '05:03:10'}}
# {'air_temperature_celcius': 21.0,
#  'date': '2023-04-07',
#  'hotspots': {'confidence': 100.0,
# ...
#               'time': '03:58:15'}}
# {'air_temperature_celcius': 13.0,
#  'date': '2023-10-03',
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 49.0,
#               'time': '03:58:15'}}
# {'air_temperature_celcius': 13.0,
#  'date': '2023-10-03',
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 55.0,
#               'time': '03:58:15'}}
# {'air_temperature_celcius': 13.0,
#  'date': '2023-10-03',
#  'hotspots': {'confidence': 90.0,
#               'surface_temperature_celcius': 63.0,
#               'time': '03:58:15'}}
# {'air_temperature_celcius': 13.0,
#  'date': '2023-10-03',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 90.0,
#               'time': '03:58:14'}}
# {'air_temperature_celcius': 13.0,
#  'date': '2023-10-03',
#  'hotspots': {'confidence': 88.0,
#               'surface_temperature_celcius': 65.0,
#               'time': '03:58:14'}}
# {'air_temperature_celcius': 13.0,
#  'date': '2023-10-03',
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 59.0,
#               'time': '03:58:14'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-10-04',
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 46.0,
#               'time': '04:41:02'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-10-04',
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 46.0,
#               'time': '04:41:00'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-10-04',
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 54.0,
#               'time': '04:41:00'}}
# {'air_temperature_celcius': 19.0,
#  'date': '2023-10-04',
#  'hotspots': {'confidence': 88.0,
#               'surface_temperature_celcius': 58.0,
#               'time': '04:41:00'}}
# {'air_temperature_celcius': 17.0,
#  'date': '2023-10-07',
#  'hotspots': {'confidence': 91.0,
#               'surface_temperature_celcius': 42.0,
#               'time': '12:59:33'}}
# {'air_temperature_celcius': 13.0,
#  'date': '2023-10-10',
#  'hotspots': {'confidence': 96.0,
#               'surface_temperature_celcius': 77.0,
#               'time': '04:04:19'}}
# {'air_temperature_celcius': 13.0,
#  'date': '2023-10-15',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 87.0,
#               'time': '04:23:01'}}
# {'air_temperature_celcius': 13.0,
#  'date': '2023-10-15',
#  'hotspots': {'confidence': 99.0,
#               'surface_temperature_celcius': 85.0,
#               'time': '04:23:01'}}
# {'air_temperature_celcius': 22.0,
#  'date': '2023-10-17',
#  'hotspots': {'confidence': 94.0,
#               'surface_temperature_celcius': 43.0,
#               'time': '13:36:12'}}
# {'air_temperature_celcius': 22.0,
#  'date': '2023-10-17',
#  'hotspots': {'confidence': 91.0,
#               'surface_temperature_celcius': 68.0,
#               'time': '04:10:45'}}
# {'air_temperature_celcius': 22.0,
#  'date': '2023-10-17',
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 55.0,
#               'time': '04:10:32'}}
# {'air_temperature_celcius': 26.0,
#  'date': '2023-10-18',
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 59.0,
#               'time': '00:39:02'}}
# {'air_temperature_celcius': 26.0,
#  'date': '2023-10-18',
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 56.0,
#               'time': '00:39:02'}}
# {'air_temperature_celcius': 13.0,
#  'date': '2023-10-20',
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 46.0,
#               'time': '04:41:19'}}
# {'air_temperature_celcius': 13.0,
#  'date': '2023-10-20',
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 50.0,
#               'time': '04:41:19'}}
# {'air_temperature_celcius': 12.0,
#  'date': '2023-10-21',
#  'hotspots': {'confidence': 88.0,
#               'surface_temperature_celcius': 59.0,
#               'time': '01:09:55'}}
# {'air_temperature_celcius': 12.0,
#  'date': '2023-10-21',
#  'hotspots': {'confidence': 92.0,
#               'surface_temperature_celcius': 67.0,
#               'time': '01:09:54'}}
# {'air_temperature_celcius': 13.0,
#  'date': '2023-10-26',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 48.0,
#               'time': '13:30:31'}}
# {'air_temperature_celcius': 13.0,
#  'date': '2023-10-26',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 53.0,
#               'time': '13:30:31'}}
# {'air_temperature_celcius': 22.0,
#  'date': '2023-10-27',
#  'hotspots': {'confidence': 86.0,
#               'surface_temperature_celcius': 60.0,
#               'time': '04:47:31'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-10-28',
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 56.0,
#               'time': '03:52:17'}}
# {'air_temperature_celcius': 13.0,
#  'date': '2023-11-05',
#  'hotspots': {'confidence': 83.0,
#               'surface_temperature_celcius': 58.0,
#               'time': '04:41:34'}}
# {'air_temperature_celcius': 13.0,
#  'date': '2023-11-05',
#  'hotspots': {'confidence': 90.0,
#               'surface_temperature_celcius': 65.0,
#               'time': '04:41:19'}}
# {'air_temperature_celcius': 13.0,
#  'date': '2023-11-05',
#  'hotspots': {'confidence': 89.0,
#               'surface_temperature_celcius': 62.0,
#               'time': '04:41:19'}}
# {'air_temperature_celcius': 14.0,
#  'date': '2023-11-09',
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 59.0,
#               'time': '04:16:48'}}
# {'air_temperature_celcius': 14.0,
#  'date': '2023-11-09',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 93.0,
#               'time': '04:16:48'}}
# {'air_temperature_celcius': 14.0,
#  'date': '2023-11-09',
#  'hotspots': {'confidence': 96.0,
#               'surface_temperature_celcius': 77.0,
#               'time': '04:16:48'}}
# {'air_temperature_celcius': 14.0,
#  'date': '2023-11-09',
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 62.0,
#               'time': '04:16:44'}}
# {'air_temperature_celcius': 14.0,
#  'date': '2023-11-09',
#  'hotspots': {'confidence': 97.0,
#               'surface_temperature_celcius': 80.0,
#               'time': '04:16:44'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-11-11',
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 37.0,
#               'time': '13:30:08'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-11-11',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 59.0,
#               'time': '13:30:08'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-11-11',
#  'hotspots': {'confidence': 86.0,
#               'surface_temperature_celcius': 60.0,
#               'time': '04:04:25'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-11-12',
#  'hotspots': {'confidence': 89.0,
#               'surface_temperature_celcius': 69.0,
#               'time': '00:33:15'}}
# {'air_temperature_celcius': 24.0,
#  'date': '2023-11-13',
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 61.0,
#               'time': '03:52:15'}}
# {'air_temperature_celcius': 24.0,
#  'date': '2023-11-13',
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 53.0,
#               'time': '03:52:14'}}
# {'air_temperature_celcius': 28.0,
#  'date': '2023-11-14',
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 65.0,
#               'time': '04:35:04'}}
# {'air_temperature_celcius': 24.0,
#  'date': '2023-11-21',
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 59.0,
#               'time': '00:27:21'}}
# {'air_temperature_celcius': 23.0,
#  'date': '2023-11-22',
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 59.0,
#               'time': '03:46:00'}}
# {'air_temperature_celcius': 23.0,
#  'date': '2023-11-22',
#  'hotspots': {'confidence': 88.0,
#               'surface_temperature_celcius': 64.0,
#               'time': '03:46:00'}}
# {'air_temperature_celcius': 24.0,
#  'date': '2023-11-23',
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 60.0,
#               'time': '04:28:59'}}
# {'air_temperature_celcius': 24.0,
#  'date': '2023-11-23',
#  'hotspots': {'confidence': 93.0,
#               'surface_temperature_celcius': 73.0,
#               'time': '04:28:59'}}
# {'air_temperature_celcius': 28.0,
#  'date': '2023-11-29',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 55.0,
#               'time': '13:17:24'}}
# {'air_temperature_celcius': 28.0,
#  'date': '2023-11-29',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 87.0,
#               'time': '03:52:10'}}
# {'air_temperature_celcius': 28.0,
#  'date': '2023-11-29',
#  'hotspots': {'confidence': 97.0,
#               'surface_temperature_celcius': 80.0,
#               'time': '03:52:10'}}
# {'air_temperature_celcius': 28.0,
#  'date': '2023-11-29',
#  'hotspots': {'confidence': 99.0,
#               'surface_temperature_celcius': 84.0,
#               'time': '03:52:10'}}
# {'air_temperature_celcius': 26.0,
#  'date': '2023-11-30',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 53.0,
#               'time': '15:38:36'}}
# {'air_temperature_celcius': 26.0,
#  'date': '2023-11-30',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 54.0,
#               'time': '15:38:35'}}
# {'air_temperature_celcius': 26.0,
#  'date': '2023-11-30',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 49.0,
#               'time': '15:38:35'}}
# {'air_temperature_celcius': 26.0,
#  'date': '2023-11-30',
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 38.0,
#               'time': '12:22:15'}}
# {'air_temperature_celcius': 26.0,
#  'date': '2023-11-30',
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 42.0,
#               'time': '12:22:15'}}
# {'air_temperature_celcius': 26.0,
#  'date': '2023-11-30',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 55.0,
#               'time': '12:22:15'}}
# {'air_temperature_celcius': 26.0,
#  'date': '2023-11-30',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 65.0,
#               'time': '12:22:15'}}
# {'air_temperature_celcius': 26.0,
#  'date': '2023-11-30',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 71.0,
#               'time': '12:22:14'}}
# {'air_temperature_celcius': 26.0,
#  'date': '2023-11-30',
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 59.0,
#               'time': '04:35:00'}}
# {'air_temperature_celcius': 26.0,
#  'date': '2023-11-30',
#  'hotspots': {'confidence': 98.0,
#               'surface_temperature_celcius': 83.0,
#               'time': '04:34:57'}}
# {'air_temperature_celcius': 26.0,
#  'date': '2023-11-30',
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 57.0,
#               'time': '04:34:57'}}
# {'air_temperature_celcius': 26.0,
#  'date': '2023-11-30',
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 61.0,
#               'time': '04:34:57'}}
# {'air_temperature_celcius': 26.0,
#  'date': '2023-11-30',
#  'hotspots': {'confidence': 99.0,
#               'surface_temperature_celcius': 86.0,
#               'time': '04:34:57'}}
# {'air_temperature_celcius': 26.0,
#  'date': '2023-11-30',
#  'hotspots': {'confidence': 83.0,
#               'surface_temperature_celcius': 58.0,
#               'time': '00:20:53'}}
# {'air_temperature_celcius': 26.0,
#  'date': '2023-11-30',
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 63.0,
#               'time': '00:20:53'}}
# {'air_temperature_celcius': 26.0,
#  'date': '2023-11-30',
#  'hotspots': {'confidence': 95.0,
#               'surface_temperature_celcius': 76.0,
#               'time': '00:20:53'}}
# {'air_temperature_celcius': 26.0,
#  'date': '2023-11-30',
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 56.0,
#               'time': '00:20:53'}}
# {'air_temperature_celcius': 26.0,
#  'date': '2023-11-30',
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 55.0,
#               'time': '00:20:53'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-12-08',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 54.0,
#               'time': '13:11:44'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-12-08',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 71.0,
#               'time': '13:11:44'}}
# {'air_temperature_celcius': 15.0,
#  'date': '2023-12-08',
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 52.0,
#               'time': '13:11:43'}}
# {'air_temperature_celcius': 17.0,
#  'date': '2023-12-09',
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 61.0,
#               'time': '00:14:34'}}
# {'air_temperature_celcius': 17.0,
#  'date': '2023-12-09',
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 54.0,
#               'time': '00:14:34'}}
# {'air_temperature_celcius': 17.0,
#  'date': '2023-12-09',
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 58.0,
#               'time': '00:14:33'}}
# {'air_temperature_celcius': 17.0,
#  'date': '2023-12-09',
#  'hotspots': {'confidence': 86.0,
#               'surface_temperature_celcius': 60.0,
#               'time': '00:14:33'}}
# {'air_temperature_celcius': 28.0,
#  'date': '2023-12-13',
#  'hotspots': {'confidence': 83.0,
#               'surface_temperature_celcius': 60.0,
#               'time': '04:04:19'}}
# {'air_temperature_celcius': 17.0,
#  'date': '2023-12-14',
#  'hotspots': {'confidence': 92.0,
#               'surface_temperature_celcius': 70.0,
#               'time': '04:47:25'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-12-15',
#  'hotspots': {'confidence': 92.0,
#               'surface_temperature_celcius': 42.0,
#               'time': '13:17:17'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-12-16',
#  'hotspots': {'confidence': 94.0,
#               'surface_temperature_celcius': 43.0,
#               'time': '15:38:39'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-12-16',
#  'hotspots': {'confidence': 93.0,
#               'surface_temperature_celcius': 73.0,
#               'time': '04:35:13'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-12-16',
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 55.0,
#               'time': '04:34:58'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-12-16',
#  'hotspots': {'confidence': 95.0,
#               'surface_temperature_celcius': 75.0,
#               'time': '04:34:58'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-12-16',
#  'hotspots': {'confidence': 90.0,
#               'surface_temperature_celcius': 66.0,
#               'time': '04:34:57'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-12-16',
#  'hotspots': {'confidence': 93.0,
#               'surface_temperature_celcius': 73.0,
#               'time': '00:21:12'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-12-16',
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 55.0,
#               'time': '00:21:11'}}
# {'air_temperature_celcius': 18.0,
#  'date': '2023-12-16',
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 64.0,
#               'time': '00:20:53'}}
# {'air_temperature_celcius': 17.0,
#  'date': '2023-12-25',
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 54.0,
#               'time': '04:29:08'}}
# {'air_temperature_celcius': 28.0,
#  'date': '2023-12-27',
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 63.0,
#               'time': '00:02:15'}}
# {'air_temperature_celcius': 28.0,
#  'date': '2023-12-27',
#  'hotspots': {'confidence': 86.0,
#               'surface_temperature_celcius': 67.0,
#               'time': '00:02:14'}}

# %%
# QUESTION E:
# Find the top 10 records with the highest surface temperature (°C)

e = list(climate_data_collection.aggregate([{'$unwind': '$hotspots'}, 
                                            {'$sort' : {'hotspots.surface_temperature_celcius': -1}},
                                            {'$limit': 10}]))
# print(len(e))
print("Top 10 records with the highest surface temperature (°C):")
for record in e:
    pprint(record)
# Out:
# Top 10 records with the highest surface temperature (°C):
# {'GHI_w/m2': 122.0,
#  '_id': ObjectId('665414224f0eb9e1d0be3802'),
#  'air_temperature_celcius': 15.0,
#  'date': '2023-04-18',
#  'hotspots': {'confidence': 100.0,
#               'latitude': -38.1665,
#               'longitude': 143.062,
#               'surface_temperature_celcius': 124.0,
#               'time': '04:52:00'},
#  'max_wind_speed': 9.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 56.1,
#  'station': '948701',
#  'windspeed_knots': 5.1}
# {'GHI_w/m2': 140.0,
#  '_id': ObjectId('665414214f0eb9e1d0be37f4'),
#  'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 100.0,
#               'latitude': -36.343,
#               'longitude': 142.1986,
#               'surface_temperature_celcius': 123.0,
#               'time': '04:32:50'},
#  'max_wind_speed': 12.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 47.5,
#  'station': '948701',
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 121.0,
#  '_id': ObjectId('665414224f0eb9e1d0be380f'),
#  'air_temperature_celcius': 14.0,
#  'date': '2023-05-01',
#  'hotspots': {'confidence': 100.0,
#               'latitude': -36.9318,
#               'longitude': 143.0907,
#               'surface_temperature_celcius': 122.0,
#               'time': '04:14:20'},
#  'max_wind_speed': 20.0,
#  'precipitation': '0.12G',
#  'relative_humidity': 49.2,
#  'station': '948701',
#  'windspeed_knots': 10.5}
# {'GHI_w/m2': 176.0,
#  '_id': ObjectId('665414204f0eb9e1d0be37e3'),
#  'air_temperature_celcius': 21.0,
#  'date': '2023-03-18',
#  'hotspots': {'confidence': 100.0,
#               'latitude': -37.017,
#               'longitude': 148.1297,
#               'surface_temperature_celcius': 121.0,
#               'time': '03:50:50'},
#  'max_wind_speed': 11.1,
#  'precipitation': '0.00I',
#  'relative_humidity': 52.8,
#  'station': '948701',
#  'windspeed_knots': 4.1}
# {'GHI_w/m2': 140.0,
#  '_id': ObjectId('665414214f0eb9e1d0be37f4'),
#  'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 100.0,
#               'latitude': -36.3521,
#               'longitude': 142.2008,
#               'surface_temperature_celcius': 120.0,
#               'time': '04:32:40'},
#  'max_wind_speed': 12.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 47.5,
#  'station': '948701',
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 132.0,
#  '_id': ObjectId('665414224f0eb9e1d0be37fd'),
#  'air_temperature_celcius': 16.0,
#  'date': '2023-04-13',
#  'hotspots': {'confidence': 100.0,
#               'latitude': -37.0745,
#               'longitude': 141.0692,
#               'surface_temperature_celcius': 120.0,
#               'time': '04:28:10'},
#  'max_wind_speed': 9.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 54.9,
#  'station': '948701',
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 81.0,
#  '_id': ObjectId('665414234f0eb9e1d0be381b'),
#  'air_temperature_celcius': 9.0,
#  'date': '2023-05-13',
#  'hotspots': {'confidence': 100.0,
#               'latitude': -34.9938,
#               'longitude': 141.876,
#               'surface_temperature_celcius': 120.0,
#               'time': '04:40:20'},
#  'max_wind_speed': 8.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 44.0,
#  'station': '948701',
#  'windspeed_knots': 2.8}
# {'GHI_w/m2': 122.0,
#  '_id': ObjectId('665414224f0eb9e1d0be3802'),
#  'air_temperature_celcius': 15.0,
#  'date': '2023-04-18',
#  'hotspots': {'confidence': 100.0,
#               'latitude': -37.8326,
#               'longitude': 143.4999,
#               'surface_temperature_celcius': 120.0,
#               'time': '04:44:50'},
#  'max_wind_speed': 9.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 56.1,
#  'station': '948701',
#  'windspeed_knots': 5.1}
# {'GHI_w/m2': 140.0,
#  '_id': ObjectId('665414214f0eb9e1d0be37f4'),
#  'air_temperature_celcius': 16.0,
#  'date': '2023-04-04',
#  'hotspots': {'confidence': 100.0,
#               'latitude': -36.1057,
#               'longitude': 141.7608,
#               'surface_temperature_celcius': 120.0,
#               'time': '04:40:00'},
#  'max_wind_speed': 12.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 47.5,
#  'station': '948701',
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 91.0,
#  '_id': ObjectId('665414234f0eb9e1d0be3812'),
#  'air_temperature_celcius': 10.0,
#  'date': '2023-05-04',
#  'hotspots': {'confidence': 100.0,
#               'latitude': -36.4057,
#               'longitude': 140.9806,
#               'surface_temperature_celcius': 119.0,
#               'time': '04:44:50'},
#  'max_wind_speed': 7.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 43.3,
#  'station': '948701',
#  'windspeed_knots': 2.6}

# %%
# QUESTION F: Find the number of fires each day. 
# Display the total number of fires and the date in the output.

# no of fires is the no of incidents per date in the hotspot collection
f = list(climate_data_collection.aggregate( [{'$project': {'_id': 0, 'date': 1, 
                                                           'total_fires': {'$size': {'$ifNull': ['$hotspots', []]}}}}]))
print("Number of fires each day:")
for record in f:
    print(f"Date: {record['date']}, Total fires: {record['total_fires']}")
# Out:
# Number of fires each day:
# Date: 2022-12-31, Total fires: 0
# Date: 2023-01-02, Total fires: 0
# Date: 2023-01-03, Total fires: 0
# Date: 2023-01-04, Total fires: 0
# Date: 2023-01-05, Total fires: 0
# Date: 2023-01-06, Total fires: 0
# Date: 2023-01-07, Total fires: 0
# Date: 2023-01-08, Total fires: 0
# Date: 2023-01-09, Total fires: 0
# Date: 2023-01-10, Total fires: 0
# Date: 2023-01-11, Total fires: 0
# Date: 2023-01-12, Total fires: 0
# Date: 2023-01-13, Total fires: 0
# Date: 2023-01-14, Total fires: 0
# Date: 2023-01-15, Total fires: 0
# Date: 2023-01-16, Total fires: 0
# Date: 2023-01-17, Total fires: 0
# Date: 2023-01-18, Total fires: 0
# Date: 2023-01-19, Total fires: 0
# Date: 2023-01-20, Total fires: 0
# Date: 2023-01-21, Total fires: 0
# Date: 2023-01-22, Total fires: 0
# Date: 2023-01-23, Total fires: 0
# Date: 2023-01-24, Total fires: 0
# Date: 2023-01-25, Total fires: 0
# Date: 2023-01-26, Total fires: 0
# Date: 2023-01-27, Total fires: 0
# Date: 2023-01-28, Total fires: 0
# Date: 2023-01-29, Total fires: 0
# Date: 2023-01-30, Total fires: 0
# Date: 2023-01-31, Total fires: 0
# Date: 2023-02-01, Total fires: 0
# Date: 2023-02-02, Total fires: 0
# Date: 2023-02-03, Total fires: 0
# Date: 2023-02-04, Total fires: 0
# Date: 2023-02-05, Total fires: 0
# Date: 2023-02-06, Total fires: 0
# Date: 2023-02-07, Total fires: 0
# Date: 2023-02-08, Total fires: 0
# Date: 2023-02-09, Total fires: 0
# Date: 2023-02-10, Total fires: 0
# Date: 2023-02-11, Total fires: 0
# Date: 2023-02-12, Total fires: 0
# Date: 2023-02-13, Total fires: 0
# Date: 2023-02-14, Total fires: 0
# Date: 2023-02-15, Total fires: 0
# Date: 2023-02-16, Total fires: 0
# Date: 2023-02-17, Total fires: 0
# Date: 2023-02-18, Total fires: 0
# Date: 2023-02-19, Total fires: 0
# Date: 2023-02-20, Total fires: 0
# Date: 2023-02-21, Total fires: 0
# Date: 2023-02-22, Total fires: 0
# Date: 2023-02-23, Total fires: 0
# Date: 2023-02-24, Total fires: 0
# Date: 2023-02-25, Total fires: 0
# Date: 2023-02-26, Total fires: 0
# Date: 2023-02-27, Total fires: 0
# Date: 2023-02-28, Total fires: 0
# Date: 2023-03-01, Total fires: 0
# Date: 2023-03-02, Total fires: 0
# Date: 2023-03-03, Total fires: 0
# Date: 2023-03-04, Total fires: 0
# Date: 2023-03-05, Total fires: 0
# Date: 2023-03-06, Total fires: 2
# Date: 2023-03-07, Total fires: 1
# Date: 2023-03-08, Total fires: 2
# Date: 2023-03-09, Total fires: 3
# Date: 2023-03-10, Total fires: 8
# Date: 2023-03-11, Total fires: 0
# Date: 2023-03-12, Total fires: 5
# Date: 2023-03-13, Total fires: 2
# Date: 2023-03-14, Total fires: 10
# Date: 2023-03-15, Total fires: 7
# Date: 2023-03-16, Total fires: 0
# Date: 2023-03-17, Total fires: 6
# Date: 2023-03-18, Total fires: 3
# Date: 2023-03-19, Total fires: 21
# Date: 2023-03-20, Total fires: 0
# Date: 2023-03-21, Total fires: 0
# Date: 2023-03-22, Total fires: 0
# Date: 2023-03-23, Total fires: 0
# Date: 2023-03-24, Total fires: 2
# Date: 2023-03-25, Total fires: 13
# Date: 2023-03-26, Total fires: 17
# Date: 2023-03-27, Total fires: 0
# Date: 2023-03-28, Total fires: 54
# Date: 2023-03-29, Total fires: 1
# Date: 2023-03-30, Total fires: 0
# Date: 2023-03-31, Total fires: 22
# Date: 2023-04-01, Total fires: 7
# Date: 2023-04-02, Total fires: 5
# Date: 2023-04-03, Total fires: 72
# Date: 2023-04-04, Total fires: 89
# Date: 2023-04-05, Total fires: 49
# Date: 2023-04-06, Total fires: 118
# Date: 2023-04-07, Total fires: 39
# Date: 2023-04-08, Total fires: 20
# Date: 2023-04-09, Total fires: 0
# Date: 2023-04-10, Total fires: 0
# Date: 2023-04-11, Total fires: 24
# Date: 2023-04-12, Total fires: 69
# Date: 2023-04-13, Total fires: 357
# Date: 2023-04-14, Total fires: 18
# Date: 2023-04-15, Total fires: 69
# Date: 2023-04-16, Total fires: 18
# Date: 2023-04-17, Total fires: 38
# Date: 2023-04-18, Total fires: 325
# Date: 2023-04-19, Total fires: 50
# Date: 2023-04-20, Total fires: 31
# Date: 2023-04-21, Total fires: 0
# Date: 2023-04-22, Total fires: 2
# Date: 2023-04-23, Total fires: 19
# Date: 2023-04-24, Total fires: 8
# Date: 2023-04-25, Total fires: 3
# Date: 2023-04-26, Total fires: 1
# Date: 2023-04-27, Total fires: 0
# Date: 2023-04-28, Total fires: 0
# Date: 2023-04-29, Total fires: 3
# Date: 2023-04-30, Total fires: 0
# Date: 2023-05-01, Total fires: 20
# Date: 2023-05-02, Total fires: 10
# Date: 2023-05-03, Total fires: 64
# Date: 2023-05-04, Total fires: 135
# Date: 2023-05-05, Total fires: 31
# Date: 2023-05-06, Total fires: 17
# Date: 2023-05-07, Total fires: 3
# Date: 2023-05-08, Total fires: 24
# Date: 2023-05-09, Total fires: 13
# Date: 2023-05-10, Total fires: 114
# Date: 2023-05-11, Total fires: 19
# Date: 2023-05-12, Total fires: 10
# Date: 2023-05-13, Total fires: 54
# Date: 2023-05-14, Total fires: 1
# Date: 2023-05-15, Total fires: 102
# Date: 2023-05-16, Total fires: 3
# Date: 2023-05-17, Total fires: 1
# Date: 2023-05-18, Total fires: 7
# Date: 2023-05-19, Total fires: 0
# Date: 2023-05-20, Total fires: 0
# Date: 2023-05-21, Total fires: 0
# Date: 2023-05-22, Total fires: 33
# Date: 2023-05-23, Total fires: 5
# Date: 2023-05-24, Total fires: 3
# Date: 2023-05-25, Total fires: 0
# Date: 2023-05-26, Total fires: 4
# Date: 2023-05-27, Total fires: 0
# Date: 2023-05-28, Total fires: 0
# Date: 2023-05-29, Total fires: 0
# Date: 2023-05-30, Total fires: 0
# Date: 2023-05-31, Total fires: 0
# Date: 2023-06-01, Total fires: 2
# Date: 2023-06-02, Total fires: 11
# Date: 2023-06-03, Total fires: 2
# Date: 2023-06-04, Total fires: 9
# Date: 2023-06-05, Total fires: 0
# Date: 2023-06-06, Total fires: 0
# Date: 2023-06-07, Total fires: 14
# Date: 2023-06-08, Total fires: 0
# Date: 2023-06-09, Total fires: 3
# Date: 2023-06-10, Total fires: 0
# Date: 2023-06-11, Total fires: 2
# Date: 2023-06-12, Total fires: 0
# Date: 2023-06-13, Total fires: 1
# Date: 2023-06-14, Total fires: 4
# Date: 2023-06-15, Total fires: 0
# Date: 2023-06-16, Total fires: 2
# Date: 2023-06-17, Total fires: 0
# Date: 2023-06-18, Total fires: 2
# Date: 2023-06-19, Total fires: 0
# Date: 2023-06-20, Total fires: 6
# Date: 2023-06-21, Total fires: 0
# Date: 2023-06-22, Total fires: 1
# Date: 2023-06-23, Total fires: 0
# Date: 2023-06-24, Total fires: 0
# Date: 2023-06-25, Total fires: 0
# Date: 2023-06-26, Total fires: 0
# Date: 2023-06-27, Total fires: 0
# Date: 2023-06-28, Total fires: 0
# Date: 2023-06-29, Total fires: 0
# Date: 2023-06-30, Total fires: 6
# Date: 2023-07-01, Total fires: 4
# Date: 2023-07-02, Total fires: 8
# Date: 2023-07-03, Total fires: 0
# Date: 2023-07-04, Total fires: 1
# Date: 2023-07-05, Total fires: 1
# Date: 2023-07-06, Total fires: 3
# Date: 2023-07-07, Total fires: 0
# Date: 2023-07-08, Total fires: 0
# Date: 2023-07-09, Total fires: 0
# Date: 2023-07-10, Total fires: 0
# Date: 2023-07-11, Total fires: 0
# Date: 2023-07-12, Total fires: 0
# Date: 2023-07-13, Total fires: 0
# Date: 2023-07-14, Total fires: 2
# Date: 2023-07-15, Total fires: 0
# Date: 2023-07-16, Total fires: 0
# Date: 2023-07-17, Total fires: 0
# Date: 2023-07-18, Total fires: 0
# Date: 2023-07-19, Total fires: 0
# Date: 2023-07-20, Total fires: 0
# Date: 2023-07-21, Total fires: 0
# Date: 2023-07-22, Total fires: 0
# Date: 2023-07-23, Total fires: 0
# Date: 2023-07-24, Total fires: 0
# Date: 2023-07-25, Total fires: 0
# Date: 2023-07-26, Total fires: 0
# Date: 2023-07-27, Total fires: 0
# Date: 2023-07-28, Total fires: 0
# Date: 2023-07-29, Total fires: 2
# Date: 2023-07-30, Total fires: 0
# Date: 2023-07-31, Total fires: 2
# Date: 2023-08-01, Total fires: 2
# Date: 2023-08-02, Total fires: 2
# Date: 2023-08-03, Total fires: 0
# Date: 2023-08-04, Total fires: 0
# Date: 2023-08-05, Total fires: 1
# Date: 2023-08-06, Total fires: 0
# Date: 2023-08-07, Total fires: 0
# Date: 2023-08-08, Total fires: 0
# Date: 2023-08-09, Total fires: 0
# Date: 2023-08-10, Total fires: 1
# Date: 2023-08-11, Total fires: 0
# Date: 2023-08-12, Total fires: 0
# Date: 2023-08-13, Total fires: 9
# Date: 2023-08-14, Total fires: 5
# Date: 2023-08-15, Total fires: 0
# Date: 2023-08-16, Total fires: 0
# Date: 2023-08-17, Total fires: 0
# Date: 2023-08-18, Total fires: 0
# Date: 2023-08-19, Total fires: 0
# Date: 2023-08-20, Total fires: 0
# Date: 2023-08-21, Total fires: 0
# Date: 2023-08-22, Total fires: 0
# Date: 2023-08-23, Total fires: 0
# Date: 2023-08-24, Total fires: 0
# Date: 2023-08-25, Total fires: 0
# Date: 2023-08-26, Total fires: 0
# Date: 2023-08-27, Total fires: 0
# Date: 2023-08-28, Total fires: 0
# Date: 2023-08-29, Total fires: 0
# Date: 2023-08-30, Total fires: 0
# Date: 2023-08-31, Total fires: 0
# Date: 2023-09-01, Total fires: 0
# Date: 2023-09-02, Total fires: 0
# Date: 2023-09-03, Total fires: 0
# Date: 2023-09-04, Total fires: 0
# Date: 2023-09-05, Total fires: 0
# Date: 2023-09-06, Total fires: 0
# Date: 2023-09-07, Total fires: 0
# Date: 2023-09-08, Total fires: 0
# Date: 2023-09-09, Total fires: 0
# Date: 2023-09-10, Total fires: 4
# Date: 2023-09-11, Total fires: 0
# Date: 2023-09-12, Total fires: 0
# Date: 2023-09-13, Total fires: 0
# Date: 2023-09-14, Total fires: 0
# Date: 2023-09-15, Total fires: 0
# Date: 2023-09-16, Total fires: 0
# Date: 2023-09-17, Total fires: 0
# Date: 2023-09-18, Total fires: 0
# Date: 2023-09-19, Total fires: 0
# Date: 2023-09-20, Total fires: 5
# Date: 2023-09-21, Total fires: 2
# Date: 2023-09-22, Total fires: 1
# Date: 2023-09-23, Total fires: 23
# Date: 2023-09-24, Total fires: 28
# Date: 2023-09-25, Total fires: 0
# Date: 2023-09-26, Total fires: 1
# Date: 2023-09-27, Total fires: 7
# Date: 2023-09-28, Total fires: 0
# Date: 2023-09-29, Total fires: 2
# Date: 2023-09-30, Total fires: 0
# Date: 2023-10-01, Total fires: 8
# Date: 2023-10-02, Total fires: 7
# Date: 2023-10-03, Total fires: 18
# Date: 2023-10-04, Total fires: 5
# Date: 2023-10-05, Total fires: 0
# Date: 2023-10-06, Total fires: 2
# Date: 2023-10-07, Total fires: 1
# Date: 2023-10-08, Total fires: 1
# Date: 2023-10-09, Total fires: 1
# Date: 2023-10-10, Total fires: 3
# Date: 2023-10-11, Total fires: 0
# Date: 2023-10-12, Total fires: 0
# Date: 2023-10-13, Total fires: 0
# Date: 2023-10-14, Total fires: 0
# Date: 2023-10-15, Total fires: 3
# Date: 2023-10-16, Total fires: 1
# Date: 2023-10-17, Total fires: 5
# Date: 2023-10-18, Total fires: 6
# Date: 2023-10-19, Total fires: 0
# Date: 2023-10-20, Total fires: 3
# Date: 2023-10-21, Total fires: 4
# Date: 2023-10-22, Total fires: 0
# Date: 2023-10-23, Total fires: 1
# Date: 2023-10-24, Total fires: 0
# Date: 2023-10-25, Total fires: 0
# Date: 2023-10-26, Total fires: 5
# Date: 2023-10-27, Total fires: 5
# Date: 2023-10-28, Total fires: 1
# Date: 2023-10-29, Total fires: 0
# Date: 2023-10-30, Total fires: 0
# Date: 2023-10-31, Total fires: 0
# Date: 2023-11-01, Total fires: 0
# Date: 2023-11-02, Total fires: 0
# Date: 2023-11-03, Total fires: 0
# Date: 2023-11-04, Total fires: 0
# Date: 2023-11-05, Total fires: 4
# Date: 2023-11-06, Total fires: 0
# Date: 2023-11-07, Total fires: 0
# Date: 2023-11-08, Total fires: 2
# Date: 2023-11-09, Total fires: 10
# Date: 2023-11-10, Total fires: 0
# Date: 2023-11-11, Total fires: 4
# Date: 2023-11-12, Total fires: 5
# Date: 2023-11-13, Total fires: 5
# Date: 2023-11-14, Total fires: 3
# Date: 2023-11-15, Total fires: 0
# Date: 2023-11-16, Total fires: 0
# Date: 2023-11-17, Total fires: 0
# Date: 2023-11-18, Total fires: 0
# Date: 2023-11-19, Total fires: 0
# Date: 2023-11-20, Total fires: 0
# Date: 2023-11-21, Total fires: 1
# Date: 2023-11-22, Total fires: 2
# Date: 2023-11-23, Total fires: 5
# Date: 2023-11-24, Total fires: 0
# Date: 2023-11-25, Total fires: 0
# Date: 2023-11-26, Total fires: 0
# Date: 2023-11-27, Total fires: 0
# Date: 2023-11-28, Total fires: 1
# Date: 2023-11-29, Total fires: 8
# Date: 2023-11-30, Total fires: 31
# Date: 2023-12-01, Total fires: 0
# Date: 2023-12-02, Total fires: 0
# Date: 2023-12-03, Total fires: 0
# Date: 2023-12-04, Total fires: 0
# Date: 2023-12-05, Total fires: 0
# Date: 2023-12-06, Total fires: 0
# Date: 2023-12-07, Total fires: 0
# Date: 2023-12-08, Total fires: 5
# Date: 2023-12-09, Total fires: 4
# Date: 2023-12-10, Total fires: 2
# Date: 2023-12-11, Total fires: 0
# Date: 2023-12-12, Total fires: 1
# Date: 2023-12-13, Total fires: 1
# Date: 2023-12-14, Total fires: 1
# Date: 2023-12-15, Total fires: 4
# Date: 2023-12-16, Total fires: 15
# Date: 2023-12-17, Total fires: 0
# Date: 2023-12-18, Total fires: 0
# Date: 2023-12-19, Total fires: 0
# Date: 2023-12-20, Total fires: 0
# Date: 2023-12-21, Total fires: 1
# Date: 2023-12-22, Total fires: 0
# Date: 2023-12-23, Total fires: 0
# Date: 2023-12-24, Total fires: 1
# Date: 2023-12-25, Total fires: 1
# Date: 2023-12-26, Total fires: 0
# Date: 2023-12-27, Total fires: 4
# Date: 2023-12-28, Total fires: 0
# Date: 2023-12-29, Total fires: 0
# Date: 2023-12-30, Total fires: 0
# Date: 2023-12-31, Total fires: 0
# Date: 2024-01-01, Total fires: 0

# %%
# QUESTION G: Find the records of fires where the confidence is below 70

g = list(climate_data_collection.aggregate([
    {'$unwind': '$hotspots'}, 
    {'$match': {'hotspots.confidence': {'$lt': 70}}}, 
    {'$project': {'_id': 0, 'hotspots': 1}}]))
print(len(g))
print("Records of fires where the confidence is below 7:")
for record in g:
    pprint(record)
# Out:
# 782
# Records of fires where the confidence is below 7:
# {'hotspots': {'confidence': 68.0,
#               'latitude': -37.7885,
#               'longitude': 141.9352,
#               'surface_temperature_celcius': 55.0,
#               'time': '04:51:00'}}
# {'hotspots': {'confidence': 54.0,
#               'latitude': -37.7171,
#               'longitude': 147.5866,
#               'surface_temperature_celcius': 44.0,
#               'time': '03:57:00'}}
# {'hotspots': {'confidence': 55.0,
#               'latitude': -36.2544,
#               'longitude': 148.0353,
#               'surface_temperature_celcius': 42.0,
#               'time': '04:43:00'}}
# {'hotspots': {'confidence': 54.0,
#               'latitude': -37.2197,
#               'longitude': 147.9621,
#               'surface_temperature_celcius': 43.0,
#               'time': '04:42:30'}}
# {'hotspots': {'confidence': 56.0,
#               'latitude': -37.0286,
#               'longitude': 148.155,
#               'surface_temperature_celcius': 42.0,
#               'time': '23:58:50'}}
# {'hotspots': {'confidence': 52.0,
#               'latitude': -37.0316,
#               'longitude': 148.1519,
#               'surface_temperature_celcius': 35.0,
#               'time': '12:57:00'}}
# {'hotspots': {'confidence': 52.0,
#               'latitude': -37.4075,
#               'longitude': 147.0233,
#               'surface_temperature_celcius': 43.0,
#               'time': '00:42:50'}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -37.0228,
#               'longitude': 148.1281,
#               'surface_temperature_celcius': 43.0,
#               'time': '00:42:50'}}
# {'hotspots': {'confidence': 51.0,
#               'latitude': -37.002,
#               'longitude': 148.2055,
#               'surface_temperature_celcius': 44.0,
#               'time': '00:42:40'}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.4313,
#               'longitude': 147.0343,
#               'surface_temperature_celcius': 37.0,
#               'time': '13:16:50'}}
# {'hotspots': {'confidence': 58.0,
#               'latitude': -37.9164,
#               'longitude': 143.4866,
#               'surface_temperature_celcius': 54.0,
#               'time': '04:39:20'}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -37.9257,
#               'longitude': 143.4891,
#               'surface_temperature_celcius': 54.0,
#               'time': '04:39:20'}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.3982,
#               'longitude': 147.0001,
#               'surface_temperature_celcius': 58.0,
#               'time': '04:36:00'}}
# {'hotspots': {'confidence': 59.0,
#               'latitude': -37.4023,
#               'longitude': 147.0394,
#               'surface_temperature_celcius': 56.0,
#               'time': '04:35:00'}}
# {'hotspots': {'confidence': 60.0,
#               'latitude': -37.4336,
#               'longitude': 147.0534,
#               'surface_temperature_celcius': 51.0,
#               'time': '04:33:50'}}
# {'hotspots': {'confidence': 61.0,
#               'latitude': -37.4003,
#               'longitude': 147.0448,
#               'surface_temperature_celcius': 55.0,
#               'time': '04:33:30'}}
# {'hotspots': {'confidence': 53.0,
#               'latitude': -37.9184,
#               'longitude': 143.4745,
#               'surface_temperature_celcius': 55.0,
#               'time': '04:33:30'}}
# {'hotspots': {'confidence': 61.0,
#               'latitude': -37.3911,
#               'longitude': 147.037,
#               'surface_temperature_celcius': 50.0,
#               'time': '04:33:10'}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -37.9277,
#               'longitude': 143.477,
#               'surface_temperature_celcius': 55.0,
#               'time': '04:32:50'}}
# {'hotspots': {'confidence': 60.0,
#               'latitude': -37.3942,
#               'longitude': 147.0455,
#               'surface_temperature_celcius': 44.0,
#               'time': '00:12:50'}}
# {'hotspots': {'confidence': 65.0,
#               'latitude': -37.1603,
#               'longitude': 142.8088,
#               'surface_temperature_celcius': 50.0,
#               'time': '04:58:00'}}
# {'hotspots': {'confidence': 55.0,
#               'latitude': -37.1684,
#               'longitude': 142.8183,
#               'surface_temperature_celcius': 48.0,
#               'time': '04:56:10'}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -37.8992,
#               'longitude': 143.4534,
#               'surface_temperature_celcius': 54.0,
#               'time': '04:03:10'}}
# {'hotspots': {'confidence': 57.0,
#               'latitude': -37.9022,
#               'longitude': 143.4607,
#               'surface_temperature_celcius': 57.0,
#               'time': '03:56:40'}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -38.1131,
#               'longitude': 143.7173,
#               'surface_temperature_celcius': 44.0,
#               'time': '04:41:10'}}
# {'hotspots': {'confidence': 60.0,
#               'latitude': -37.8469,
#               'longitude': 143.5343,
#               'surface_temperature_celcius': 50.0,
#               'time': '04:39:10'}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -37.1956,
#               'longitude': 141.0252,
#               'surface_temperature_celcius': 44.0,
#               'time': '04:39:10'}}
# {'hotspots': {'confidence': 53.0,
#               'latitude': -37.6195,
#               'longitude': 143.4212,
#               'surface_temperature_celcius': 46.0,
#               'time': '04:29:30'}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -37.6376,
#               'longitude': 143.4255,
#               'surface_temperature_celcius': 48.0,
#               'time': '04:26:50'}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -36.4422,
#               'longitude': 141.4172,
#               'surface_temperature_celcius': 46.0,
#               'time': '04:26:50'}}
# {'hotspots': {'confidence': 55.0,
#               'latitude': -34.342,
#               'longitude': 141.6548,
#               'surface_temperature_celcius': 54.0,
#               'time': '04:26:50'}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -34.2648,
#               'longitude': 141.6325,
#               'surface_temperature_celcius': 51.0,
#               'time': '00:48:40'}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -36.1649,
#               'longitude': 145.9352,
#               'surface_temperature_celcius': 44.0,
#               'time': '04:57:50'}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -36.0436,
#               'longitude': 145.7964,
#               'surface_temperature_celcius': 44.0,
#               'time': '04:57:40'}}
# {'hotspots': {'confidence': 52.0,
#               'latitude': -36.7134,
#               'longitude': 145.2151,
#               'surface_temperature_celcius': 38.0,
#               'time': '04:57:10'}}
# {'hotspots': {'confidence': 61.0,
#               'latitude': -36.7028,
#               'longitude': 145.2519,
#               'surface_temperature_celcius': 44.0,
#               'time': '04:57:10'}}
# {'hotspots': {'confidence': 51.0,
#               'latitude': -37.561,
#               'longitude': 143.242,
#               'surface_temperature_celcius': 38.0,
#               'time': '04:57:10'}}
# {'hotspots': {'confidence': 56.0,
#               'latitude': -37.982,
#               'longitude': 143.6422,
#               'surface_temperature_celcius': 42.0,
#               'time': '04:57:10'}}
# {'hotspots': {'confidence': 51.0,
#               'latitude': -34.2568,
#               'longitude': 141.64,
#               'surface_temperature_celcius': 42.0,
#               'time': '00:36:30'}}
# {'hotspots': {'confidence': 58.0,
#               'latitude': -36.2044,
#               'longitude': 145.7706,
#               'surface_temperature_celcius': 51.0,
#               'time': '04:02:40'}}
# {'hotspots': {'confidence': 57.0,
#               'latitude': -36.5245,
#               'longitude': 143.1556,
#               'surface_temperature_celcius': 43.0,
#               'time': '04:02:40'}}
# {'hotspots': {'confidence': 50.0,
#               'latitude': -36.1002,
#               'longitude': 147.6494,
#               'surface_temperature_celcius': 39.0,
#               'time': '04:02:40'}}
# {'hotspots': {'confidence': 60.0,
#               'latitude': -36.3872,
#               'longitude': 145.3858,
#               'surface_temperature_celcius': 40.0,
#               'time': '04:53:30'}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -36.494,
#               'longitude': 145.4522,
#               'surface_temperature_celcius': 41.0,
#               'time': '04:45:10'}}
# {'hotspots': {'confidence': 60.0,
#               'latitude': -37.324,
#               'longitude': 146.1647,
#               'surface_temperature_celcius': 46.0,
#               'time': '00:24:50'}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -37.8668,
#               'longitude': 143.0472,
#               'surface_temperature_celcius': 44.0,
#               'time': '03:53:50'}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -37.7602,
#               'longitude': 143.382,
#               'surface_temperature_celcius': 44.0,
#               'time': '03:53:40'}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -37.7885,
#               'longitude': 142.9509,
#               'surface_temperature_celcius': 43.0,
#               'time': '03:53:30'}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -37.8717,
#               'longitude': 143.2566,
#               'surface_temperature_celcius': 43.0,
#               'time': '03:52:10'}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -37.8011,
#               'longitude': 144.7343,
#               'surface_temperature_celcius': 44.0,
#               'time': '03:51:10'}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -37.0241,
#               'longitude': 141.5163,
#               'surface_temperature_celcius': 43.0,
#               'time': '03:50:50'}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -37.2912,
#               'longitude': 143.543,
#               'surface_temperature_celcius': 43.0,
#               'time': '03:50:50'}}
# {'hotspots': {'confidence': 52.0,
#               'latitude': -37.313,
#               'longitude': 146.1561,
#               'surface_temperature_celcius': 46.0,
#               'time': '03:50:50'}}
# {'hotspots': {'confidence': 56.0,
#               'latitude': -38.0226,
#               'longitude': 143.6739,
#               'surface_temperature_celcius': 39.0,
#               'time': '03:50:50'}}
# {'hotspots': {'confidence': 56.0,
#               'latitude': -37.8089,
#               'longitude': 145.9555,
#               'surface_temperature_celcius': 41.0,
#               'time': '03:50:40'}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -37.9009,
#               'longitude': 143.6217,
#               'surface_temperature_celcius': 45.0,
#               'time': '03:50:40'}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -37.7836,
#               'longitude': 142.9437,
#               'surface_temperature_celcius': 44.0,
#               'time': '03:50:40'}}
# {'hotspots': {'confidence': 52.0,
#               'latitude': -37.0484,
#               'longitude': 141.6245,
#               'surface_temperature_celcius': 42.0,
#               'time': '03:50:40'}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -36.911,
#               'longitude': 142.1445,
#               'surface_temperature_celcius': 47.0,
#               'time': '03:50:40'}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -34.2536,
#               'longitude': 141.6199,
#               'surface_temperature_celcius': 46.0,
#               'time': '01:11:00'}}
# {'hotspots': {'confidence': 57.0,
#               'latitude': -34.2614,
#               'longitude': 141.6412,
#               'surface_temperature_celcius': 43.0,
#               'time': '01:07:00'}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -36.0933,
#               'longitude': 141.7154,
#               'surface_temperature_celcius': 35.0,
#               'time': '15:30:40'}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -36.6281,
#               'longitude': 142.4349,
#               'surface_temperature_celcius': 68.0,
#               'time': '04:39:50'}}
# {'hotspots': {'confidence': 61.0,
#               'latitude': -36.937,
#               'longitude': 142.1176,
#               'surface_temperature_celcius': 50.0,
#               'time': '04:39:40'}}
# {'hotspots': {'confidence': 50.0,
#               'latitude': -36.6951,
#               'longitude': 145.424,
#               'surface_temperature_celcius': 43.0,
#               'time': '04:38:10'}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -37.6714,
#               'longitude': 144.2154,
#               'surface_temperature_celcius': 46.0,
#               'time': '04:36:30'}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -38.0494,
#               'longitude': 143.9141,
#               'surface_temperature_celcius': 58.0,
#               'time': '04:36:30'}}
# {'hotspots': {'confidence': 54.0,
#               'latitude': -38.4879,
#               'longitude': 143.9971,
#               'surface_temperature_celcius': 40.0,
#               'time': '04:34:20'}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -37.1744,
#               'longitude': 143.9256,
#               'surface_temperature_celcius': 43.0,
#               'time': '04:33:30'}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -36.4918,
#               'longitude': 142.2465,
#               'surface_temperature_celcius': 54.0,
#               'time': '04:33:30'}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -36.6299,
#               'longitude': 142.4234,
#               'surface_temperature_celcius': 71.0,
#               'time': '04:33:10'}}
# {'hotspots': {'confidence': 53.0,
#               'latitude': -36.1439,
#               'longitude': 145.832,
#               'surface_temperature_celcius': 50.0,
#               'time': '04:33:10'}}
# {'hotspots': {'confidence': 54.0,
#               'latitude': -36.7009,
#               'longitude': 141.541,
#               'surface_temperature_celcius': 49.0,
#               'time': '04:32:50'}}
# {'hotspots': {'confidence': 55.0,
#               'latitude': -36.4611,
#               'longitude': 143.146,
#               'surface_temperature_celcius': 48.0,
#               'time': '04:32:40'}}
# {'hotspots': {'confidence': 53.0,
#               'latitude': -36.3539,
#               'longitude': 142.1894,
#               'surface_temperature_celcius': 53.0,
#               'time': '04:32:40'}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -37.0081,
#               'longitude': 141.7654,
#               'surface_temperature_celcius': 62.0,
#               'time': '04:32:40'}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -36.2889,
#               'longitude': 141.7692,
#               'surface_temperature_celcius': 51.0,
#               'time': '04:32:40'}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -36.6228,
#               'longitude': 142.428,
#               'surface_temperature_celcius': 43.0,
#               'time': '04:32:40'}}
# {'hotspots': {'confidence': 60.0,
#               'latitude': -38.1177,
#               'longitude': 143.6409,
#               'surface_temperature_celcius': 40.0,
#               'time': '04:32:40'}}
# {'hotspots': {'confidence': 61.0,
#               'latitude': -38.3499,
#               'longitude': 147.033,
#               'surface_temperature_celcius': 35.0,
#               'time': '13:10:10'}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -37.6435,
#               'longitude': 146.1417,
#               'surface_temperature_celcius': 36.0,
#               'time': '13:02:40'}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -37.7522,
#               'longitude': 142.3183,
#               'surface_temperature_celcius': 50.0,
#               'time': '05:15:40'}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -36.9396,
#               'longitude': 141.9303,
#               'surface_temperature_celcius': 45.0,
#               'time': '05:15:30'}}
# {'hotspots': {'confidence': 65.0,
#               'latitude': -37.78,
#               'longitude': 141.8091,
#               'surface_temperature_celcius': 42.0,
#               'time': '03:45:10'}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -37.7767,
#               'longitude': 141.8127,
#               'surface_temperature_celcius': 44.0,
#               'time': '03:44:40'}}
# {'hotspots': {'confidence': 65.0,
#               'latitude': -38.1756,
#               'longitude': 143.9829,
#               'surface_temperature_celcius': 53.0,
#               'time': '03:44:30'}}
# {'hotspots': {'confidence': 50.0,
#               'latitude': -38.3553,
#               'longitude': 147.0231,
#               'surface_temperature_celcius': 38.0,
#               'time': '03:40:30'}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -36.934,
#               'longitude': 142.5759,
#               'surface_temperature_celcius': 47.0,
#               'time': '03:40:30'}}
# {'hotspots': {'confidence': 59.0,
#               'latitude': -38.0383,
#               'longitude': 144.4307,
#               'surface_temperature_celcius': 40.0,
#               'time': '03:39:10'}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -36.9354,
#               'longitude': 142.5807,
#               'surface_temperature_celcius': 45.0,
#               'time': '03:39:10'}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -36.9405,
#               'longitude': 142.8627,
#               'surface_temperature_celcius': 44.0,
#               'time': '03:39:10'}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -37.6339,
#               'longitude': 143.4108,
#               'surface_temperature_celcius': 46.0,
#               'time': '03:39:10'}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -37.7069,
#               'longitude': 142.1573,
#               'surface_temperature_celcius': 53.0,
#               'time': '04:25:40'}}
# {'hotspots': {'confidence': 50.0,
#               'latitude': -36.0834,
#               'longitude': 146.5364,
#               'surface_temperature_celcius': 53.0,
#               'time': '04:25:40'}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -36.3557,
#               'longitude': 141.3268,
#               'surface_temperature_celcius': 52.0,
#               'time': '04:23:50'}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -37.6104,
#               'longitude': 147.8367,
#               'surface_temperature_celcius': 42.0,
#               'time': '04:23:50'}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.9229,
#               'longitude': 143.647,
#               'surface_temperature_celcius': 63.0,
#               'time': '04:23:50'}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -37.5052,
#               'longitude': 142.8636,
#               'surface_temperature_celcius': 54.0,
#               'time': '04:23:50'}}
# {'hotspots': {'confidence': 51.0,
#               'latitude': -37.8177,
#               'longitude': 142.9168,
#               'surface_temperature_celcius': 50.0,
#               'time': '04:22:20'}}
# {'hotspots': {'confidence': 65.0,
#               'latitude': -37.5842,
#               'longitude': 148.5717,
#               'surface_temperature_celcius': 49.0,
#               'time': '04:21:20'}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -38.0089,
#               'longitude': 143.8976,
#               'surface_temperature_celcius': 45.0,
#               'time': '04:21:00'}}
# {'hotspots': {'confidence': 58.0,
#               'latitude': -37.3072,
#               'longitude': 147.5003,
#               'surface_temperature_celcius': 46.0,
#               'time': '04:21:00'}}
# {'hotspots': {'confidence': 50.0,
#               'latitude': -37.3556,
#               'longitude': 146.1085,
#               'surface_temperature_celcius': 47.0,
#               'time': '04:20:50'}}
# {'hotspots': {'confidence': 59.0,
#               'latitude': -37.6806,
#               'longitude': 143.2676,
#               'surface_temperature_celcius': 51.0,
#               'time': '04:20:40'}}
# {'hotspots': {'confidence': 58.0,
#               'latitude': -37.7212,
#               'longitude': 145.9754,
#               'surface_temperature_celcius': 52.0,
#               'time': '04:20:40'}}
# {'hotspots': {'confidence': 59.0,
#               'latitude': -38.3343,
#               'longitude': 143.8644,
#               'surface_temperature_celcius': 43.0,
#               'time': '04:20:40'}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -35.723,
#               'longitude': 142.063,
#               'surface_temperature_celcius': 54.0,
#               'time': '04:20:40'}}
# {'hotspots': {'confidence': 50.0,
#               'latitude': -35.1383,
#               'longitude': 141.8172,
#               'surface_temperature_celcius': 53.0,
#               'time': '04:20:40'}}
# {'hotspots': {'confidence': 52.0,
#               'latitude': -36.4133,
#               'longitude': 141.0286,
#               'surface_temperature_celcius': 47.0,
#               'time': '04:20:40'}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -36.6492,
#               'longitude': 142.3976,
#               'surface_temperature_celcius': 60.0,
#               'time': '04:20:40'}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -36.0765,
#               'longitude': 146.4896,
#               'surface_temperature_celcius': 46.0,
#               'time': '04:20:40'}}
# {'hotspots': {'confidence': 57.0,
#               'latitude': -36.0799,
#               'longitude': 146.529,
#               'surface_temperature_celcius': 44.0,
#               'time': '04:20:40'}}
# {'hotspots': {'confidence': 60.0,
#               'latitude': -36.8632,
#               'longitude': 142.5802,
#               'surface_temperature_celcius': 60.0,
#               'time': '04:20:40'}}
# {'hotspots': {'confidence': 59.0,
#               'latitude': -37.1929,
#               'longitude': 143.8132,
#               'surface_temperature_celcius': 45.0,
#               'time': '04:20:40'}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -37.1992,
#               'longitude': 146.2301,
#               'surface_temperature_celcius': 60.0,
#               'time': '04:20:40'}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -37.5914,
#               'longitude': 148.5807,
#               'surface_temperature_celcius': 61.0,
#               'time': '04:20:40'}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.7496,
#               'longitude': 148.3898,
#               'surface_temperature_celcius': 46.0,
#               'time': '04:20:40'}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -35.4625,
#               'longitude': 143.1486,
#               'surface_temperature_celcius': 44.0,
#               'time': '00:03:50'}}
# {'hotspots': {'confidence': 52.0,
#               'latitude': -38.0942,
#               'longitude': 146.9603,
#               'surface_temperature_celcius': 39.0,
#               'time': '00:01:40'}}
# {'hotspots': {'confidence': 61.0,
#               'latitude': -35.6961,
#               'longitude': 143.1935,
#               'surface_temperature_celcius': 35.0,
#               'time': '12:53:40'}}
# {'hotspots': {'confidence': 65.0,
#               'latitude': -37.3314,
#               'longitude': 149.1283,
#               'surface_temperature_celcius': 35.0,
#               'time': '12:52:10'}}
# {'hotspots': {'confidence': 51.0,
#               'latitude': -37.3359,
#               'longitude': 149.3816,
#               'surface_temperature_celcius': 48.0,
#               'time': '12:51:20'}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -37.3526,
#               'longitude': 149.3972,
#               'surface_temperature_celcius': 43.0,
#               'time': '12:51:00'}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -37.3344,
#               'longitude': 149.3933,
#               'surface_temperature_celcius': 47.0,
#               'time': '12:50:40'}}
# {'hotspots': {'confidence': 61.0,
#               'latitude': -37.3511,
#               'longitude': 149.4088,
#               'surface_temperature_celcius': 46.0,
#               'time': '12:50:40'}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -36.7508,
#               'longitude': 147.1254,
#               'surface_temperature_celcius': 39.0,
#               'time': '12:50:40'}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -36.1031,
#               'longitude': 143.0782,
#               'surface_temperature_celcius': 45.0,
#               'time': '05:03:10'}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -36.1025,
#               'longitude': 143.0825,
#               'surface_temperature_celcius': 43.0,
#               'time': '05:03:10'}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -36.7314,
#               'longitude': 141.8698,
#               'surface_temperature_celcius': 44.0,
#               'time': '05:03:10'}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.7931,
#               'longitude': 148.385,
#               'surface_temperature_celcius': 58.0,
#               'time': '03:31:40'}}
# {'hotspots': {'confidence': 60.0,
#               'latitude': -37.7974,
#               'longitude': 148.5498,
#               'surface_temperature_celcius': 53.0,
#               'time': '03:27:50'}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -37.34,
#               'longitude': 149.3668,
#               'surface_temperature_celcius': 74.0,
#               'time': '04:15:20'}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -37.8567,
#               'longitude': 147.1576,
#               'surface_temperature_celcius': 48.0,
#               'time': '04:14:40'}}
# {'hotspots': {'confidence': 56.0,
#               'latitude': -37.4368,
#               'longitude': 149.1191,
#               'surface_temperature_celcius': 52.0,
#               'time': '04:12:20'}}
# {'hotspots': {'confidence': 58.0,
#               'latitude': -37.9408,
#               'longitude': 146.0611,
#               'surface_temperature_celcius': 47.0,
#               'time': '04:11:40'}}
# {'hotspots': {'confidence': 59.0,
#               'latitude': -37.6994,
#               'longitude': 146.2162,
#               'surface_temperature_celcius': 40.0,
#               'time': '04:09:20'}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -36.7199,
#               'longitude': 142.5844,
#               'surface_temperature_celcius': 56.0,
#               'time': '04:08:50'}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -37.3493,
#               'longitude': 149.3691,
#               'surface_temperature_celcius': 80.0,
#               'time': '04:08:40'}}
# {'hotspots': {'confidence': 61.0,
#               'latitude': -37.6447,
#               'longitude': 148.6039,
#               'surface_temperature_celcius': 50.0,
#               'time': '04:08:40'}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -36.2282,
#               'longitude': 145.9074,
#               'surface_temperature_celcius': 43.0,
#               'time': '04:50:20'}}
# {'hotspots': {'confidence': 53.0,
#               'latitude': -36.3499,
#               'longitude': 146.1402,
#               'surface_temperature_celcius': 41.0,
#               'time': '04:42:10'}}
# {'hotspots': {'confidence': 56.0,
#               'latitude': -36.4439,
#               'longitude': 145.8846,
#               'surface_temperature_celcius': 39.0,
#               'time': '04:40:30'}}
# {'hotspots': {'confidence': 57.0,
#               'latitude': -36.0818,
#               'longitude': 146.5461,
#               'surface_temperature_celcius': 44.0,
#               'time': '04:39:40'}}
# {'hotspots': {'confidence': 50.0,
#               'latitude': -36.343,
#               'longitude': 143.3479,
#               'surface_temperature_celcius': 40.0,
#               'time': '04:38:50'}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -36.1751,
#               'longitude': 142.7831,
#               'surface_temperature_celcius': 43.0,
#               'time': '04:38:50'}}
# {'hotspots': {'confidence': 55.0,
#               'latitude': -36.4606,
#               'longitude': 141.0562,
#               'surface_temperature_celcius': 39.0,
#               'time': '04:38:50'}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -36.0156,
#               'longitude': 143.2188,
#               'surface_temperature_celcius': 43.0,
#               'time': '04:38:50'}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -36.1398,
#               'longitude': 141.7793,
#               'surface_temperature_celcius': 47.0,
#               'time': '04:38:50'}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -35.2068,
#               'longitude': 143.2912,
#               'surface_temperature_celcius': 44.0,
#               'time': '04:38:50'}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -36.3579,
#               'longitude': 146.1268,
#               'surface_temperature_celcius': 42.0,
#               'time': '04:38:50'}}
# {'hotspots': {'confidence': 60.0,
#               'latitude': -36.0787,
#               'longitude': 146.5728,
#               'surface_temperature_celcius': 40.0,
#               'time': '04:38:50'}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -37.9796,
#               'longitude': 146.8024,
#               'surface_temperature_celcius': 41.0,
#               'time': '00:20:30'}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -35.4309,
#               'longitude': 142.3626,
#               'surface_temperature_celcius': 36.0,
#               'time': '13:13:10'}}
# {'hotspots': {'confidence': 57.0,
#               'latitude': -35.4407,
#               'longitude': 142.3644,
#               'surface_temperature_celcius': 35.0,
#               'time': '13:09:20'}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -37.4755,
#               'longitude': 142.6339,
#               'surface_temperature_celcius': 43.0,
#               'time': '05:28:00'}}
# {'hotspots': {'confidence': 54.0,
#               'latitude': -36.7453,
#               'longitude': 141.4578,
#               'surface_temperature_celcius': 39.0,
#               'time': '05:26:50'}}
# {'hotspots': {'confidence': 50.0,
#               'latitude': -36.7038,
#               'longitude': 141.0498,
#               'surface_temperature_celcius': 39.0,
#               'time': '05:25:00'}}
# {'hotspots': {'confidence': 60.0,
#               'latitude': -37.7578,
#               'longitude': 142.227,
#               'surface_temperature_celcius': 40.0,
#               'time': '05:21:50'}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -36.8083,
#               'longitude': 142.0219,
#               'surface_temperature_celcius': 44.0,
#               'time': '05:21:40'}}
# {'hotspots': {'confidence': 61.0,
#               'latitude': -36.714,
#               'longitude': 141.1485,
#               'surface_temperature_celcius': 41.0,
#               'time': '05:21:40'}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -36.6385,
#               'longitude': 142.5297,
#               'surface_temperature_celcius': 44.0,
#               'time': '03:51:00'}}
# {'hotspots': {'confidence': 59.0,
#               'latitude': -36.9179,
#               'longitude': 141.3095,
#               'surface_temperature_celcius': 40.0,
#               'time': '03:50:10'}}
# {'hotspots': {'confidence': 65.0,
#               'latitude': -37.3654,
#               'longitude': 143.8156,
#               'surface_temperature_celcius': 42.0,
#               'time': '03:46:50'}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -36.6188,
#               'longitude': 144.0402,
#               'surface_temperature_celcius': 44.0,
#               'time': '03:46:20'}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -37.4047,
#               'longitude': 143.6615,
#               'surface_temperature_celcius': 45.0,
#               'time': '03:46:00'}}
# {'hotspots': {'confidence': 65.0,
#               'latitude': -36.2367,
#               'longitude': 141.3998,
#               'surface_temperature_celcius': 42.0,
#               'time': '03:46:00'}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -36.5234,
#               'longitude': 144.6939,
#               'surface_temperature_celcius': 41.0,
#               'time': '03:45:10'}}
# {'hotspots': {'confidence': 60.0,
#               'latitude': -36.6803,
#               'longitude': 141.0957,
#               'surface_temperature_celcius': 44.0,
#               'time': '03:45:00'}}
# {'hotspots': {'confidence': 65.0,
#               'latitude': -36.7866,
#               'longitude': 142.1989,
#               'surface_temperature_celcius': 42.0,
#               'time': '03:44:50'}}
# {'hotspots': {'confidence': 65.0,
#               'latitude': -36.6292,
#               'longitude': 143.8862,
#               'surface_temperature_celcius': 43.0,
#               'time': '03:44:40'}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -35.7937,
#               'longitude': 143.195,
#               'surface_temperature_celcius': 44.0,
#               'time': '03:44:40'}}
# {'hotspots': {'confidence': 57.0,
#               'latitude': -36.9142,
#               'longitude': 141.3013,
#               'surface_temperature_celcius': 40.0,
#               'time': '03:44:40'}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -36.6306,
#               'longitude': 143.8908,
#               'surface_temperature_celcius': 44.0,
#               'time': '03:44:40'}}
# {'hotspots': {'confidence': 59.0,
#               'latitude': -37.3586,
#               'longitude': 142.9087,
#               'surface_temperature_celcius': 40.0,
#               'time': '03:44:40'}}
# {'hotspots': {'confidence': 60.0,
#               'latitude': -36.9524,
#               'longitude': 143.7501,
#               'surface_temperature_celcius': 40.0,
#               'time': '03:44:40'}}
# {'hotspots': {'confidence': 50.0,
#               'latitude': -37.0643,
#               'longitude': 141.8567,
#               'surface_temperature_celcius': 40.0,
#               'time': '03:44:40'}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -36.2403,
#               'longitude': 141.4047,
#               'surface_temperature_celcius': 42.0,
#               'time': '03:44:40'}}
# {'hotspots': {'confidence': 56.0,
#               'latitude': -36.6776,
#               'longitude': 141.0877,
#               'surface_temperature_celcius': 44.0,
#               'time': '03:44:40'}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.7929,
#               'longitude': 143.1197,
#               'surface_temperature_celcius': 42.0,
#               'time': '03:44:40'}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.7972,
#               'longitude': 143.1153,
#               'surface_temperature_celcius': 42.0,
#               'time': '03:44:40'}}
# {'hotspots': {'confidence': 59.0,
#               'latitude': -37.3656,
#               'longitude': 143.8206,
#               'surface_temperature_celcius': 40.0,
#               'time': '03:44:40'}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -37.8865,
#               'longitude': 143.3048,
#               'surface_temperature_celcius': 44.0,
#               'time': '04:36:30'}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -37.5687,
#               'longitude': 143.2121,
#               'surface_temperature_celcius': 41.0,
#               'time': '04:36:20'}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -37.7359,
#               'longitude': 143.0108,
#               'surface_temperature_celcius': 44.0,
#               'time': '04:34:50'}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -37.1009,
#               'longitude': 141.9666,
#               'surface_temperature_celcius': 45.0,
#               'time': '04:33:50'}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -36.9211,
#               'longitude': 143.6017,
#               'surface_temperature_celcius': 44.0,
#               'time': '04:33:50'}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -38.211,
#               'longitude': 143.9122,
#               'surface_temperature_celcius': 42.0,
#               'time': '04:33:30'}}
# {'hotspots': {'confidence': 59.0,
#               'latitude': -37.7576,
#               'longitude': 142.465,
#               'surface_temperature_celcius': 40.0,
#               'time': '04:33:30'}}
# {'hotspots': {'confidence': 57.0,
#               'latitude': -38.0505,
#               'longitude': 142.4791,
#               'surface_temperature_celcius': 40.0,
#               'time': '04:33:20'}}
# {'hotspots': {'confidence': 52.0,
#               'latitude': -37.7851,
#               'longitude': 141.4593,
#               'surface_temperature_celcius': 38.0,
#               'time': '04:33:10'}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -37.9075,
#               'longitude': 142.6403,
#               'surface_temperature_celcius': 41.0,
#               'time': '04:33:10'}}
# {'hotspots': {'confidence': 50.0,
#               'latitude': -37.8345,
#               'longitude': 142.447,
#               'surface_temperature_celcius': 38.0,
#               'time': '04:33:10'}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -36.8573,
#               'longitude': 143.5278,
#               'surface_temperature_celcius': 45.0,
#               'time': '04:31:30'}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -37.0207,
#               'longitude': 141.4778,
#               'surface_temperature_celcius': 41.0,
#               'time': '04:29:50'}}
# {'hotspots': {'confidence': 59.0,
#               'latitude': -37.6857,
#               'longitude': 142.8532,
#               'surface_temperature_celcius': 40.0,
#               'time': '04:29:40'}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -37.2709,
#               'longitude': 143.9659,
#               'surface_temperature_celcius': 45.0,
#               'time': '04:29:40'}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -37.5632,
#               'longitude': 142.2864,
#               'surface_temperature_celcius': 45.0,
#               'time': '04:29:40'}}
# {'hotspots': {'confidence': 65.0,
#               'latitude': -36.3305,
#               'longitude': 146.049,
#               'surface_temperature_celcius': 46.0,
#               'time': '04:29:30'}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -38.0132,
#               'longitude': 143.2528,
#               'surface_temperature_celcius': 44.0,
#               'time': '04:29:20'}}
# {'hotspots': {'confidence': 57.0,
#               'latitude': -38.0643,
#               'longitude': 143.6616,
#               'surface_temperature_celcius': 43.0,
#               'time': '04:28:30'}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -37.9898,
#               'longitude': 143.8507,
#               'surface_temperature_celcius': 43.0,
#               'time': '04:28:30'}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -37.0667,
#               'longitude': 143.0582,
#               'surface_temperature_celcius': 44.0,
#               'time': '04:28:10'}}
# {'hotspots': {'confidence': 60.0,
#               'latitude': -37.7836,
#               'longitude': 141.4711,
#               'surface_temperature_celcius': 40.0,
#               'time': '04:27:40'}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -36.778,
#               'longitude': 145.1635,
#               'surface_temperature_celcius': 45.0,
#               'time': '04:27:30'}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -37.6008,
#               'longitude': 143.0558,
#               'surface_temperature_celcius': 44.0,
#               'time': '04:27:20'}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -37.2757,
#               'longitude': 143.8126,
#               'surface_temperature_celcius': 42.0,
#               'time': '04:26:50'}}
# {'hotspots': {'confidence': 58.0,
#               'latitude': -38.26,
#               'longitude': 143.9602,
#               'surface_temperature_celcius': 40.0,
#               'time': '04:26:40'}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -37.9916,
#               'longitude': 143.8392,
#               'surface_temperature_celcius': 44.0,
#               'time': '04:26:40'}}
# {'hotspots': {'confidence': 61.0,
#               'latitude': -37.7635,
#               'longitude': 142.8181,
#               'surface_temperature_celcius': 41.0,
#               'time': '04:26:40'}}
# {'hotspots': {'confidence': 53.0,
#               'latitude': -37.7982,
#               'longitude': 142.2386,
#               'surface_temperature_celcius': 41.0,
#               'time': '04:26:40'}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -37.4391,
#               'longitude': 143.0293,
#               'surface_temperature_celcius': 43.0,
#               'time': '04:26:40'}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -37.6161,
#               'longitude': 141.2781,
#               'surface_temperature_celcius': 45.0,
#               'time': '04:26:40'}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -36.6777,
#               'longitude': 141.37,
#               'surface_temperature_celcius': 49.0,
#               'time': '04:26:30'}}
# {'hotspots': {'confidence': 61.0,
#               'latitude': -36.6701,
#               'longitude': 141.3566,
#               'surface_temperature_celcius': 50.0,
#               'time': '04:26:30'}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -36.4373,
#               'longitude': 143.6328,
#               'surface_temperature_celcius': 43.0,
#               'time': '04:26:30'}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -36.4392,
#               'longitude': 144.2111,
#               'surface_temperature_celcius': 44.0,
#               'time': '04:26:30'}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -36.3275,
#               'longitude': 145.5876,
#               'surface_temperature_celcius': 44.0,
#               'time': '04:26:30'}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -36.9875,
#               'longitude': 141.9298,
#               'surface_temperature_celcius': 44.0,
#               'time': '04:26:30'}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -36.7754,
#               'longitude': 143.5261,
#               'surface_temperature_celcius': 44.0,
#               'time': '04:26:30'}}
# {'hotspots': {'confidence': 61.0,
#               'latitude': -37.2054,
#               'longitude': 141.1083,
#               'surface_temperature_celcius': 41.0,
#               'time': '04:26:30'}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -37.1089,
#               'longitude': 141.8394,
#               'surface_temperature_celcius': 42.0,
#               'time': '04:26:30'}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -36.7804,
#               'longitude': 145.1698,
#               'surface_temperature_celcius': 45.0,
#               'time': '04:26:30'}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -37.1949,
#               'longitude': 142.675,
#               'surface_temperature_celcius': 44.0,
#               'time': '04:26:30'}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -37.4784,
#               'longitude': 143.015,
#               'surface_temperature_celcius': 47.0,
#               'time': '04:26:30'}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -37.5358,
#               'longitude': 143.0572,
#               'surface_temperature_celcius': 43.0,
#               'time': '04:26:30'}}
# {'hotspots': {'confidence': 59.0,
#               'latitude': -37.5077,
#               'longitude': 143.2495,
#               'surface_temperature_celcius': 40.0,
#               'time': '04:26:30'}}
# {'hotspots': {'confidence': 57.0,
#               'latitude': -37.5389,
#               'longitude': 143.1632,
#               'surface_temperature_celcius': 53.0,
#               'time': '04:26:30'}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -37.7037,
#               'longitude': 142.3299,
#               'surface_temperature_celcius': 41.0,
#               'time': '04:26:30'}}
# {'hotspots': {'confidence': 59.0,
#               'latitude': -37.5837,
#               'longitude': 144.1565,
#               'surface_temperature_celcius': 40.0,
#               'time': '04:26:30'}}
# {'hotspots': {'confidence': 61.0,
#               'latitude': -37.9158,
#               'longitude': 141.9147,
#               'surface_temperature_celcius': 41.0,
#               'time': '04:26:30'}}
# {'hotspots': {'confidence': 61.0,
#               'latitude': -37.9143,
#               'longitude': 141.9264,
#               'surface_temperature_celcius': 41.0,
#               'time': '04:26:30'}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -37.7862,
#               'longitude': 142.9823,
#               'surface_temperature_celcius': 43.0,
#               'time': '04:26:30'}}
# {'hotspots': {'confidence': 61.0,
#               'latitude': -37.7416,
#               'longitude': 143.2885,
#               'surface_temperature_celcius': 41.0,
#               'time': '04:26:30'}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -37.8131,
#               'longitude': 143.1175,
#               'surface_temperature_celcius': 45.0,
#               'time': '04:26:30'}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -37.8759,
#               'longitude': 143.3141,
#               'surface_temperature_celcius': 45.0,
#               'time': '04:26:30'}}
# {'hotspots': {'confidence': 51.0,
#               'latitude': -37.9359,
#               'longitude': 143.3468,
#               'surface_temperature_celcius': 38.0,
#               'time': '04:26:30'}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -37.9309,
#               'longitude': 143.381,
#               'surface_temperature_celcius': 44.0,
#               'time': '04:26:30'}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -34.5442,
#               'longitude': 141.7211,
#               'surface_temperature_celcius': 52.0,
#               'time': '04:26:30'}}
# {'hotspots': {'confidence': 53.0,
#               'latitude': -37.9422,
#               'longitude': 143.6199,
#               'surface_temperature_celcius': 39.0,
#               'time': '04:26:30'}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -35.2791,
#               'longitude': 142.5659,
#               'surface_temperature_celcius': 49.0,
#               'time': '04:26:30'}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -38.219,
#               'longitude': 143.7352,
#               'surface_temperature_celcius': 44.0,
#               'time': '04:26:30'}}
# {'hotspots': {'confidence': 57.0,
#               'latitude': -38.2093,
#               'longitude': 143.9237,
#               'surface_temperature_celcius': 40.0,
#               'time': '04:26:30'}}
# {'hotspots': {'confidence': 54.0,
#               'latitude': -35.7608,
#               'longitude': 143.3545,
#               'surface_temperature_celcius': 47.0,
#               'time': '04:26:30'}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -38.2583,
#               'longitude': 143.9717,
#               'surface_temperature_celcius': 41.0,
#               'time': '04:26:30'}}
# {'hotspots': {'confidence': 65.0,
#               'latitude': -36.6843,
#               'longitude': 141.5899,
#               'surface_temperature_celcius': 43.0,
#               'time': '04:26:30'}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -35.2465,
#               'longitude': 143.4426,
#               'surface_temperature_celcius': 42.0,
#               'time': '00:14:50'}}
# {'hotspots': {'confidence': 58.0,
#               'latitude': -35.2432,
#               'longitude': 143.4496,
#               'surface_temperature_celcius': 44.0,
#               'time': '00:08:50'}}
# {'hotspots': {'confidence': 65.0,
#               'latitude': -34.5396,
#               'longitude': 141.7292,
#               'surface_temperature_celcius': 43.0,
#               'time': '00:07:00'}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -34.532,
#               'longitude': 141.7257,
# ...
#               'latitude': -34.793,
#               'longitude': 141.5898,
#               'surface_temperature_celcius': 42.0,
#               'time': '05:03:10'}}
# {'hotspots': {'confidence': 56.0,
#               'latitude': -37.4421,
#               'longitude': 148.259,
#               'surface_temperature_celcius': 39.0,
#               'time': '04:15:40'}}
# {'hotspots': {'confidence': 61.0,
#               'latitude': -38.0173,
#               'longitude': 144.0571,
#               'surface_temperature_celcius': 41.0,
#               'time': '04:11:00'}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -37.4754,
#               'longitude': 148.161,
#               'surface_temperature_celcius': 43.0,
#               'time': '04:10:20'}}
# {'hotspots': {'confidence': 61.0,
#               'latitude': -37.443,
#               'longitude': 147.3064,
#               'surface_temperature_celcius': 41.0,
#               'time': '04:09:30'}}
# {'hotspots': {'confidence': 58.0,
#               'latitude': -37.7836,
#               'longitude': 143.9688,
#               'surface_temperature_celcius': 40.0,
#               'time': '04:07:50'}}
# {'hotspots': {'confidence': 56.0,
#               'latitude': -37.559,
#               'longitude': 148.037,
#               'surface_temperature_celcius': 41.0,
#               'time': '23:50:43'}}
# {'hotspots': {'confidence': 58.0,
#               'latitude': -37.379,
#               'longitude': 148.126,
#               'surface_temperature_celcius': 82.0,
#               'time': '23:50:40'}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -37.379,
#               'longitude': 148.132,
#               'surface_temperature_celcius': 78.0,
#               'time': '23:50:40'}}
# {'hotspots': {'confidence': 50.0,
#               'latitude': -36.984,
#               'longitude': 148.25,
#               'surface_temperature_celcius': 35.0,
#               'time': '04:59:18'}}
# {'hotspots': {'confidence': 61.0,
#               'latitude': -37.347,
#               'longitude': 148.019,
#               'surface_temperature_celcius': 36.0,
#               'time': '04:59:13'}}
# {'hotspots': {'confidence': 56.0,
#               'latitude': -36.995,
#               'longitude': 148.268,
#               'surface_temperature_celcius': 37.0,
#               'time': '03:21:28'}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -37.554,
#               'longitude': 148.073,
#               'surface_temperature_celcius': 37.0,
#               'time': '03:21:19'}}
# {'hotspots': {'confidence': 59.0,
#               'latitude': -37.375,
#               'longitude': 148.063,
#               'surface_temperature_celcius': 35.0,
#               'time': '13:30:09'}}
# {'hotspots': {'confidence': 58.0,
#               'latitude': -37.397,
#               'longitude': 148.121,
#               'surface_temperature_celcius': 58.0,
#               'time': '04:04:19'}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -37.452,
#               'longitude': 148.115,
#               'surface_temperature_celcius': 77.0,
#               'time': '04:04:18'}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -37.465,
#               'longitude': 148.153,
#               'surface_temperature_celcius': 63.0,
#               'time': '04:04:18'}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.45,
#               'longitude': 148.126,
#               'surface_temperature_celcius': 69.0,
#               'time': '04:04:18'}}
# {'hotspots': {'confidence': 61.0,
#               'latitude': -37.562,
#               'longitude': 148.05,
#               'surface_temperature_celcius': 72.0,
#               'time': '04:04:17'}}
# {'hotspots': {'confidence': 56.0,
#               'latitude': -38.495,
#               'longitude': 146.944,
#               'surface_temperature_celcius': 53.0,
#               'time': '04:04:04'}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.087,
#               'longitude': 145.37,
#               'surface_temperature_celcius': 33.0,
#               'time': '03:52:14'}}
# {'hotspots': {'confidence': 65.0,
#               'latitude': -36.398,
#               'longitude': 145.286,
#               'surface_temperature_celcius': 39.0,
#               'time': '04:35:18'}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -37.463,
#               'longitude': 148.109,
#               'surface_temperature_celcius': 34.0,
#               'time': '15:13:56'}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.46,
#               'longitude': 148.113,
#               'surface_temperature_celcius': 52.0,
#               'time': '04:10:28'}}
# {'hotspots': {'confidence': 50.0,
#               'latitude': -37.466,
#               'longitude': 148.1,
#               'surface_temperature_celcius': 29.0,
#               'time': '23:44:31'}}
# {'hotspots': {'confidence': 59.0,
#               'latitude': -37.475,
#               'longitude': 148.134,
#               'surface_temperature_celcius': 40.0,
#               'time': '04:53:10'}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -37.456,
#               'longitude': 148.11,
#               'surface_temperature_celcius': 40.0,
#               'time': '00:39:34'}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -37.461,
#               'longitude': 148.109,
#               'surface_temperature_celcius': 33.0,
#               'time': '15:01:44'}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -37.236,
#               'longitude': 141.176,
#               'surface_temperature_celcius': 37.0,
#               'time': '03:58:28'}}
# {'hotspots': {'confidence': 59.0,
#               'latitude': -37.227,
#               'longitude': 141.151,
#               'surface_temperature_celcius': 35.0,
#               'time': '03:58:28'}}
# {'hotspots': {'confidence': 54.0,
#               'latitude': -37.227,
#               'longitude': 141.146,
#               'surface_temperature_celcius': 31.0,
#               'time': '01:22:44'}}
# {'hotspots': {'confidence': 50.0,
#               'latitude': -36.418,
#               'longitude': 141.596,
#               'surface_temperature_celcius': 41.0,
#               'time': '04:41:36'}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -37.288,
#               'longitude': 144.39,
#               'surface_temperature_celcius': 36.0,
#               'time': '23:56:43'}}
# {'hotspots': {'confidence': 58.0,
#               'latitude': -37.587,
#               'longitude': 142.479,
#               'surface_temperature_celcius': 41.0,
#               'time': '04:10:38'}}
# {'hotspots': {'confidence': 65.0,
#               'latitude': -37.296,
#               'longitude': 144.386,
#               'surface_temperature_celcius': 54.0,
#               'time': '00:27:12'}}
# {'hotspots': {'confidence': 65.0,
#               'latitude': -36.1,
#               'longitude': 143.772,
#               'surface_temperature_celcius': 35.0,
#               'time': '01:09:54'}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -36.156,
#               'longitude': 143.568,
#               'surface_temperature_celcius': 42.0,
#               'time': '04:04:53'}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -36.152,
#               'longitude': 143.578,
#               'surface_temperature_celcius': 44.0,
#               'time': '04:04:53'}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -36.748,
#               'longitude': 144.168,
#               'surface_temperature_celcius': 44.0,
#               'time': '04:47:31'}}
# {'hotspots': {'confidence': 60.0,
#               'latitude': -36.538,
#               'longitude': 141.129,
#               'surface_temperature_celcius': 43.0,
#               'time': '05:12:08'}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -36.759,
#               'longitude': 145.179,
#               'surface_temperature_celcius': 52.0,
#               'time': '04:16:56'}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -36.758,
#               'longitude': 145.19,
#               'surface_temperature_celcius': 51.0,
#               'time': '04:16:56'}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -37.719,
#               'longitude': 142.154,
#               'surface_temperature_celcius': 41.0,
#               'time': '04:16:46'}}
# {'hotspots': {'confidence': 51.0,
#               'latitude': -36.943,
#               'longitude': 143.286,
#               'surface_temperature_celcius': 29.0,
#               'time': '15:08:00'}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -36.942,
#               'longitude': 143.282,
#               'surface_temperature_celcius': 53.0,
#               'time': '04:47:32'}}
# {'hotspots': {'confidence': 58.0,
#               'latitude': -37.864,
#               'longitude': 144.174,
#               'surface_temperature_celcius': 41.0,
#               'time': '04:47:16'}}
# {'hotspots': {'confidence': 56.0,
#               'latitude': -38.912,
#               'longitude': 146.272,
#               'surface_temperature_celcius': 48.0,
#               'time': '04:46:53'}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -36.942,
#               'longitude': 143.292,
#               'surface_temperature_celcius': 54.0,
#               'time': '00:33:15'}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.954,
#               'longitude': 143.918,
#               'surface_temperature_celcius': 42.0,
#               'time': '03:52:08'}}
# {'hotspots': {'confidence': 51.0,
#               'latitude': -38.167,
#               'longitude': 143.841,
#               'surface_temperature_celcius': 38.0,
#               'time': '01:16:38'}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -38.16,
#               'longitude': 143.803,
#               'surface_temperature_celcius': 41.0,
#               'time': '01:16:37'}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -38.527,
#               'longitude': 143.493,
#               'surface_temperature_celcius': 45.0,
#               'time': '00:21:26'}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.332,
#               'longitude': 143.375,
#               'surface_temperature_celcius': 46.0,
#               'time': '00:21:07'}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -38.141,
#               'longitude': 143.183,
#               'surface_temperature_celcius': 46.0,
#               'time': '00:15:12'}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -36.952,
#               'longitude': 144.972,
#               'surface_temperature_celcius': 60.0,
#               'time': '00:14:47'}}
# {'hotspots': {'confidence': 50.0,
#               'latitude': -37.749,
#               'longitude': 148.297,
#               'surface_temperature_celcius': 42.0,
#               'time': '00:33:14'}}
# {'hotspots': {'confidence': 53.0,
#               'latitude': -37.611,
#               'longitude': 149.277,
#               'surface_temperature_celcius': 38.0,
#               'time': '13:17:24'}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -37.605,
#               'longitude': 149.308,
#               'surface_temperature_celcius': 43.0,
#               'time': '13:17:24'}}
# {'hotspots': {'confidence': 52.0,
#               'latitude': -34.282,
#               'longitude': 142.121,
#               'surface_temperature_celcius': 54.0,
#               'time': '03:53:16'}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.605,
#               'longitude': 149.326,
#               'surface_temperature_celcius': 44.0,
#               'time': '03:52:10'}}
# {'hotspots': {'confidence': 52.0,
#               'latitude': -37.635,
#               'longitude': 149.303,
#               'surface_temperature_celcius': 47.0,
#               'time': '23:25:57'}}
# {'hotspots': {'confidence': 51.0,
#               'latitude': -37.59,
#               'longitude': 149.31,
#               'surface_temperature_celcius': 42.0,
#               'time': '15:38:36'}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.633,
#               'longitude': 149.264,
#               'surface_temperature_celcius': 42.0,
#               'time': '15:38:36'}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -37.58,
#               'longitude': 149.331,
#               'surface_temperature_celcius': 35.0,
#               'time': '15:38:35'}}
# {'hotspots': {'confidence': 61.0,
#               'latitude': -37.38,
#               'longitude': 149.334,
#               'surface_temperature_celcius': 31.0,
#               'time': '15:38:32'}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -37.602,
#               'longitude': 149.295,
#               'surface_temperature_celcius': 33.0,
#               'time': '12:22:15'}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.598,
#               'longitude': 149.29,
#               'surface_temperature_celcius': 32.0,
#               'time': '12:22:15'}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -37.61,
#               'longitude': 149.279,
#               'surface_temperature_celcius': 48.0,
#               'time': '04:34:57'}}
# {'hotspots': {'confidence': 60.0,
#               'latitude': -37.637,
#               'longitude': 146.288,
#               'surface_temperature_celcius': 42.0,
#               'time': '00:21:00'}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -37.6,
#               'longitude': 149.297,
#               'surface_temperature_celcius': 50.0,
#               'time': '00:20:53'}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.382,
#               'longitude': 149.341,
#               'surface_temperature_celcius': 41.0,
#               'time': '00:20:49'}}
# {'hotspots': {'confidence': 56.0,
#               'latitude': -36.291,
#               'longitude': 146.159,
#               'surface_temperature_celcius': 40.0,
#               'time': '13:11:43'}}
# {'hotspots': {'confidence': 50.0,
#               'latitude': -37.987,
#               'longitude': 144.005,
#               'surface_temperature_celcius': 38.0,
#               'time': '00:57:59'}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -34.289,
#               'longitude': 141.712,
#               'surface_temperature_celcius': 54.0,
#               'time': '00:56:57'}}
# {'hotspots': {'confidence': 53.0,
#               'latitude': -37.903,
#               'longitude': 145.25,
#               'surface_temperature_celcius': 44.0,
#               'time': '00:45:38'}}
# {'hotspots': {'confidence': 51.0,
#               'latitude': -37.623,
#               'longitude': 149.323,
#               'surface_temperature_celcius': 38.0,
#               'time': '13:17:17'}}
# {'hotspots': {'confidence': 65.0,
#               'latitude': -38.038,
#               'longitude': 142.986,
#               'surface_temperature_celcius': 40.0,
#               'time': '01:16:23'}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -37.624,
#               'longitude': 149.332,
#               'surface_temperature_celcius': 33.0,
#               'time': '15:38:39'}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -37.82,
#               'longitude': 142.323,
#               'surface_temperature_celcius': 54.0,
#               'time': '04:35:15'}}
# {'hotspots': {'confidence': 59.0,
#               'latitude': -37.644,
#               'longitude': 149.346,
#               'surface_temperature_celcius': 55.0,
#               'time': '04:34:57'}}
# {'hotspots': {'confidence': 60.0,
#               'latitude': -38.046,
#               'longitude': 144.201,
#               'surface_temperature_celcius': 48.0,
#               'time': '00:21:11'}}
# {'hotspots': {'confidence': 53.0,
#               'latitude': -37.63,
#               'longitude': 149.335,
#               'surface_temperature_celcius': 57.0,
#               'time': '00:20:53'}}
# {'hotspots': {'confidence': 65.0,
#               'latitude': -35.646,
#               'longitude': 142.282,
#               'surface_temperature_celcius': 32.0,
#               'time': '13:12:01'}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -35.554,
#               'longitude': 143.307,
#               'surface_temperature_celcius': 53.0,
#               'time': '00:02:15'}}

# %%
# QUESTION H: Find the average surface temperature (°C) for each day. 
# Display average surface temperature (°C) and the date in the output

h = list(climate_data_collection.aggregate(
    [{'$unwind': '$hotspots'},
     {'$group': {'_id': '$date', 
                 'avg_surface_temp': {
                     '$avg': '$hotspots.surface_temperature_celcius'}}}]))
print("Average surface temperature (°C) for each day:")
for record in h:
    pprint(f"Date: {record['_id']}, Average Surface Temperature (°C): {record['avg_surface_temp']}")
# Out:
# Average surface temperature (°C) for each day:
# 'Date: 2023-10-07, Average Surface Temperature (°C): 42.0'
# 'Date: 2023-12-09, Average Surface Temperature (°C): 58.25'
# 'Date: 2023-03-06, Average Surface Temperature (°C): 60.5'
# 'Date: 2023-10-15, Average Surface Temperature (°C): 72.66666666666667'
# 'Date: 2023-12-27, Average Surface Temperature (°C): 62.75'
# 'Date: 2023-04-18, Average Surface Temperature (°C): 53.36615384615384'
# 'Date: 2023-09-27, Average Surface Temperature (°C): 49.714285714285715'
# 'Date: 2023-05-07, Average Surface Temperature (°C): 50.333333333333336'
# 'Date: 2023-05-23, Average Surface Temperature (°C): 51.2'
# 'Date: 2023-03-09, Average Surface Temperature (°C): 46.666666666666664'
# 'Date: 2023-03-29, Average Surface Temperature (°C): 51.0'
# 'Date: 2023-04-08, Average Surface Temperature (°C): 60.75'
# 'Date: 2023-04-16, Average Surface Temperature (°C): 48.72222222222222'
# 'Date: 2023-06-07, Average Surface Temperature (°C): 51.857142857142854'
# 'Date: 2023-11-08, Average Surface Temperature (°C): 45.5'
# 'Date: 2023-09-10, Average Surface Temperature (°C): 56.5'
# 'Date: 2023-03-24, Average Surface Temperature (°C): 49.0'
# 'Date: 2023-11-28, Average Surface Temperature (°C): 42.0'
# 'Date: 2023-10-21, Average Surface Temperature (°C): 51.25'
# 'Date: 2023-05-16, Average Surface Temperature (°C): 39.666666666666664'
# 'Date: 2023-10-02, Average Surface Temperature (°C): 43.57142857142857'
# 'Date: 2023-10-28, Average Surface Temperature (°C): 56.0'
# 'Date: 2023-06-18, Average Surface Temperature (°C): 42.0'
# 'Date: 2023-12-15, Average Surface Temperature (°C): 39.0'
# 'Date: 2023-04-14, Average Surface Temperature (°C): 61.94444444444444'
# 'Date: 2023-07-29, Average Surface Temperature (°C): 48.0'
# 'Date: 2023-10-06, Average Surface Temperature (°C): 44.0'
# 'Date: 2023-07-05, Average Surface Temperature (°C): 45.0'
# 'Date: 2023-03-12, Average Surface Temperature (°C): 88.2'
# 'Date: 2023-09-21, Average Surface Temperature (°C): 40.5'
# 'Date: 2023-11-23, Average Surface Temperature (°C): 58.8'
# 'Date: 2023-10-01, Average Surface Temperature (°C): 48.25'
# 'Date: 2023-04-06, Average Surface Temperature (°C): 61.71186440677966'
# 'Date: 2023-06-02, Average Surface Temperature (°C): 47.72727272727273'
# 'Date: 2023-05-26, Average Surface Temperature (°C): 49.5'
# 'Date: 2023-06-20, Average Surface Temperature (°C): 71.16666666666667'
# 'Date: 2023-10-10, Average Surface Temperature (°C): 53.333333333333336'
# 'Date: 2023-12-24, Average Surface Temperature (°C): 32.0'
# 'Date: 2023-05-11, Average Surface Temperature (°C): 59.36842105263158'
# 'Date: 2023-04-12, Average Surface Temperature (°C): 52.69565217391305'
# 'Date: 2023-04-26, Average Surface Temperature (°C): 34.0'
# 'Date: 2023-07-01, Average Surface Temperature (°C): 30.5'
# 'Date: 2023-03-07, Average Surface Temperature (°C): 64.0'
# 'Date: 2023-12-10, Average Surface Temperature (°C): 46.0'
# 'Date: 2023-04-01, Average Surface Temperature (°C): 46.714285714285715'
# 'Date: 2023-04-04, Average Surface Temperature (°C): 62.57303370786517'
# 'Date: 2023-04-20, Average Surface Temperature (°C): 56.58064516129032'
# 'Date: 2023-09-23, Average Surface Temperature (°C): 52.73913043478261'
# 'Date: 2023-10-26, Average Surface Temperature (°C): 44.6'
# 'Date: 2023-03-28, Average Surface Temperature (°C): 60.925925925925924'
# 'Date: 2023-11-05, Average Surface Temperature (°C): 58.5'
# 'Date: 2023-05-09, Average Surface Temperature (°C): 42.46153846153846'
# 'Date: 2023-12-25, Average Surface Temperature (°C): 54.0'
# 'Date: 2023-05-06, Average Surface Temperature (°C): 57.529411764705884'
# 'Date: 2023-06-13, Average Surface Temperature (°C): 41.0'
# 'Date: 2023-03-18, Average Surface Temperature (°C): 79.33333333333333'
# 'Date: 2023-06-11, Average Surface Temperature (°C): 41.5'
# 'Date: 2023-03-08, Average Surface Temperature (°C): 51.5'
# 'Date: 2023-05-18, Average Surface Temperature (°C): 44.142857142857146'
# 'Date: 2023-11-22, Average Surface Temperature (°C): 61.5'
# 'Date: 2023-03-19, Average Surface Temperature (°C): 65.57142857142857'
# 'Date: 2023-08-05, Average Surface Temperature (°C): 40.0'
# 'Date: 2023-09-20, Average Surface Temperature (°C): 63.6'
# 'Date: 2023-08-14, Average Surface Temperature (°C): 40.8'
# 'Date: 2023-10-20, Average Surface Temperature (°C): 50.0'
# 'Date: 2023-09-26, Average Surface Temperature (°C): 33.0'
# 'Date: 2023-06-22, Average Surface Temperature (°C): 46.0'
# 'Date: 2023-11-09, Average Surface Temperature (°C): 61.3'
# 'Date: 2023-11-30, Average Surface Temperature (°C): 52.41935483870968'
# 'Date: 2023-04-02, Average Surface Temperature (°C): 45.2'
# 'Date: 2023-04-29, Average Surface Temperature (°C): 63.0'
# 'Date: 2023-04-11, Average Surface Temperature (°C): 46.291666666666664'
# 'Date: 2023-03-13, Average Surface Temperature (°C): 38.5'
# 'Date: 2023-07-31, Average Surface Temperature (°C): 47.0'
# 'Date: 2023-04-07, Average Surface Temperature (°C): 50.69230769230769'
# 'Date: 2023-03-10, Average Surface Temperature (°C): 69.375'
# 'Date: 2023-04-17, Average Surface Temperature (°C): 50.921052631578945'
# 'Date: 2023-05-14, Average Surface Temperature (°C): 49.0'
# 'Date: 2023-08-13, Average Surface Temperature (°C): 49.0'
# 'Date: 2023-05-24, Average Surface Temperature (°C): 40.333333333333336'
# 'Date: 2023-09-29, Average Surface Temperature (°C): 43.0'
# 'Date: 2023-11-13, Average Surface Temperature (°C): 47.0'
# 'Date: 2023-06-04, Average Surface Temperature (°C): 52.22222222222222'
# 'Date: 2023-04-22, Average Surface Temperature (°C): 54.5'
# 'Date: 2023-06-03, Average Surface Temperature (°C): 47.0'
# 'Date: 2023-05-17, Average Surface Temperature (°C): 52.0'
# 'Date: 2023-10-04, Average Surface Temperature (°C): 49.0'
# 'Date: 2023-11-21, Average Surface Temperature (°C): 59.0'
# 'Date: 2023-12-08, Average Surface Temperature (°C): 50.6'
# 'Date: 2023-05-01, Average Surface Temperature (°C): 68.4'
# 'Date: 2023-05-05, Average Surface Temperature (°C): 51.70967741935484'
# 'Date: 2023-12-12, Average Surface Temperature (°C): 44.0'
# 'Date: 2023-04-23, Average Surface Temperature (°C): 53.89473684210526'
# 'Date: 2023-04-25, Average Surface Temperature (°C): 48.666666666666664'
# 'Date: 2023-08-02, Average Surface Temperature (°C): 63.5'
# 'Date: 2023-03-26, Average Surface Temperature (°C): 56.88235294117647'
# 'Date: 2023-10-17, Average Surface Temperature (°C): 51.6'
# 'Date: 2023-10-08, Average Surface Temperature (°C): 41.0'
# 'Date: 2023-10-27, Average Surface Temperature (°C): 50.4'
# 'Date: 2023-05-02, Average Surface Temperature (°C): 55.6'
# 'Date: 2023-04-03, Average Surface Temperature (°C): 58.44444444444444'
# 'Date: 2023-08-01, Average Surface Temperature (°C): 58.0'
# 'Date: 2023-06-14, Average Surface Temperature (°C): 53.25'
# 'Date: 2023-06-01, Average Surface Temperature (°C): 54.0'
# 'Date: 2023-07-06, Average Surface Temperature (°C): 56.0'
# 'Date: 2023-10-03, Average Surface Temperature (°C): 50.0'
# 'Date: 2023-05-13, Average Surface Temperature (°C): 58.611111111111114'
# 'Date: 2023-09-22, Average Surface Temperature (°C): 45.0'
# 'Date: 2023-10-09, Average Surface Temperature (°C): 44.0'
# 'Date: 2023-06-30, Average Surface Temperature (°C): 44.333333333333336'
# 'Date: 2023-04-24, Average Surface Temperature (°C): 59.375'
# 'Date: 2023-04-05, Average Surface Temperature (°C): 53.142857142857146'
# 'Date: 2023-12-14, Average Surface Temperature (°C): 70.0'
# 'Date: 2023-03-14, Average Surface Temperature (°C): 65.6'
# 'Date: 2023-11-29, Average Surface Temperature (°C): 60.625'
# 'Date: 2023-04-13, Average Surface Temperature (°C): 58.57983193277311'
# 'Date: 2023-09-24, Average Surface Temperature (°C): 53.57142857142857'
# 'Date: 2023-06-16, Average Surface Temperature (°C): 42.5'
# 'Date: 2023-11-14, Average Surface Temperature (°C): 52.0'
# 'Date: 2023-12-13, Average Surface Temperature (°C): 60.0'
# 'Date: 2023-05-22, Average Surface Temperature (°C): 54.484848484848484'
# 'Date: 2023-07-04, Average Surface Temperature (°C): 40.0'
# 'Date: 2023-07-02, Average Surface Temperature (°C): 43.5'
# 'Date: 2023-04-19, Average Surface Temperature (°C): 54.16'
# 'Date: 2023-03-25, Average Surface Temperature (°C): 66.0'
# 'Date: 2023-11-12, Average Surface Temperature (°C): 53.0'
# 'Date: 2023-06-09, Average Surface Temperature (°C): 49.0'
# 'Date: 2023-12-21, Average Surface Temperature (°C): 46.0'
# 'Date: 2023-10-23, Average Surface Temperature (°C): 38.0'
# 'Date: 2023-10-18, Average Surface Temperature (°C): 52.166666666666664'
# 'Date: 2023-05-08, Average Surface Temperature (°C): 56.291666666666664'
# 'Date: 2023-05-04, Average Surface Temperature (°C): 56.80740740740741'
# 'Date: 2023-07-14, Average Surface Temperature (°C): 41.5'
# 'Date: 2023-05-15, Average Surface Temperature (°C): 53.950980392156865'
# 'Date: 2023-05-10, Average Surface Temperature (°C): 52.86842105263158'
# 'Date: 2023-11-11, Average Surface Temperature (°C): 46.25'
# 'Date: 2023-03-15, Average Surface Temperature (°C): 46.0'
# 'Date: 2023-03-31, Average Surface Temperature (°C): 48.72727272727273'
# 'Date: 2023-10-16, Average Surface Temperature (°C): 36.0'
# 'Date: 2023-04-15, Average Surface Temperature (°C): 59.57971014492754'
# 'Date: 2023-05-03, Average Surface Temperature (°C): 56.796875'
# 'Date: 2023-08-10, Average Surface Temperature (°C): 63.0'
# 'Date: 2023-12-16, Average Surface Temperature (°C): 57.8'
# 'Date: 2023-05-12, Average Surface Temperature (°C): 51.5'
# 'Date: 2023-03-17, Average Surface Temperature (°C): 59.5'

# %%
# QUESTION I: Find the top 10 records with the lowest GHI.
i = list(climate_data_collection.aggregate([{'$sort': {'ghi': 1}},{'$limit': 10}]))
print("Top 10 records with the lowest GHI:")
for record in i:
    pprint(record)
# Out:
# Top 10 records with the lowest GHI:
# {'GHI_w/m2': 154.0,
#  '_id': ObjectId('6654141c4f0eb9e1d0be379f'),
#  'air_temperature_celcius': 19.0,
#  'date': '2023-01-09',
#  'hotspots': [],
#  'max_wind_speed': 8.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 56.3,
#  'station': '948700',
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 161.0,
#  '_id': ObjectId('6654141c4f0eb9e1d0be37a0'),
#  'air_temperature_celcius': 20.0,
#  'date': '2023-01-10',
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 57.0,
#  'station': '948700',
#  'windspeed_knots': 8.7}
# {'GHI_w/m2': 185.0,
#  '_id': ObjectId('6654141b4f0eb9e1d0be379b'),
#  'air_temperature_celcius': 24.0,
#  'date': '2023-01-05',
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 62.3,
#  'station': '948700',
#  'windspeed_knots': 7.0}
# {'GHI_w/m2': 160.0,
#  '_id': ObjectId('6654141c4f0eb9e1d0be379e'),
#  'air_temperature_celcius': 20.0,
#  'date': '2023-01-08',
#  'hotspots': [],
#  'max_wind_speed': 18.1,
#  'precipitation': '0.00I',
#  'relative_humidity': 57.7,
#  'station': '948700',
#  'windspeed_knots': 9.9}
# {'GHI_w/m2': 203.0,
#  '_id': ObjectId('6654141b4f0eb9e1d0be379c'),
#  'air_temperature_celcius': 26.0,
#  'date': '2023-01-06',
#  'hotspots': [],
#  'max_wind_speed': 12.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 60.8,
#  'station': '948700',
#  'windspeed_knots': 6.9}
# {'GHI_w/m2': 186.0,
#  '_id': ObjectId('6654141b4f0eb9e1d0be379a'),
#  'air_temperature_celcius': 24.0,
#  'date': '2023-01-04',
#  'hotspots': [],
#  'max_wind_speed': 14.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 61.6,
#  'station': '948700',
#  'windspeed_knots': 7.7}
# {'GHI_w/m2': 128.0,
#  '_id': ObjectId('6654141b4f0eb9e1d0be3798'),
#  'air_temperature_celcius': 15.0,
#  'date': '2023-01-02',
#  'hotspots': [],
#  'max_wind_speed': 13.0,
#  'precipitation': '0.02G',
#  'relative_humidity': 50.7,
#  'station': '948700',
#  'windspeed_knots': 9.2}
# {'GHI_w/m2': 154.0,
#  '_id': ObjectId('6654141b4f0eb9e1d0be3797'),
#  'air_temperature_celcius': 19.0,
#  'date': '2022-12-31',
#  'hotspots': [],
#  'max_wind_speed': 11.1,
#  'precipitation': '0.00I',
#  'relative_humidity': 56.8,
#  'station': '948700',
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 133.0,
#  '_id': ObjectId('6654141b4f0eb9e1d0be3799'),
#  'air_temperature_celcius': 16.0,
#  'date': '2023-01-03',
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation': '0.00G',
#  'relative_humidity': 53.6,
#  'station': '948700',
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 265.0,
#  '_id': ObjectId('6654141b4f0eb9e1d0be379d'),
#  'air_temperature_celcius': 32.0,
#  'date': '2023-01-07',
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 54.1,
#  'station': '948700',
#  'windspeed_knots': 12.8}

# %%
# QUESTION J: Find the records with a 24-hour precipitation recorded between 0.20 to 0.35.
# we want it ending with G, G=1reportof24-hourprecipitation amount.

j = list(climate_data_collection.aggregate(
    [{'$match': {'precipitation': {'$gt': '0.20G','$lt': '0.35G'}}
    }]))
print(len(j))
print("Records with a 24-hour precipitation recorded between 0.20 to 0.35:")
for record in j:
    pprint(record)
# Out:
# 13
# Records with a 24-hour precipitation recorded between 0.20 to 0.35:
# {'GHI_w/m2': 157.0,
#  '_id': ObjectId('6654141c4f0eb9e1d0be37a3'),
#  'air_temperature_celcius': 19.0,
#  'date': '2023-01-13',
#  'hotspots': [],
#  'max_wind_speed': 18.1,
#  'precipitation': '0.31G',
#  'relative_humidity': 54.1,
#  'station': '948700',
#  'windspeed_knots': 11.2}
# {'GHI_w/m2': 146.0,
#  '_id': ObjectId('665414214f0eb9e1d0be37ee'),
#  'air_temperature_celcius': 17.0,
#  'date': '2023-03-29',
#  'hotspots': [{'confidence': 69.0,
#                'latitude': -34.2648,
#                'longitude': 141.6325,
#                'surface_temperature_celcius': 51.0,
#                'time': '00:48:40'}],
#  'max_wind_speed': 21.0,
#  'precipitation': '0.24G',
#  'relative_humidity': 49.9,
#  'station': '948701',
#  'windspeed_knots': 12.2}
# {'GHI_w/m2': 166.0,
#  '_id': ObjectId('665414224f0eb9e1d0be3804'),
#  'air_temperature_celcius': 20.0,
#  'date': '2023-04-20',
#  'hotspots': [{'confidence': 84.0,
#                'latitude': -36.8871,
#                'longitude': 145.1536,
#                'surface_temperature_celcius': 58.0,
#                'time': '04:44:20'},
#               {'confidence': 59.0,
#                'latitude': -38.4685,
#                'longitude': 146.673,
#                'surface_temperature_celcius': 40.0,
#                'time': '04:36:00'},
#               {'confidence': 60.0,
#                'latitude': -36.8922,
#                'longitude': 145.1252,
#                'surface_temperature_celcius': 40.0,
#                'time': '04:34:10'},
#               {'confidence': 93.0,
#                'latitude': -37.769,
#                'longitude': 147.94,
#                'surface_temperature_celcius': 72.0,
#                'time': '04:34:10'},
#               {'confidence': 77.0,
#                'latitude': -36.0799,
#                'longitude': 146.0784,
#                'surface_temperature_celcius': 50.0,
#                'time': '04:33:40'},
#               {'confidence': 88.0,
#                'latitude': -36.0829,
#                'longitude': 146.0621,
#                'surface_temperature_celcius': 63.0,
#                'time': '04:33:20'},
#               {'confidence': 90.0,
#                'latitude': -36.1303,
#                'longitude': 146.3606,
#                'surface_temperature_celcius': 67.0,
#                'time': '04:32:50'},
#               {'confidence': 67.0,
#                'latitude': -37.7615,
#                'longitude': 147.9169,
#                'surface_temperature_celcius': 45.0,
#                'time': '04:32:50'},
#               {'confidence': 63.0,
#                'latitude': -36.8079,
#                'longitude': 145.1409,
#                'surface_temperature_celcius': 42.0,
#                'time': '04:32:30'},
#               {'confidence': 85.0,
#                'latitude': -37.7783,
#                'longitude': 147.9284,
#                'surface_temperature_celcius': 60.0,
#                'time': '04:32:30'},
#               {'confidence': 79.0,
#                'latitude': -36.8846,
#                'longitude': 145.1679,
#                'surface_temperature_celcius': 52.0,
#                'time': '04:32:30'},
#               {'confidence': 80.0,
#                'latitude': -37.2341,
#                'longitude': 149.1736,
#                'surface_temperature_celcius': 53.0,
#                'time': '04:32:30'},
#               {'confidence': 63.0,
#                'latitude': -36.9189,
#                'longitude': 147.5603,
#                'surface_temperature_celcius': 52.0,
#                'time': '04:32:30'},
#               {'confidence': 98.0,
#                'latitude': -36.1345,
#                'longitude': 146.351,
#                'surface_temperature_celcius': 84.0,
#                'time': '04:32:30'},
#               {'confidence': 87.0,
#                'latitude': -36.9246,
#                'longitude': 147.5559,
#                'surface_temperature_celcius': 62.0,
#                'time': '04:32:30'},
#               {'confidence': 64.0,
#                'latitude': -36.085,
#                'longitude': 145.9096,
#                'surface_temperature_celcius': 42.0,
#                'time': '00:19:00'},
#               {'confidence': 88.0,
#                'latitude': -38.1301,
#                'longitude': 143.9398,
#                'surface_temperature_celcius': 63.0,
#                'time': '00:18:40'},
#               {'confidence': 69.0,
#                'latitude': -37.7087,
#                'longitude': 145.5499,
#                'surface_temperature_celcius': 45.0,
#                'time': '00:18:20'},
#               {'confidence': 100.0,
#                'latitude': -36.5865,
#                'longitude': 145.2081,
#                'surface_temperature_celcius': 111.0,
#                'time': '00:18:20'},
#               {'confidence': 73.0,
#                'latitude': -36.8702,
#                'longitude': 144.0381,
#                'surface_temperature_celcius': 47.0,
#                'time': '00:17:10'},
#               {'confidence': 99.0,
#                'latitude': -36.1586,
#                'longitude': 145.6666,
#                'surface_temperature_celcius': 85.0,
#                'time': '00:17:10'},
#               {'confidence': 74.0,
#                'latitude': -37.8672,
#                'longitude': 143.8194,
#                'surface_temperature_celcius': 48.0,
#                'time': '00:16:50'},
#               {'confidence': 78.0,
#                'latitude': -36.5956,
#                'longitude': 145.206,
#                'surface_temperature_celcius': 51.0,
#                'time': '00:15:30'},
#               {'confidence': 77.0,
#                'latitude': -37.2197,
#                'longitude': 148.8134,
#                'surface_temperature_celcius': 50.0,
#                'time': '00:14:20'},
#               {'confidence': 96.0,
#                'latitude': -36.5847,
#                'longitude': 145.1968,
#                'surface_temperature_celcius': 78.0,
#                'time': '00:14:10'},
#               {'confidence': 89.0,
#                'latitude': -37.6997,
#                'longitude': 145.5519,
#                'surface_temperature_celcius': 64.0,
#                'time': '00:13:40'},
#               {'confidence': 61.0,
#                'latitude': -37.932,
#                'longitude': 146.1845,
#                'surface_temperature_celcius': 50.0,
#                'time': '00:13:30'},
#               {'confidence': 76.0,
#                'latitude': -36.6407,
#                'longitude': 144.2957,
#                'surface_temperature_celcius': 50.0,
#                'time': '00:13:10'},
#               {'confidence': 63.0,
#                'latitude': -36.1569,
#                'longitude': 145.6554,
#                'surface_temperature_celcius': 41.0,
#                'time': '00:13:00'},
#               {'confidence': 54.0,
#                'latitude': -36.6363,
#                'longitude': 144.3033,
#                'surface_temperature_celcius': 40.0,
#                'time': '00:13:00'},
#               {'confidence': 76.0,
#                'latitude': -37.2212,
#                'longitude': 148.8262,
#                'surface_temperature_celcius': 49.0,
#                'time': '00:12:50'}],
#  'max_wind_speed': 15.9,
#  'precipitation': '0.31G',
#  'relative_humidity': 53.5,
#  'station': '948701',
#  'windspeed_knots': 7.2}
# {'GHI_w/m2': 102.0,
#  '_id': ObjectId('665414224f0eb9e1d0be380a'),
#  'air_temperature_celcius': 11.0,
#  'date': '2023-04-26',
#  'hotspots': [{'confidence': 56.0,
#                'latitude': -36.5511,
#                'longitude': 146.7819,
#                'surface_temperature_celcius': 34.0,
#                'time': '13:26:10'}],
#  'max_wind_speed': 20.0,
#  'precipitation': '0.24G',
#  'relative_humidity': 40.8,
#  'station': '948701',
#  'windspeed_knots': 12.2}
# {'GHI_w/m2': 73.0,
#  '_id': ObjectId('665414244f0eb9e1d0be382c'),
#  'air_temperature_celcius': 8.0,
#  'date': '2023-05-30',
#  'hotspots': [],
#  'max_wind_speed': 15.9,
#  'precipitation': '0.24G',
#  'relative_humidity': 41.6,
#  'station': '948701',
#  'windspeed_knots': 8.3}
# {'GHI_w/m2': 99.0,
#  '_id': ObjectId('665414274f0eb9e1d0be3866'),
#  'air_temperature_celcius': 11.0,
#  'date': '2023-07-27',
#  'hotspots': [],
#  'max_wind_speed': 21.0,
#  'precipitation': '0.24G',
#  'relative_humidity': 43.5,
#  'station': '948701',
#  'windspeed_knots': 13.1}
# {'GHI_w/m2': 83.0,
#  '_id': ObjectId('665414274f0eb9e1d0be3870'),
#  'air_temperature_celcius': 9.0,
#  'date': '2023-08-06',
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation': '0.24G',
#  'relative_humidity': 41.1,
#  'station': '948702',
#  'windspeed_knots': 12.7}
# {'GHI_w/m2': 102.0,
#  '_id': ObjectId('665414284f0eb9e1d0be3884'),
#  'air_temperature_celcius': 11.0,
#  'date': '2023-08-26',
#  'hotspots': [],
#  'max_wind_speed': 19.0,
#  'precipitation': '0.28G',
#  'relative_humidity': 39.7,
#  'station': '948702',
#  'windspeed_knots': 11.8}
# {'GHI_w/m2': 75.0,
#  '_id': ObjectId('665414284f0eb9e1d0be388e'),
#  'air_temperature_celcius': 8.0,
#  'date': '2023-09-05',
#  'hotspots': [],
#  'max_wind_speed': 18.1,
#  'precipitation': '0.31G',
#  'relative_humidity': 38.6,
#  'station': '948702',
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 97.0,
#  '_id': ObjectId('665414294f0eb9e1d0be3898'),
#  'air_temperature_celcius': 11.0,
#  'date': '2023-09-15',
#  'hotspots': [],
#  'max_wind_speed': 15.0,
#  'precipitation': '0.28G',
#  'relative_humidity': 46.2,
#  'station': '948702',
#  'windspeed_knots': 10.5}
# {'GHI_w/m2': 152.0,
#  '_id': ObjectId('6654142b4f0eb9e1d0be38c4'),
#  'air_temperature_celcius': 17.0,
#  'date': '2023-10-29',
#  'hotspots': [],
#  'max_wind_speed': 27.0,
#  'precipitation': '0.24G',
#  'relative_humidity': 44.9,
#  'station': '948702',
#  'windspeed_knots': 16.1}
# {'GHI_w/m2': 140.0,
#  '_id': ObjectId('6654142c4f0eb9e1d0be38d6'),
#  'air_temperature_celcius': 18.0,
#  'date': '2023-11-16',
#  'hotspots': [],
#  'max_wind_speed': 11.1,
#  'precipitation': '0.28G',
#  'relative_humidity': 61.5,
#  'station': '948702',
#  'windspeed_knots': 5.5}
# {'GHI_w/m2': 151.0,
#  '_id': ObjectId('6654142c4f0eb9e1d0be38d7'),
#  'air_temperature_celcius': 19.0,
#  'date': '2023-11-17',
#  'hotspots': [],
#  'max_wind_speed': 12.0,
#  'precipitation': '0.28G',
#  'relative_humidity': 58.7,
#  'station': '948702',
#  'windspeed_knots': 5.5}

# %% [markdown]
# ### Task 2.3 Optimization

# %%
# Get the admin database
admin_db = client.admin

# Run the currentOp command
current_op_result = admin_db.command({"currentOp": 1})

# Print the result
pprint(current_op_result)
# Out:
# {'inprog': [{'active': True,
#              'client': '172.17.0.1:43978',
#              'clientMetadata': {'driver': {'name': 'PyMongo',
#                                            'version': '4.3.3'},
#                                 'os': {'architecture': 'x86_64',
#                                        'name': 'Linux',
#                                        'type': 'Linux',
#                                        'version': '5.15.133.1-microsoft-standard-WSL2'},
#                                 'platform': 'CPython 3.8.16.final.0'},
#              'command': {'$db': 'admin',
#                          'currentOp': 1,
#                          'lsid': {'id': Binary(b'\xbe\t\x19P\x19\x89G\x0c\x9cpJ\xa4\xe2`[D', 4)}},
#              'connectionId': 6,
#              'currentOpTime': '2024-05-27T15:06:18.771+10:00',
#              'desc': 'conn6',
#              'flowControlStats': {},
#              'host': '77a8ae913ea1:27017',
#              'lockStats': {},
#              'locks': {},
#              'lsid': {'id': Binary(b'\xbe\t\x19P\x19\x89G\x0c\x9cpJ\xa4\xe2`[D', 4),
#                       'uid': b'\xe3\xb0\xc4B\x98\xfc\x1c\x14\x9a\xfb\xf4\xc8'
#                              b"\x99o\xb9$'\xaeA\xe4d\x9b\x93L\xa4\x95\x99\x1b"
#                              b'xR\xb8U'},
#              'microsecs_running': 1304,
#              'ns': 'admin.$cmd.aggregate',
#              'numYields': 0,
#              'op': 'command',
#              'opid': 25455,
#              'secs_running': 0,
#              'threaded': True,
#              'type': 'op',
#              'waitingForFlowControl': False,
#              'waitingForLock': False},
#             {'active': True,
#              'client': '172.17.0.1:43956',
#              'clientMetadata': {'driver': {'name': 'PyMongo',
#                                            'version': '4.3.3'},
#                                 'os': {'architecture': 'x86_64',
#                                        'name': 'Linux',
#                                        'type': 'Linux',
#                                        'version': '5.15.133.1-microsoft-standard-WSL2'},
#                                 'platform': 'CPython 3.8.16.final.0'},
#              'command': {'$db': 'admin',
#                          'hello': 1,
#                          'maxAwaitTimeMS': 10000,
#                          'topologyVersion': {'counter': 0,
#                                              'processId': ObjectId('66540b935046bbc980b8f080')}},
#              'connectionId': 4,
#              'currentOpTime': '2024-05-27T15:06:18.772+10:00',
#              'desc': 'conn4',
#              'flowControlStats': {},
#              'host': '77a8ae913ea1:27017',
#              'lockStats': {},
#              'locks': {},
#              'microsecs_running': 7826450,
#              'ns': 'admin.$cmd',
#              'numYields': 0,
#              'op': 'command',
#              'opid': 25337,
#              'secs_running': 7,
#              'threaded': True,
#              'type': 'op',
#              'waitingForFlowControl': False,
#              'waitingForLatch': {'captureName': 'AnonymousLatch',
#                                  'timestamp': datetime.datetime(2024, 5, 27, 5, 6, 11, 46000)},
#              'waitingForLock': False},
#             {'active': True,
#              'command': {},
#              'currentOpTime': '2024-05-27T15:06:18.772+10:00',
#              'desc': 'JournalFlusher',
#              'flowControlStats': {},
#              'host': '77a8ae913ea1:27017',
#              'lockStats': {},
#              'locks': {},
#              'ns': '',
#              'numYields': 0,
#              'op': 'none',
#              'opid': 25452,
#              'type': 'op',
#              'waitingForFlowControl': False,
#              'waitingForLock': False},
#             {'active': True,
#              'command': {},
#              'currentOpTime': '2024-05-27T15:06:18.772+10:00',
#              'desc': 'Checkpointer',
#              'flowControlStats': {},
#              'host': '77a8ae913ea1:27017',
#              'lockStats': {},
#              'locks': {},
#              'ns': '',
#              'numYields': 0,
#              'op': 'none',
#              'opid': 24927,
#              'type': 'op',
#              'waitingForFlowControl': False,
#              'waitingForLock': False}],
#  'ok': 1.0}

# %% [markdown]
# Overall, this performance snapshot indicates that there are multiple active operations, mostly command-related, within the MongoDB deployment. The operations seem to be initiated by clients using PyMongo drivers, running on both Windows and Linux platforms. They are generally performing well, with varying durations and some minor waits observed.

# %%
query = {'precipitation': {'$gte': '0.20G','$lte': '0.35G'}}

# Use $explain to evaluate the query
query_explain = climate_data_collection.find(query).explain()

# Print the explanation
pprint(query_explain)
# Out:
# {'command': {'$db': 'fit3182_assignment_db',
#              'filter': {'precipitation': {'$gte': '0.20G', '$lte': '0.35G'}},
#              'find': 'climate_data'},
#  'executionStats': {'allPlansExecution': [],
#                     'executionStages': {'advanced': 19,
#                                         'direction': 'forward',
#                                         'docsExamined': 366,
#                                         'executionTimeMillisEstimate': 0,
#                                         'filter': {'$and': [{'precipitation': {'$lte': '0.35G'}},
#                                                             {'precipitation': {'$gte': '0.20G'}}]},
#                                         'isEOF': 1,
#                                         'nReturned': 19,
#                                         'needTime': 348,
#                                         'needYield': 0,
#                                         'restoreState': 0,
#                                         'saveState': 0,
#                                         'stage': 'COLLSCAN',
#                                         'works': 368},
#                     'executionSuccess': True,
#                     'executionTimeMillis': 2,
#                     'nReturned': 19,
#                     'totalDocsExamined': 366,
#                     'totalKeysExamined': 0},
#  'explainVersion': '1',
#  'ok': 1.0,
#  'queryPlanner': {'indexFilterSet': False,
#                   'maxIndexedAndSolutionsReached': False,
#                   'maxIndexedOrSolutionsReached': False,
#                   'maxScansToExplodeReached': False,
#                   'namespace': 'fit3182_assignment_db.climate_data',
#                   'parsedQuery': {'$and': [{'precipitation': {'$lte': '0.35G'}},
#                                            {'precipitation': {'$gte': '0.20G'}}]},
#                   'planCacheKey': '9E8199A3',
#                   'queryHash': '9E8199A3',
#                   'rejectedPlans': [],
#                   'winningPlan': {'direction': 'forward',
#                                   'filter': {'$and': [{'precipitation': {'$lte': '0.35G'}},
#                                                       {'precipitation': {'$gte': '0.20G'}}]},
#                                   'stage': 'COLLSCAN'}},
#  'serverInfo': {'gitVersion': '44ff59461c1353638a71e710f385a566bcd2f547',
#                 'host': '77a8ae913ea1',
#                 'port': 27017,
#                 'version': '6.0.4'},
#  'serverParameters': {'internalDocumentSourceGroupMaxMemoryBytes': 104857600,
#                       'internalDocumentSourceSetWindowFieldsMaxMemoryBytes': 104857600,
#                       'internalLookupStageIntermediateDocumentMaxSizeBytes': 104857600,
#                       'internalQueryFacetBufferSizeBytes': 104857600,
#                       'internalQueryFacetMaxOutputDocSizeBytes': 104857600,
#                       'internalQueryMaxAddToSetBytes': 104857600,
#                       'internalQueryMaxBlockingSortMemoryUsageBytes': 104857600,
#                       'internalQueryProhibitBlockingMergeOnMongoS': 0}}

# %%
# happens 5 times
hotspots_collection.create_index([('surface_temperature_celcius', 1)])

#happens 3 times
hotspots_collection.create_index([('confidence', 1)])

# happens 2 times
hotspots_collection.create_index([('air_temperature_celcius', 1)])
hotspots_collection.create_index([('date', 1), ('surface_temperature_celcius', 1)])
hotspots_collection.create_index([('date', -1)])
hotspots_collection.create_index([('GHI_w/m2', 1)])
hotspots_collection.create_index([('precipitation', 1)])
# Out:
# ----------------------------------------------------------------
# NameError                      Traceback (most recent call last)
# Cell In[25], line 2
#       1 # happens 5 times
# ----> 2 hotspots_collection.create_index([('surface_temperature_celcius', 1)])
#       4 #happens 3 times
#       5 hotspots_collection.create_index([('confidence', 1)])
#
# NameError: name 'hotspots_collection' is not defined

# %% [markdown]
# For the queries mentioned in Task 2, typical fields involved include date, surface_temperature_celcius, confidence, GHI_w/m2, precipitation, etc.
#
# Justification for Index Design:
#
# Indexes on date, surface_temperature_celcius, confidence, GHI_w/m2, and precipitation are essential for the given queries.
# Single-field indexes are efficient for queries filtering on a single field. The chosen index design for date, surface_temperature_celcius, confidence, GHI_w/m2, and precipitation strikes a balance between efficiency and resource utilization. Single-field indexes cater to individual field queries, while potential compound indexes can be explored based on the specific query patterns in Task 2. By monitoring query performance and analyzing data distribution, further optimizations to the index strategy can be made.
